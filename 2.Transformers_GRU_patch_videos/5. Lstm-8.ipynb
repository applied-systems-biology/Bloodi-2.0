# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 2048
MAX_SEQ_LENGTH = 40
IMG_SIZE = 456

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==11)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1152, 40, 2048)
# (1152, 1)
# (144, 40, 2048)
# (144, 1)

# %%
with strategy.scope():

    def get_compiled_model():
        
        frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))

        x = keras.layers.GRU(128, return_sequences=True)(frame_features_input)
        x = keras.layers.GRU(64)(x)
        x = keras.layers.Dropout(0.4)(x)
        x = keras.layers.Dense(64, activation="relu")(x)
        output = keras.layers.Dense(3, activation="softmax")(x)

        rnn_model = keras.Model(frame_features_input, output)

        rnn_model.compile(
            loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
        )
        
        rnn_model.summary()
        
        return rnn_model
    
with strategy.scope():
    
    def run_experiment():
        
        filepath = "lstm_8.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 40, 2048)]        0
#
#  gru (GRU)                   (None, 40, 128)           836352
#
#  gru_1 (GRU)                 (None, 64)                37248
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 877,955
# Trainable params: 877,955
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.6281 - accuracy: 0.7087
# Epoch 1: val_loss improved from inf to 0.12152, saving model to lstm_8.h5
# 33/33 [==============================] - 5s 30ms/step - loss: 0.6161 - accuracy: 0.7143 - val_loss: 0.1215 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 2/500
# 28/33 [========================>.....] - ETA: 0s - loss: 0.2486 - accuracy: 0.9051
# Epoch 2: val_loss improved from 0.12152 to 0.08030, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 0.2384 - accuracy: 0.9093 - val_loss: 0.0803 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 3/500
# 27/33 [=======================>......] - ETA: 0s - loss: 0.1114 - accuracy: 0.9595
# Epoch 3: val_loss improved from 0.08030 to 0.06798, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 0.1306 - accuracy: 0.9517 - val_loss: 0.0680 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 4/500
# 26/33 [======================>.......] - ETA: 0s - loss: 0.0931 - accuracy: 0.9651
# Epoch 4: val_loss did not improve from 0.06798
# 33/33 [==============================] - 0s 9ms/step - loss: 0.1121 - accuracy: 0.9595 - val_loss: 0.0952 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 5/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0585 - accuracy: 0.9823
# Epoch 5: val_loss improved from 0.06798 to 0.00336, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0636 - accuracy: 0.9817 - val_loss: 0.0034 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0167 - accuracy: 0.9969
# Epoch 6: val_loss did not improve from 0.00336
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0165 - accuracy: 0.9971 - val_loss: 0.0411 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 7/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0492 - accuracy: 0.9844
# Epoch 7: val_loss did not improve from 0.00336
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0487 - accuracy: 0.9846 - val_loss: 0.0458 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 8/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0663 - accuracy: 0.9740
# Epoch 8: val_loss did not improve from 0.00336
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0619 - accuracy: 0.9759 - val_loss: 0.0064 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 9/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9952
# Epoch 9: val_loss improved from 0.00336 to 0.00061, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0165 - accuracy: 0.9952 - val_loss: 6.1218e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 10/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9990
# Epoch 10: val_loss improved from 0.00061 to 0.00032, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0048 - accuracy: 0.9990 - val_loss: 3.2412e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 11/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9846
# Epoch 11: val_loss did not improve from 0.00032
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0462 - accuracy: 0.9846 - val_loss: 0.0034 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 12/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 12: val_loss did not improve from 0.00032
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 13/500
# 25/33 [=====================>........] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 13: val_loss improved from 0.00032 to 0.00030, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.9515e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 14/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 14: val_loss improved from 0.00030 to 0.00024, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.4073e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 15/500
# 32/33 [============================>.] - ETA: 0s - loss: 8.4891e-04 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.00024 to 0.00020, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 17ms/step - loss: 8.4459e-04 - accuracy: 1.0000 - val_loss: 1.9665e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/500
# 30/33 [==========================>...] - ETA: 0s - loss: 8.5367e-04 - accuracy: 1.0000
# Epoch 16: val_loss improved from 0.00020 to 0.00016, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 26ms/step - loss: 8.3846e-04 - accuracy: 1.0000 - val_loss: 1.6049e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/500
# 32/33 [============================>.] - ETA: 0s - loss: 6.5188e-04 - accuracy: 1.0000
# Epoch 17: val_loss improved from 0.00016 to 0.00012, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 22ms/step - loss: 6.5463e-04 - accuracy: 1.0000 - val_loss: 1.1814e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/500
# 28/33 [========================>.....] - ETA: 0s - loss: 5.6968e-04 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.00012 to 0.00010, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 20ms/step - loss: 5.6826e-04 - accuracy: 1.0000 - val_loss: 1.0269e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/500
# 33/33 [==============================] - ETA: 0s - loss: 4.6375e-04 - accuracy: 1.0000
# Epoch 19: val_loss improved from 0.00010 to 0.00009, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 4.6375e-04 - accuracy: 1.0000 - val_loss: 9.0353e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/500
# 31/33 [===========================>..] - ETA: 0s - loss: 3.7419e-04 - accuracy: 1.0000
# Epoch 20: val_loss improved from 0.00009 to 0.00008, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 26ms/step - loss: 3.6999e-04 - accuracy: 1.0000 - val_loss: 7.9422e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 21/500
# 33/33 [==============================] - ETA: 0s - loss: 3.0250e-04 - accuracy: 1.0000
# Epoch 21: val_loss improved from 0.00008 to 0.00007, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 20ms/step - loss: 3.0250e-04 - accuracy: 1.0000 - val_loss: 6.9781e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 22/500
# 30/33 [==========================>...] - ETA: 0s - loss: 3.5226e-04 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.00007 to 0.00006, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 24ms/step - loss: 3.4509e-04 - accuracy: 1.0000 - val_loss: 5.9624e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 23/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.2177e-04 - accuracy: 1.0000
# Epoch 23: val_loss improved from 0.00006 to 0.00006, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 3.2255e-04 - accuracy: 1.0000 - val_loss: 5.5345e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.8203e-04 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.00006 to 0.00005, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.7698e-04 - accuracy: 1.0000 - val_loss: 4.9701e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 25/500
# 30/33 [==========================>...] - ETA: 0s - loss: 3.0501e-04 - accuracy: 1.0000
# Epoch 25: val_loss improved from 0.00005 to 0.00004, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.9088e-04 - accuracy: 1.0000 - val_loss: 4.4959e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 26/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.7129e-04 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 10ms/step - loss: 3.7240e-04 - accuracy: 1.0000 - val_loss: 4.6862e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 27/500
# 27/33 [=======================>......] - ETA: 0s - loss: 2.4475e-04 - accuracy: 1.0000
# Epoch 27: val_loss improved from 0.00004 to 0.00004, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 17ms/step - loss: 2.4335e-04 - accuracy: 1.0000 - val_loss: 3.6951e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 28/500
# 33/33 [==============================] - ETA: 0s - loss: 2.0889e-04 - accuracy: 1.0000
# Epoch 28: val_loss improved from 0.00004 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 2.0889e-04 - accuracy: 1.0000 - val_loss: 3.3291e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 29/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.7317e-04 - accuracy: 1.0000
# Epoch 29: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 33/33 [==============================] - 0s 15ms/step - loss: 1.7015e-04 - accuracy: 1.0000 - val_loss: 3.0126e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 30/500
# 25/33 [=====================>........] - ETA: 0s - loss: 1.8000e-04 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 1.9321e-04 - accuracy: 1.0000 - val_loss: 2.9875e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 31/500
# 25/33 [=====================>........] - ETA: 0s - loss: 1.8682e-04 - accuracy: 1.0000
# Epoch 31: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 1.8776e-04 - accuracy: 1.0000 - val_loss: 2.9635e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 32/500
# 27/33 [=======================>......] - ETA: 0s - loss: 2.2228e-04 - accuracy: 1.0000
# Epoch 32: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 2.0501e-04 - accuracy: 1.0000 - val_loss: 2.9394e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 33/500
# 33/33 [==============================] - ETA: 0s - loss: 1.7295e-04 - accuracy: 1.0000
# Epoch 33: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 15ms/step - loss: 1.7295e-04 - accuracy: 1.0000 - val_loss: 2.9203e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 34/500
# 33/33 [==============================] - ETA: 0s - loss: 1.8788e-04 - accuracy: 1.0000
# Epoch 34: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 1.8788e-04 - accuracy: 1.0000 - val_loss: 2.8924e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 35/500
# 30/33 [==========================>...] - ETA: 0s - loss: 2.0482e-04 - accuracy: 1.0000
# Epoch 35: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.0523e-04 - accuracy: 1.0000 - val_loss: 2.8655e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 36/500
# 33/33 [==============================] - ETA: 0s - loss: 1.5871e-04 - accuracy: 1.0000
# Epoch 36: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 1.5871e-04 - accuracy: 1.0000 - val_loss: 2.8393e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 37/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.2601e-04 - accuracy: 1.0000
# Epoch 37: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.2412e-04 - accuracy: 1.0000 - val_loss: 2.7988e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 38/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.8983e-04 - accuracy: 1.0000
# Epoch 38: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 17ms/step - loss: 1.8870e-04 - accuracy: 1.0000 - val_loss: 2.7689e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 39/500
# 33/33 [==============================] - ETA: 0s - loss: 1.6439e-04 - accuracy: 1.0000
# Epoch 39: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 33/33 [==============================] - 0s 14ms/step - loss: 1.6439e-04 - accuracy: 1.0000 - val_loss: 2.7479e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 40/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.4437e-04 - accuracy: 1.0000
# Epoch 40: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 1.4424e-04 - accuracy: 1.0000 - val_loss: 2.7461e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 41/500
# 33/33 [==============================] - ETA: 0s - loss: 1.7920e-04 - accuracy: 1.0000
# Epoch 41: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 1.7920e-04 - accuracy: 1.0000 - val_loss: 2.7435e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 42/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.5299e-04 - accuracy: 1.0000
# Epoch 42: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 1.5798e-04 - accuracy: 1.0000 - val_loss: 2.7409e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 43/500
# 29/33 [=========================>....] - ETA: 0s - loss: 1.6329e-04 - accuracy: 1.0000
# Epoch 43: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 15ms/step - loss: 1.6122e-04 - accuracy: 1.0000 - val_loss: 2.7389e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 44/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.7960e-04 - accuracy: 1.0000
# Epoch 44: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 15ms/step - loss: 1.8533e-04 - accuracy: 1.0000 - val_loss: 2.7365e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 45/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.7384e-04 - accuracy: 1.0000
# Epoch 45: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 1.7102e-04 - accuracy: 1.0000 - val_loss: 2.7333e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 46/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.4620e-04 - accuracy: 1.0000
# Epoch 46: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 1.4902e-04 - accuracy: 1.0000 - val_loss: 2.7300e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 47/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.8544e-04 - accuracy: 1.0000
# Epoch 47: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 15ms/step - loss: 1.9688e-04 - accuracy: 1.0000 - val_loss: 2.7262e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 48/500
# 33/33 [==============================] - ETA: 0s - loss: 1.8465e-04 - accuracy: 1.0000
# Epoch 48: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 19ms/step - loss: 1.8465e-04 - accuracy: 1.0000 - val_loss: 2.7220e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 49/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.8783e-04 - accuracy: 1.0000
# Epoch 49: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 33/33 [==============================] - 1s 22ms/step - loss: 1.8148e-04 - accuracy: 1.0000 - val_loss: 2.7195e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 50/500
# 33/33 [==============================] - ETA: 0s - loss: 1.6392e-04 - accuracy: 1.0000
# Epoch 50: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 20ms/step - loss: 1.6392e-04 - accuracy: 1.0000 - val_loss: 2.7192e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 51/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.4576e-04 - accuracy: 1.0000
# Epoch 51: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 17ms/step - loss: 1.4273e-04 - accuracy: 1.0000 - val_loss: 2.7187e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 52/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.5972e-04 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 14ms/step - loss: 1.5902e-04 - accuracy: 1.0000 - val_loss: 2.7187e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 53/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.0822e-04 - accuracy: 1.0000
# Epoch 53: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 2.0687e-04 - accuracy: 1.0000 - val_loss: 2.7183e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 54/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.3827e-04 - accuracy: 1.0000
# Epoch 54: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 15ms/step - loss: 1.4065e-04 - accuracy: 1.0000 - val_loss: 2.7180e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 55/500
# 29/33 [=========================>....] - ETA: 0s - loss: 1.7282e-04 - accuracy: 1.0000
# Epoch 55: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 1.7146e-04 - accuracy: 1.0000 - val_loss: 2.7179e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 56/500
# 29/33 [=========================>....] - ETA: 0s - loss: 1.7570e-04 - accuracy: 1.0000
# Epoch 56: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 15ms/step - loss: 1.9759e-04 - accuracy: 1.0000 - val_loss: 2.7175e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 57/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.6951e-04 - accuracy: 1.0000
# Epoch 57: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 1.7173e-04 - accuracy: 1.0000 - val_loss: 2.7173e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 58/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.8929e-04 - accuracy: 1.0000
# Epoch 58: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 1.8640e-04 - accuracy: 1.0000 - val_loss: 2.7172e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 59/500
# 29/33 [=========================>....] - ETA: 0s - loss: 1.6407e-04 - accuracy: 1.0000
# Epoch 59: val_loss improved from 0.00003 to 0.00003, saving model to lstm_8.h5
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 33/33 [==============================] - 0s 14ms/step - loss: 1.6126e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 60/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.8442e-04 - accuracy: 1.0000
# Epoch 60: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.7378e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 61/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.7151e-04 - accuracy: 1.0000
# Epoch 61: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.6887e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 62/500
# 29/33 [=========================>....] - ETA: 0s - loss: 3.0072e-04 - accuracy: 1.0000
# Epoch 62: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 2.8438e-04 - accuracy: 1.0000 - val_loss: 2.7166e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 63/500
# 28/33 [========================>.....] - ETA: 0s - loss: 2.0193e-04 - accuracy: 1.0000
# Epoch 63: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.9755e-04 - accuracy: 1.0000 - val_loss: 2.7166e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 64/500
# 28/33 [========================>.....] - ETA: 0s - loss: 2.2134e-04 - accuracy: 1.0000
# Epoch 64: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 2.0901e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 65/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.5967e-04 - accuracy: 1.0000
# Epoch 65: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.6417e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 66/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.5468e-04 - accuracy: 1.0000
# Epoch 66: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.5523e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 67/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.7319e-04 - accuracy: 1.0000
# Epoch 67: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.7767e-04 - accuracy: 1.0000 - val_loss: 2.7166e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 68/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.5496e-04 - accuracy: 1.0000
# Epoch 68: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 9ms/step - loss: 1.5429e-04 - accuracy: 1.0000 - val_loss: 2.7166e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 69/500
# 26/33 [======================>.......] - ETA: 0s - loss: 1.5910e-04 - accuracy: 1.0000
# Epoch 69: val_loss did not improve from 0.00003
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 33/33 [==============================] - 0s 11ms/step - loss: 1.6101e-04 - accuracy: 1.0000 - val_loss: 2.7166e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 70/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.7631e-04 - accuracy: 1.0000
# Epoch 70: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 13ms/step - loss: 1.8009e-04 - accuracy: 1.0000 - val_loss: 2.7166e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 71/500
# 26/33 [======================>.......] - ETA: 0s - loss: 1.5919e-04 - accuracy: 1.0000
# Epoch 71: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.6042e-04 - accuracy: 1.0000 - val_loss: 2.7166e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 72/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.9186e-04 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.8815e-04 - accuracy: 1.0000 - val_loss: 2.7166e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 73/500
# 29/33 [=========================>....] - ETA: 0s - loss: 1.6637e-04 - accuracy: 1.0000
# Epoch 73: val_loss did not improve from 0.00003
# 33/33 [==============================] - 1s 38ms/step - loss: 1.6768e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 74/500
# 29/33 [=========================>....] - ETA: 0s - loss: 1.7625e-04 - accuracy: 1.0000
# Epoch 74: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.7863e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 75/500
# 29/33 [=========================>....] - ETA: 0s - loss: 1.4766e-04 - accuracy: 1.0000
# Epoch 75: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.5139e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 76/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.5536e-04 - accuracy: 1.0000
# Epoch 76: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 12ms/step - loss: 1.5718e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 77/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.6716e-04 - accuracy: 1.0000
# Epoch 77: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.7168e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 78/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.8413e-04 - accuracy: 1.0000
# Epoch 78: val_loss did not improve from 0.00003
# 33/33 [==============================] - 1s 39ms/step - loss: 1.9546e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 79/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.5004e-04 - accuracy: 1.0000
# Epoch 79: val_loss did not improve from 0.00003
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 33/33 [==============================] - 0s 12ms/step - loss: 1.5113e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 80/500
# 27/33 [=======================>......] - ETA: 0s - loss: 2.2107e-04 - accuracy: 1.0000
# Epoch 80: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 2.1223e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 81/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.8990e-04 - accuracy: 1.0000
# Epoch 81: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.9210e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 82/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.7328e-04 - accuracy: 1.0000
# Epoch 82: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 12ms/step - loss: 1.7237e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 83/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.9060e-04 - accuracy: 1.0000
# Epoch 83: val_loss did not improve from 0.00003
# 33/33 [==============================] - 1s 37ms/step - loss: 1.8921e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 84/500
# 33/33 [==============================] - ETA: 0s - loss: 1.6945e-04 - accuracy: 1.0000
# Epoch 84: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.6945e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 85/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.5832e-04 - accuracy: 1.0000
# Epoch 85: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.6001e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 86/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.4916e-04 - accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.5273e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 87/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.8631e-04 - accuracy: 1.0000
# Epoch 87: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.8096e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 88/500
# 30/33 [==========================>...] - ETA: 0s - loss: 2.0424e-04 - accuracy: 1.0000
# Epoch 88: val_loss did not improve from 0.00003
# 33/33 [==============================] - 1s 40ms/step - loss: 1.9945e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 89/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.6144e-04 - accuracy: 1.0000
# Epoch 89: val_loss did not improve from 0.00003
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 33/33 [==============================] - 0s 10ms/step - loss: 1.6979e-04 - accuracy: 1.0000 - val_loss: 2.7165e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4393 - accuracy: 0.8125
# Test accuracy: 81.25%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('lstm_8.h5')

predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 5/5 [==============================] - 1s 5ms/step
# ([<matplotlib.axis.YTick at 0x7fd22858ba90>,
#   <matplotlib.axis.YTick at 0x7fd22858b430>,
#   <matplotlib.axis.YTick at 0x7fd22856eca0>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
