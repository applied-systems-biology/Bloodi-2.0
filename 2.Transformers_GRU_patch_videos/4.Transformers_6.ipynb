# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import numpy as np
import tensorflow as tf
from transformers import TFBertModel, BertTokenizer
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import imageio
import cv2 as cv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 2048
MAX_SEQ_LENGTH = 40
IMG_SIZE = 456

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==9)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1152, 40, 2048)
# (1152, 1)
# (144, 40, 2048)
# (144, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_6.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 2048)       81920
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 2048)       67162116
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 2048)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_2 (Dense)             (None, 3)                 6147
#
# =================================================================
# Total params: 67,250,183
# Trainable params: 67,250,183
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 29/33 [=========================>....] - ETA: 0s - loss: 1.3129 - accuracy: 0.6735
# Epoch 1: val_loss improved from inf to 0.12299, saving model to Transformer_6.h5
# 33/33 [==============================] - 12s 279ms/step - loss: 1.2379 - accuracy: 0.6824 - val_loss: 0.1230 - val_accuracy: 0.9397 - lr: 1.0000e-04
# Epoch 2/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.4004 - accuracy: 0.8481
# Epoch 2: val_loss improved from 0.12299 to 0.11844, saving model to Transformer_6.h5
# 33/33 [==============================] - 9s 287ms/step - loss: 0.3920 - accuracy: 0.8504 - val_loss: 0.1184 - val_accuracy: 0.9397 - lr: 1.0000e-04
# Epoch 3/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.2524 - accuracy: 0.9095
# Epoch 3: val_loss improved from 0.11844 to 0.10697, saving model to Transformer_6.h5
# 33/33 [==============================] - 9s 282ms/step - loss: 0.2499 - accuracy: 0.9083 - val_loss: 0.1070 - val_accuracy: 0.9483 - lr: 1.0000e-04
# Epoch 4/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.2198 - accuracy: 0.9310
# Epoch 4: val_loss improved from 0.10697 to 0.03109, saving model to Transformer_6.h5
# 33/33 [==============================] - 15s 477ms/step - loss: 0.2165 - accuracy: 0.9315 - val_loss: 0.0311 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 5/500
# 33/33 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9508
# Epoch 5: val_loss improved from 0.03109 to 0.01543, saving model to Transformer_6.h5
# 33/33 [==============================] - 13s 421ms/step - loss: 0.1465 - accuracy: 0.9508 - val_loss: 0.0154 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 6/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.1693 - accuracy: 0.9414
# Epoch 6: val_loss did not improve from 0.01543
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1674 - accuracy: 0.9421 - val_loss: 0.0485 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 7/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0555 - accuracy: 0.9763
# Epoch 7: val_loss improved from 0.01543 to 0.01108, saving model to Transformer_6.h5
# 33/33 [==============================] - 12s 382ms/step - loss: 0.0514 - accuracy: 0.9778 - val_loss: 0.0111 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 8/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0562 - accuracy: 0.9775
# Epoch 8: val_loss did not improve from 0.01108
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0555 - accuracy: 0.9778 - val_loss: 0.0200 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 9/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0143 - accuracy: 0.9970
# Epoch 9: val_loss did not improve from 0.01108
# 33/33 [==============================] - 1s 24ms/step - loss: 0.0138 - accuracy: 0.9971 - val_loss: 0.0311 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 10/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9932
# Epoch 10: val_loss did not improve from 0.01108
# 33/33 [==============================] - 1s 26ms/step - loss: 0.0220 - accuracy: 0.9932 - val_loss: 0.0244 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 11/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0756 - accuracy: 0.9717
# Epoch 11: val_loss did not improve from 0.01108
# 33/33 [==============================] - 1s 23ms/step - loss: 0.0756 - accuracy: 0.9710 - val_loss: 0.3631 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 12/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0788 - accuracy: 0.9688
# Epoch 12: val_loss did not improve from 0.01108
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0778 - accuracy: 0.9701 - val_loss: 0.1228 - val_accuracy: 0.9741 - lr: 1.0000e-04
# Epoch 13/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0362 - accuracy: 0.9875
# Epoch 13: val_loss did not improve from 0.01108
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0362 - accuracy: 0.9875 - val_loss: 0.0112 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 14/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9990
# Epoch 14: val_loss improved from 0.01108 to 0.00899, saving model to Transformer_6.h5
# 33/33 [==============================] - 15s 468ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0090 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 15/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 0.00899
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 16/500
# 29/33 [=========================>....] - ETA: 0s - loss: 9.8233e-04 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.00899
# 33/33 [==============================] - 1s 16ms/step - loss: 9.1116e-04 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 17/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0029 - accuracy: 0.9990
# Epoch 17: val_loss did not improve from 0.00899
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.0636 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 18/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.00899
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 19/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 19: val_loss improved from 0.00899 to 0.00546, saving model to Transformer_6.h5
# 33/33 [==============================] - 13s 420ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 20/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9990
# Epoch 20: val_loss improved from 0.00546 to 0.00508, saving model to Transformer_6.h5
# 33/33 [==============================] - 15s 468ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.0051 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 21/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9990
# Epoch 21: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0378 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 22/500
# 33/33 [==============================] - ETA: 0s - loss: 3.2813e-04 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 16ms/step - loss: 3.2813e-04 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 23/500
# 33/33 [==============================] - ETA: 0s - loss: 2.2116e-04 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 33/33 [==============================] - 1s 17ms/step - loss: 2.3020e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9914 - lr: 1.0000e-05
# Epoch 41/500
# 29/33 [=========================>....] - ETA: 0s - loss: 4.6470e-05 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 17ms/step - loss: 4.3160e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9914 - lr: 1.0000e-06
# Epoch 42/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.3965e-05 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 18ms/step - loss: 1.4128e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9914 - lr: 1.0000e-06
# Epoch 43/500
# 32/33 [============================>.] - ETA: 0s - loss: 4.7331e-05 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 20ms/step - loss: 4.6856e-05 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9914 - lr: 1.0000e-06
# Epoch 44/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.3460e-05 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 20ms/step - loss: 2.3190e-05 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9914 - lr: 1.0000e-06
# Epoch 45/500
# 33/33 [==============================] - ETA: 0s - loss: 3.1767e-05 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 23ms/step - loss: 3.1767e-05 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9914 - lr: 1.0000e-06
# Epoch 46/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.0896e-05 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 18ms/step - loss: 2.0230e-05 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9914 - lr: 1.0000e-06
# Epoch 47/500
# 31/33 [===========================>..] - ETA: 0s - loss: 4.5565e-05 - accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 18ms/step - loss: 4.5119e-05 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9914 - lr: 1.0000e-06
# Epoch 48/500
# 32/33 [============================>.] - ETA: 0s - loss: 4.6753e-05 - accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 21ms/step - loss: 4.6335e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9914 - lr: 1.0000e-06
# Epoch 49/500
# 33/33 [==============================] - ETA: 0s - loss: 1.8333e-05 - accuracy: 1.0000
# Epoch 49: val_loss did not improve from 0.00508
# 33/33 [==============================] - 1s 20ms/step - loss: 1.8333e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9914 - lr: 1.0000e-06
# Epoch 50/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.4089e-05 - accuracy: 1.0000
# Epoch 50: val_loss did not improve from 0.00508
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 33/33 [==============================] - 1s 18ms/step - loss: 1.5451e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9914 - lr: 1.0000e-06
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3242 - accuracy: 0.9167
# Test accuracy: 91.67%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_6.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 5/5 [==============================] - 1s 20ms/step
# ([<matplotlib.axis.YTick at 0x7f364c33dbb0>,
#   <matplotlib.axis.YTick at 0x7f364c33d9a0>,
#   <matplotlib.axis.YTick at 0x7f364c327a90>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
