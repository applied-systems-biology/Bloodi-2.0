# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 2048
MAX_SEQ_LENGTH = 40
IMG_SIZE = 456

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==10)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1152, 40, 2048)
# (1152, 1)
# (144, 40, 2048)
# (144, 1)

# %%
with strategy.scope():

    def get_compiled_model():
        
        frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))

        x = keras.layers.GRU(128, return_sequences=True)(frame_features_input)
        x = keras.layers.GRU(64)(x)
        x = keras.layers.Dropout(0.4)(x)
        x = keras.layers.Dense(64, activation="relu")(x)
        output = keras.layers.Dense(3, activation="softmax")(x)

        rnn_model = keras.Model(frame_features_input, output)

        rnn_model.compile(
            loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
        )
        
        rnn_model.summary()
        
        return rnn_model
    
with strategy.scope():
    
    def run_experiment():
        
        filepath = "lstm_7.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 40, 2048)]        0
#
#  gru (GRU)                   (None, 40, 128)           836352
#
#  gru_1 (GRU)                 (None, 64)                37248
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 877,955
# Trainable params: 877,955
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.5988 - accuracy: 0.7241
# Epoch 1: val_loss improved from inf to 0.10816, saving model to lstm_7.h5
# 33/33 [==============================] - 5s 30ms/step - loss: 0.5767 - accuracy: 0.7336 - val_loss: 0.1082 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 2/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.2503 - accuracy: 0.9030
# Epoch 2: val_loss did not improve from 0.10816
# 33/33 [==============================] - 0s 10ms/step - loss: 0.2464 - accuracy: 0.9035 - val_loss: 0.1325 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 3/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.1374 - accuracy: 0.9494
# Epoch 3: val_loss improved from 0.10816 to 0.03831, saving model to lstm_7.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1360 - accuracy: 0.9527 - val_loss: 0.0383 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 4/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.1122 - accuracy: 0.9634
# Epoch 4: val_loss improved from 0.03831 to 0.02143, saving model to lstm_7.h5
# 33/33 [==============================] - 0s 15ms/step - loss: 0.1138 - accuracy: 0.9624 - val_loss: 0.0214 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 5/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0645 - accuracy: 0.9806
# Epoch 5: val_loss improved from 0.02143 to 0.00166, saving model to lstm_7.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0596 - accuracy: 0.9826 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9749
# Epoch 6: val_loss did not improve from 0.00166
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0816 - accuracy: 0.9749 - val_loss: 0.0043 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/500
# 33/33 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9411
# Epoch 7: val_loss did not improve from 0.00166
# 33/33 [==============================] - 0s 10ms/step - loss: 0.1462 - accuracy: 0.9411 - val_loss: 0.0386 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 8/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9826
# Epoch 8: val_loss did not improve from 0.00166
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0496 - accuracy: 0.9826 - val_loss: 0.0087 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 9/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0818 - accuracy: 0.9730
# Epoch 9: val_loss did not improve from 0.00166
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0818 - accuracy: 0.9730 - val_loss: 0.0127 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 10/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9961
# Epoch 10: val_loss did not improve from 0.00166
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0156 - accuracy: 0.9961 - val_loss: 0.0022 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 11/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9981
# Epoch 11: val_loss did not improve from 0.00166
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0112 - accuracy: 0.9981 - val_loss: 0.0195 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 12/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0522 - accuracy: 0.9834
# Epoch 12: val_loss did not improve from 0.00166
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0524 - accuracy: 0.9836 - val_loss: 0.0370 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 13/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9884
# Epoch 13: val_loss did not improve from 0.00166
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0348 - accuracy: 0.9884 - val_loss: 0.0020 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 14/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0042 - accuracy: 0.9990
# Epoch 14: val_loss improved from 0.00166 to 0.00106, saving model to lstm_7.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 15/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 0.00106
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/500
# 32/33 [============================>.] - ETA: 0s - loss: 9.1872e-04 - accuracy: 1.0000
# Epoch 16: val_loss improved from 0.00106 to 0.00048, saving model to lstm_7.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 9.1209e-04 - accuracy: 1.0000 - val_loss: 4.7840e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/500
# 30/33 [==========================>...] - ETA: 0s - loss: 8.2431e-04 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 8.1776e-04 - accuracy: 1.0000 - val_loss: 5.3585e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/500
# 31/33 [===========================>..] - ETA: 0s - loss: 7.2880e-04 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 9ms/step - loss: 7.1444e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/500
# 30/33 [==========================>...] - ETA: 0s - loss: 6.4978e-04 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 6.8949e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/500
# 30/33 [==========================>...] - ETA: 0s - loss: 6.2949e-04 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 6.2412e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 21/500
# 32/33 [============================>.] - ETA: 0s - loss: 4.9947e-04 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 4.9680e-04 - accuracy: 1.0000 - val_loss: 6.9558e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 22/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.6787e-04 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 3.6780e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 23/500
# 33/33 [==============================] - ETA: 0s - loss: 3.6677e-04 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 3.6677e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/500
# 33/33 [==============================] - ETA: 0s - loss: 3.1737e-04 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 9ms/step - loss: 3.1737e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 25/500
# 33/33 [==============================] - ETA: 0s - loss: 2.7949e-04 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 9ms/step - loss: 2.7949e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 26/500
# 33/33 [==============================] - ETA: 0s - loss: 2.8874e-04 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.00048
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 33/33 [==============================] - 0s 9ms/step - loss: 2.8874e-04 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 27/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.8777e-04 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 2.7995e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 28/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.5071e-04 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 2.5301e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 29/500
# 33/33 [==============================] - ETA: 0s - loss: 3.0499e-04 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 9ms/step - loss: 3.0499e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 30/500
# 33/33 [==============================] - ETA: 0s - loss: 2.8057e-04 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 2.8057e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 31/500
# 33/33 [==============================] - ETA: 0s - loss: 2.9468e-04 - accuracy: 1.0000
# Epoch 31: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 9ms/step - loss: 2.9468e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 32/500
# 33/33 [==============================] - ETA: 0s - loss: 2.7469e-04 - accuracy: 1.0000
# Epoch 32: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 2.7469e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 33/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.6073e-04 - accuracy: 1.0000
# Epoch 33: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 2.6059e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 34/500
# 33/33 [==============================] - ETA: 0s - loss: 3.0350e-04 - accuracy: 1.0000
# Epoch 34: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 12ms/step - loss: 3.0350e-04 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 35/500
# 33/33 [==============================] - ETA: 0s - loss: 2.9904e-04 - accuracy: 1.0000
# Epoch 35: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 11ms/step - loss: 2.9904e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 36/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.4265e-04 - accuracy: 1.0000
# Epoch 36: val_loss did not improve from 0.00048
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 33/33 [==============================] - 0s 10ms/step - loss: 2.3924e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 37/500
# 33/33 [==============================] - ETA: 0s - loss: 2.5441e-04 - accuracy: 1.0000
# Epoch 37: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 11ms/step - loss: 2.5441e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 38/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.5529e-04 - accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 2.6118e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 39/500
# 30/33 [==========================>...] - ETA: 0s - loss: 2.4200e-04 - accuracy: 1.0000
# Epoch 39: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 10ms/step - loss: 2.3563e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 40/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.3068e-04 - accuracy: 1.0000
# Epoch 40: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 11ms/step - loss: 2.3005e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 41/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2991e-04 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 12ms/step - loss: 2.3219e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 42/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4188e-04 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 11ms/step - loss: 2.4335e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 43/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.5856e-04 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 13ms/step - loss: 2.6083e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 44/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.2779e-04 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 14ms/step - loss: 2.2913e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 45/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.7837e-04 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.00048
# 33/33 [==============================] - 0s 13ms/step - loss: 2.8761e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 46/500
# 30/33 [==========================>...] - ETA: 0s - loss: 2.6357e-04 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.00048
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 33/33 [==============================] - 0s 12ms/step - loss: 2.5478e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000 - lr: 1.0000e-05
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2796 - accuracy: 0.9444
# Test accuracy: 94.44%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('lstm_7.h5')

predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 5/5 [==============================] - 0s 4ms/step
# ([<matplotlib.axis.YTick at 0x7fe5c40e1d60>,
#   <matplotlib.axis.YTick at 0x7fe5c41002e0>,
#   <matplotlib.axis.YTick at 0x7fe5c40e1b50>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
