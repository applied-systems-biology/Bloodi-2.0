# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="2"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 2048
MAX_SEQ_LENGTH = 40
IMG_SIZE = 456

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==9)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1152, 40, 2048)
# (1152, 1)
# (144, 40, 2048)
# (144, 1)

# %%
with strategy.scope():

    def get_compiled_model():
        
        frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))

        x = keras.layers.GRU(128, return_sequences=True)(frame_features_input)
        x = keras.layers.GRU(64)(x)
        x = keras.layers.Dropout(0.4)(x)
        x = keras.layers.Dense(64, activation="relu")(x)
        output = keras.layers.Dense(3, activation="softmax")(x)

        rnn_model = keras.Model(frame_features_input, output)

        rnn_model.compile(
            loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
        )
        
        rnn_model.summary()
        
        return rnn_model
    
with strategy.scope():
    
    def run_experiment():
        
        filepath = "lstm_6.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 40, 2048)]        0
#
#  gru (GRU)                   (None, 40, 128)           836352
#
#  gru_1 (GRU)                 (None, 64)                37248
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 877,955
# Trainable params: 877,955
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.6137 - accuracy: 0.7061
# Epoch 1: val_loss improved from inf to 0.18126, saving model to lstm_6.h5
# 33/33 [==============================] - 5s 29ms/step - loss: 0.6100 - accuracy: 0.7085 - val_loss: 0.1813 - val_accuracy: 0.9224 - lr: 0.0010
# Epoch 2/500
# 33/33 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.8977
# Epoch 2: val_loss improved from 0.18126 to 0.04031, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 0.2471 - accuracy: 0.8977 - val_loss: 0.0403 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 3/500
# 33/33 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9546
# Epoch 3: val_loss improved from 0.04031 to 0.02794, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 0.1364 - accuracy: 0.9546 - val_loss: 0.0279 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 0.9653
# Epoch 4: val_loss did not improve from 0.02794
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0999 - accuracy: 0.9653 - val_loss: 0.0501 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 5/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.1668 - accuracy: 0.9345
# Epoch 5: val_loss improved from 0.02794 to 0.00797, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1653 - accuracy: 0.9344 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9720
# Epoch 6: val_loss did not improve from 0.00797
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0770 - accuracy: 0.9720 - val_loss: 0.0179 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9768
# Epoch 7: val_loss did not improve from 0.00797
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0595 - accuracy: 0.9768 - val_loss: 0.0374 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 8/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9942
# Epoch 8: val_loss did not improve from 0.00797
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0198 - accuracy: 0.9942 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 9/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9961
# Epoch 9: val_loss did not improve from 0.00797
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0186 - accuracy: 0.9961 - val_loss: 0.0251 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 10/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9720
# Epoch 10: val_loss did not improve from 0.00797
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0831 - accuracy: 0.9720 - val_loss: 0.0085 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 11/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0833 - accuracy: 0.9729
# Epoch 11: val_loss did not improve from 0.00797
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0806 - accuracy: 0.9739 - val_loss: 0.0332 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 12/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0368 - accuracy: 0.9883
# Epoch 12: val_loss improved from 0.00797 to 0.00465, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0364 - accuracy: 0.9884 - val_loss: 0.0047 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 13/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 13: val_loss improved from 0.00465 to 0.00080, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 8.0385e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 14/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 14: val_loss improved from 0.00080 to 0.00039, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.9483e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 15/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.00039 to 0.00026, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.5581e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 16: val_loss improved from 0.00026 to 0.00023, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.2962e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/500
# 29/33 [=========================>....] - ETA: 0s - loss: 9.7078e-04 - accuracy: 1.0000
# Epoch 17: val_loss improved from 0.00023 to 0.00016, saving model to lstm_6.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 9.2199e-04 - accuracy: 1.0000 - val_loss: 1.6232e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/500
# 28/33 [========================>.....] - ETA: 0s - loss: 6.7939e-04 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.00016 to 0.00014, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 6.8456e-04 - accuracy: 1.0000 - val_loss: 1.3584e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/500
# 28/33 [========================>.....] - ETA: 0s - loss: 7.3327e-04 - accuracy: 1.0000
# Epoch 19: val_loss improved from 0.00014 to 0.00011, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 7.0744e-04 - accuracy: 1.0000 - val_loss: 1.1239e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/500
# 28/33 [========================>.....] - ETA: 0s - loss: 5.1075e-04 - accuracy: 1.0000
# Epoch 20: val_loss improved from 0.00011 to 0.00010, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 15ms/step - loss: 4.9232e-04 - accuracy: 1.0000 - val_loss: 9.8171e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 21/500
# 31/33 [===========================>..] - ETA: 0s - loss: 5.2805e-04 - accuracy: 1.0000
# Epoch 21: val_loss improved from 0.00010 to 0.00009, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 5.3491e-04 - accuracy: 1.0000 - val_loss: 8.6767e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 22/500
# 28/33 [========================>.....] - ETA: 0s - loss: 4.5521e-04 - accuracy: 1.0000
# Epoch 22: val_loss improved from 0.00009 to 0.00007, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 4.6170e-04 - accuracy: 1.0000 - val_loss: 7.4547e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 23/500
# 30/33 [==========================>...] - ETA: 0s - loss: 4.3206e-04 - accuracy: 1.0000
# Epoch 23: val_loss improved from 0.00007 to 0.00007, saving model to lstm_6.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 4.4613e-04 - accuracy: 1.0000 - val_loss: 6.5351e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/500
# 28/33 [========================>.....] - ETA: 0s - loss: 4.0782e-04 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.00007 to 0.00006, saving model to lstm_6.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 3.8494e-04 - accuracy: 1.0000 - val_loss: 5.8393e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 25/500
# 29/33 [=========================>....] - ETA: 0s - loss: 3.3952e-04 - accuracy: 1.0000
# Epoch 25: val_loss improved from 0.00006 to 0.00005, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 3.4132e-04 - accuracy: 1.0000 - val_loss: 5.3771e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 26/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.1262e-04 - accuracy: 1.0000
# Epoch 26: val_loss improved from 0.00005 to 0.00005, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 3.0990e-04 - accuracy: 1.0000 - val_loss: 4.8708e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 27/500
# 28/33 [========================>.....] - ETA: 0s - loss: 2.8536e-04 - accuracy: 1.0000
# Epoch 27: val_loss improved from 0.00005 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.7823e-04 - accuracy: 1.0000 - val_loss: 4.4176e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 28/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.4412e-04 - accuracy: 1.0000
# Epoch 28: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 33/33 [==============================] - 0s 14ms/step - loss: 2.5762e-04 - accuracy: 1.0000 - val_loss: 4.0201e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 29/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.5289e-04 - accuracy: 1.0000
# Epoch 29: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.5311e-04 - accuracy: 1.0000 - val_loss: 3.9826e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 30/500
# 33/33 [==============================] - ETA: 0s - loss: 2.5278e-04 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 2.5278e-04 - accuracy: 1.0000 - val_loss: 3.9533e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 31/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.3293e-04 - accuracy: 1.0000
# Epoch 31: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.3156e-04 - accuracy: 1.0000 - val_loss: 3.9251e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 32/500
# 30/33 [==========================>...] - ETA: 0s - loss: 2.3393e-04 - accuracy: 1.0000
# Epoch 32: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.2946e-04 - accuracy: 1.0000 - val_loss: 3.8983e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 33/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2868e-04 - accuracy: 1.0000
# Epoch 33: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.2530e-04 - accuracy: 1.0000 - val_loss: 3.8670e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 34/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.2443e-04 - accuracy: 1.0000
# Epoch 34: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.2543e-04 - accuracy: 1.0000 - val_loss: 3.8309e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 35/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4790e-04 - accuracy: 1.0000
# Epoch 35: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.5149e-04 - accuracy: 1.0000 - val_loss: 3.7940e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 36/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.0215e-04 - accuracy: 1.0000
# Epoch 36: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 3.0019e-04 - accuracy: 1.0000 - val_loss: 3.7568e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 37/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.2820e-04 - accuracy: 1.0000
# Epoch 37: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 2.2976e-04 - accuracy: 1.0000 - val_loss: 3.7223e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 38/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.4039e-04 - accuracy: 1.0000
# Epoch 38: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 33/33 [==============================] - 0s 14ms/step - loss: 2.3750e-04 - accuracy: 1.0000 - val_loss: 3.6893e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 39/500
# 30/33 [==========================>...] - ETA: 0s - loss: 2.2781e-04 - accuracy: 1.0000
# Epoch 39: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.2636e-04 - accuracy: 1.0000 - val_loss: 3.6844e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 40/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3196e-04 - accuracy: 1.0000
# Epoch 40: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.3495e-04 - accuracy: 1.0000 - val_loss: 3.6802e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 41/500
# 30/33 [==========================>...] - ETA: 0s - loss: 2.1209e-04 - accuracy: 1.0000
# Epoch 41: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.2587e-04 - accuracy: 1.0000 - val_loss: 3.6757e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 42/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.9412e-04 - accuracy: 1.0000
# Epoch 42: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 3.2240e-04 - accuracy: 1.0000 - val_loss: 3.6683e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 43/500
# 33/33 [==============================] - ETA: 0s - loss: 1.9327e-04 - accuracy: 1.0000
# Epoch 43: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 1.9327e-04 - accuracy: 1.0000 - val_loss: 3.6657e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 44/500
# 33/33 [==============================] - ETA: 0s - loss: 2.5136e-04 - accuracy: 1.0000
# Epoch 44: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 2.5136e-04 - accuracy: 1.0000 - val_loss: 3.6618e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 45/500
# 33/33 [==============================] - ETA: 0s - loss: 2.4103e-04 - accuracy: 1.0000
# Epoch 45: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 2.4103e-04 - accuracy: 1.0000 - val_loss: 3.6582e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 46/500
# 33/33 [==============================] - ETA: 0s - loss: 2.2341e-04 - accuracy: 1.0000
# Epoch 46: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 2.2341e-04 - accuracy: 1.0000 - val_loss: 3.6549e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 47/500
# 30/33 [==========================>...] - ETA: 0s - loss: 2.5031e-04 - accuracy: 1.0000
# Epoch 47: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.5718e-04 - accuracy: 1.0000 - val_loss: 3.6512e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 48/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.9870e-04 - accuracy: 1.0000
# Epoch 48: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 33/33 [==============================] - 0s 14ms/step - loss: 1.9753e-04 - accuracy: 1.0000 - val_loss: 3.6470e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 49/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.8524e-04 - accuracy: 1.0000
# Epoch 49: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 1.8350e-04 - accuracy: 1.0000 - val_loss: 3.6469e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 50/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.7732e-04 - accuracy: 1.0000
# Epoch 50: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 2.7504e-04 - accuracy: 1.0000 - val_loss: 3.6464e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 51/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.0616e-04 - accuracy: 1.0000
# Epoch 51: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 2.0574e-04 - accuracy: 1.0000 - val_loss: 3.6456e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 52/500
# 33/33 [==============================] - ETA: 0s - loss: 2.3323e-04 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 15ms/step - loss: 2.3323e-04 - accuracy: 1.0000 - val_loss: 3.6456e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 53/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2019e-04 - accuracy: 1.0000
# Epoch 53: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 10ms/step - loss: 2.2144e-04 - accuracy: 1.0000 - val_loss: 3.6458e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 54/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.1819e-04 - accuracy: 1.0000
# Epoch 54: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 15ms/step - loss: 2.1592e-04 - accuracy: 1.0000 - val_loss: 3.6447e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 55/500
# 25/33 [=====================>........] - ETA: 0s - loss: 2.4278e-04 - accuracy: 1.0000
# Epoch 55: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 2.5255e-04 - accuracy: 1.0000 - val_loss: 3.6440e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 56/500
# 27/33 [=======================>......] - ETA: 0s - loss: 2.3301e-04 - accuracy: 1.0000
# Epoch 56: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 2.3400e-04 - accuracy: 1.0000 - val_loss: 3.6432e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 57/500
# 26/33 [======================>.......] - ETA: 0s - loss: 2.3582e-04 - accuracy: 1.0000
# Epoch 57: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5061e-04 - accuracy: 1.0000 - val_loss: 3.6432e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 58/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4554e-04 - accuracy: 1.0000
# Epoch 58: val_loss improved from 0.00004 to 0.00004, saving model to lstm_6.h5
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 33/33 [==============================] - 0s 13ms/step - loss: 2.4097e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 59/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.0742e-04 - accuracy: 1.0000
# Epoch 59: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 10ms/step - loss: 2.0742e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 60/500
# 26/33 [======================>.......] - ETA: 0s - loss: 2.3988e-04 - accuracy: 1.0000
# Epoch 60: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.3056e-04 - accuracy: 1.0000 - val_loss: 3.6430e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 61/500
# 26/33 [======================>.......] - ETA: 0s - loss: 2.0427e-04 - accuracy: 1.0000
# Epoch 61: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0746e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 62/500
# 28/33 [========================>.....] - ETA: 0s - loss: 2.6744e-04 - accuracy: 1.0000
# Epoch 62: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 10ms/step - loss: 2.7285e-04 - accuracy: 1.0000 - val_loss: 3.6431e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 63/500
# 28/33 [========================>.....] - ETA: 0s - loss: 2.0571e-04 - accuracy: 1.0000
# Epoch 63: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 1.9952e-04 - accuracy: 1.0000 - val_loss: 3.6430e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 64/500
# 33/33 [==============================] - ETA: 0s - loss: 2.3984e-04 - accuracy: 1.0000
# Epoch 64: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.3984e-04 - accuracy: 1.0000 - val_loss: 3.6430e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 65/500
# 26/33 [======================>.......] - ETA: 0s - loss: 2.1585e-04 - accuracy: 1.0000
# Epoch 65: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1611e-04 - accuracy: 1.0000 - val_loss: 3.6431e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 66/500
# 25/33 [=====================>........] - ETA: 0s - loss: 2.2460e-04 - accuracy: 1.0000
# Epoch 66: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4329e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 67/500
# 26/33 [======================>.......] - ETA: 0s - loss: 1.7580e-04 - accuracy: 1.0000
# Epoch 67: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 1.7537e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 68/500
# 33/33 [==============================] - ETA: 0s - loss: 2.1683e-04 - accuracy: 1.0000
# Epoch 68: val_loss did not improve from 0.00004
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 33/33 [==============================] - 0s 10ms/step - loss: 2.1683e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# Epoch 69/500
# 33/33 [==============================] - ETA: 0s - loss: 2.3424e-04 - accuracy: 1.0000
# Epoch 69: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.3424e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 70/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.2359e-04 - accuracy: 1.0000
# Epoch 70: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 10ms/step - loss: 2.2276e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 71/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.1143e-04 - accuracy: 1.0000
# Epoch 71: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 10ms/step - loss: 2.1034e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 72/500
# 33/33 [==============================] - ETA: 0s - loss: 2.5049e-04 - accuracy: 1.0000
# Epoch 72: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5049e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 73/500
# 33/33 [==============================] - ETA: 0s - loss: 2.0998e-04 - accuracy: 1.0000
# Epoch 73: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 11ms/step - loss: 2.0998e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 74/500
# 28/33 [========================>.....] - ETA: 0s - loss: 2.4972e-04 - accuracy: 1.0000
# Epoch 74: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 11ms/step - loss: 2.6311e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 75/500
# 30/33 [==========================>...] - ETA: 0s - loss: 2.5591e-04 - accuracy: 1.0000
# Epoch 75: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 10ms/step - loss: 2.5569e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 76/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.6749e-04 - accuracy: 1.0000
# Epoch 76: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 11ms/step - loss: 1.8220e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 77/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.2322e-04 - accuracy: 1.0000
# Epoch 77: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 11ms/step - loss: 2.2278e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 78/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.8417e-04 - accuracy: 1.0000
# Epoch 78: val_loss did not improve from 0.00004
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 33/33 [==============================] - 0s 9ms/step - loss: 1.8569e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-08
# Epoch 79/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.9917e-04 - accuracy: 1.0000
# Epoch 79: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 11ms/step - loss: 1.9967e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 80/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.8430e-04 - accuracy: 1.0000
# Epoch 80: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 11ms/step - loss: 1.8538e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 81/500
# 30/33 [==========================>...] - ETA: 0s - loss: 2.2083e-04 - accuracy: 1.0000
# Epoch 81: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 10ms/step - loss: 2.2080e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 82/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.1151e-04 - accuracy: 1.0000
# Epoch 82: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 10ms/step - loss: 2.1285e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 83/500
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2441e-04 - accuracy: 1.0000
# Epoch 83: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 10ms/step - loss: 2.2643e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 84/500
# 25/33 [=====================>........] - ETA: 0s - loss: 2.0625e-04 - accuracy: 1.0000
# Epoch 84: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0638e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 85/500
# 33/33 [==============================] - ETA: 0s - loss: 2.1124e-04 - accuracy: 1.0000
# Epoch 85: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1124e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 86/500
# 27/33 [=======================>......] - ETA: 0s - loss: 2.1524e-04 - accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0655e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 87/500
# 33/33 [==============================] - ETA: 0s - loss: 2.0973e-04 - accuracy: 1.0000
# Epoch 87: val_loss did not improve from 0.00004
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0973e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# Epoch 88/500
# 29/33 [=========================>....] - ETA: 0s - loss: 2.3077e-04 - accuracy: 1.0000
# Epoch 88: val_loss did not improve from 0.00004
#
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 33/33 [==============================] - 0s 10ms/step - loss: 2.2732e-04 - accuracy: 1.0000 - val_loss: 3.6429e-05 - val_accuracy: 1.0000 - lr: 1.0000e-09
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4608 - accuracy: 0.9236
# Test accuracy: 92.36%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('lstm_6.h5')

predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 5/5 [==============================] - 0s 4ms/step
# ([<matplotlib.axis.YTick at 0x7f90e8042b80>,
#   <matplotlib.axis.YTick at 0x7f90e8042520>,
#   <matplotlib.axis.YTick at 0x7f90e8022d90>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
