# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import imageio
import cv2 as cv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="6"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 2048
MAX_SEQ_LENGTH = 40
IMG_SIZE = 456

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==1)]
test
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1152, 40, 2048)
# (1152, 1)
# (144, 40, 2048)
# (144, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_1.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 2048)       81920
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 2048)       67162116
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 2048)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_2 (Dense)             (None, 3)                 6147
#
# =================================================================
# Total params: 67,250,183
# Trainable params: 67,250,183
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.8748 - accuracy: 0.7480
# Epoch 1: val_loss improved from inf to 0.05843, saving model to Transformer_1.h5
# 33/33 [==============================] - 13s 341ms/step - loss: 0.8670 - accuracy: 0.7500 - val_loss: 0.0584 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 2/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.2289 - accuracy: 0.9141
# Epoch 2: val_loss did not improve from 0.05843
# 33/33 [==============================] - 2s 55ms/step - loss: 0.2268 - accuracy: 0.9151 - val_loss: 0.0624 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 3/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.1708 - accuracy: 0.9434
# Epoch 3: val_loss improved from 0.05843 to 0.03753, saving model to Transformer_1.h5
# 33/33 [==============================] - 11s 334ms/step - loss: 0.1712 - accuracy: 0.9421 - val_loss: 0.0375 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 4/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.2381 - accuracy: 0.9248
# Epoch 4: val_loss did not improve from 0.03753
# 33/33 [==============================] - 2s 56ms/step - loss: 0.2364 - accuracy: 0.9247 - val_loss: 0.5436 - val_accuracy: 0.8534 - lr: 1.0000e-04
# Epoch 5/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.1429 - accuracy: 0.9492
# Epoch 5: val_loss improved from 0.03753 to 0.02396, saving model to Transformer_1.h5
# 33/33 [==============================] - 11s 327ms/step - loss: 0.1413 - accuracy: 0.9498 - val_loss: 0.0240 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 6/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0616 - accuracy: 0.9756
# Epoch 6: val_loss did not improve from 0.02396
# 33/33 [==============================] - 2s 54ms/step - loss: 0.0609 - accuracy: 0.9759 - val_loss: 0.0303 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 7/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0256 - accuracy: 0.9893
# Epoch 7: val_loss improved from 0.02396 to 0.00768, saving model to Transformer_1.h5
# 33/33 [==============================] - 10s 324ms/step - loss: 0.0269 - accuracy: 0.9884 - val_loss: 0.0077 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 8/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 0.9932
# Epoch 8: val_loss did not improve from 0.00768
# 33/33 [==============================] - 2s 57ms/step - loss: 0.0262 - accuracy: 0.9923 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 9/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.1014 - accuracy: 0.9658
# Epoch 9: val_loss did not improve from 0.00768
# 33/33 [==============================] - 2s 56ms/step - loss: 0.1002 - accuracy: 0.9662 - val_loss: 0.1088 - val_accuracy: 0.9483 - lr: 1.0000e-04
# Epoch 10/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0328 - accuracy: 0.9873
# Epoch 10: val_loss improved from 0.00768 to 0.00490, saving model to Transformer_1.h5
# 33/33 [==============================] - 11s 329ms/step - loss: 0.0324 - accuracy: 0.9875 - val_loss: 0.0049 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 11/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9971
# Epoch 11: val_loss improved from 0.00490 to 0.00385, saving model to Transformer_1.h5
# 33/33 [==============================] - 10s 323ms/step - loss: 0.0074 - accuracy: 0.9971 - val_loss: 0.0039 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 12/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9990
# Epoch 12: val_loss did not improve from 0.00385
# 33/33 [==============================] - 2s 56ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0155 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 13/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 13: val_loss did not improve from 0.00385
# 33/33 [==============================] - 2s 57ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 14/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0133 - accuracy: 0.9961
# Epoch 14: val_loss did not improve from 0.00385
# 33/33 [==============================] - 2s 55ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.0050 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 15/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.9990
# Epoch 15: val_loss improved from 0.00385 to 0.00095, saving model to Transformer_1.h5
# 33/33 [==============================] - 11s 331ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 9.4677e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 16/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0269 - accuracy: 0.9932
# Epoch 16: val_loss did not improve from 0.00095
# 33/33 [==============================] - 2s 54ms/step - loss: 0.0268 - accuracy: 0.9932 - val_loss: 0.2207 - val_accuracy: 0.9397 - lr: 1.0000e-04
# Epoch 17/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0509 - accuracy: 0.9824
# Epoch 17: val_loss did not improve from 0.00095
# 33/33 [==============================] - 2s 54ms/step - loss: 0.0504 - accuracy: 0.9826 - val_loss: 0.0058 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 18/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0074 - accuracy: 0.9951
# Epoch 18: val_loss did not improve from 0.00095
# 33/33 [==============================] - 2s 55ms/step - loss: 0.0074 - accuracy: 0.9952 - val_loss: 0.0047 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 19/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0159 - accuracy: 0.9951
# Epoch 19: val_loss improved from 0.00095 to 0.00040, saving model to Transformer_1.h5
# 33/33 [==============================] - 11s 332ms/step - loss: 0.0157 - accuracy: 0.9952 - val_loss: 3.9608e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 20/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9990
# Epoch 20: val_loss did not improve from 0.00040
# 33/33 [==============================] - 2s 56ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 21/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0026 - accuracy: 0.9980
# Epoch 21: val_loss improved from 0.00040 to 0.00036, saving model to Transformer_1.h5
# 33/33 [==============================] - 10s 320ms/step - loss: 0.0027 - accuracy: 0.9981 - val_loss: 3.6397e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 22/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.7832e-04 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.00036
# 33/33 [==============================] - 2s 56ms/step - loss: 3.7399e-04 - accuracy: 1.0000 - val_loss: 6.9866e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 23/500
# 32/33 [============================>.] - ETA: 0s - loss: 4.5209e-04 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.00036
# 33/33 [==============================] - 2s 55ms/step - loss: 4.4699e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 24/500
# 32/33 [============================>.] - ETA: 0s - loss: 6.9595e-04 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.00036 to 0.00025, saving model to Transformer_1.h5
# 33/33 [==============================] - 10s 324ms/step - loss: 6.8793e-04 - accuracy: 1.0000 - val_loss: 2.5030e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 25/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.2049e-04 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 3.1679e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 26/500
# 32/33 [============================>.] - ETA: 0s - loss: 5.1852e-05 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 56ms/step - loss: 5.1734e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 27/500
# 32/33 [============================>.] - ETA: 0s - loss: 9.0917e-05 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 57ms/step - loss: 8.9915e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 28/500
# 32/33 [============================>.] - ETA: 0s - loss: 9.2909e-05 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 9.2031e-05 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 29/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.0631e-04 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 1.0513e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 30/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.3280e-04 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 54ms/step - loss: 2.3020e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 31/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.1036e-04 - accuracy: 1.0000
# Epoch 31: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 54ms/step - loss: 2.0794e-04 - accuracy: 1.0000 - val_loss: 2.8722e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 32/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.4514e-04 - accuracy: 1.0000
# Epoch 32: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 54ms/step - loss: 1.4550e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 33/500
# 32/33 [============================>.] - ETA: 0s - loss: 9.3934e-05 - accuracy: 1.0000
# Epoch 33: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 54ms/step - loss: 9.2934e-05 - accuracy: 1.0000 - val_loss: 8.4447e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 34/500
# 32/33 [============================>.] - ETA: 0s - loss: 6.1290e-05 - accuracy: 1.0000
# Epoch 34: val_loss did not improve from 0.00025
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 33/33 [==============================] - 2s 55ms/step - loss: 6.0587e-05 - accuracy: 1.0000 - val_loss: 7.7052e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 35/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.8904e-05 - accuracy: 1.0000
# Epoch 35: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 2.8590e-05 - accuracy: 1.0000 - val_loss: 7.8405e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 36/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.6998e-05 - accuracy: 1.0000
# Epoch 36: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 54ms/step - loss: 3.7193e-05 - accuracy: 1.0000 - val_loss: 8.1988e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 37/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.0189e-04 - accuracy: 1.0000
# Epoch 37: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 1.0075e-04 - accuracy: 1.0000 - val_loss: 8.8681e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 38/500
# 32/33 [============================>.] - ETA: 0s - loss: 6.9939e-05 - accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 54ms/step - loss: 6.9165e-05 - accuracy: 1.0000 - val_loss: 9.9595e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 39/500
# 32/33 [============================>.] - ETA: 0s - loss: 4.7978e-05 - accuracy: 1.0000
# Epoch 39: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 4.7504e-05 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 40/500
# 32/33 [============================>.] - ETA: 0s - loss: 4.4973e-05 - accuracy: 1.0000
# Epoch 40: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 4.4473e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 41/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.2695e-05 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 54ms/step - loss: 2.3743e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 42/500
# 32/33 [============================>.] - ETA: 0s - loss: 6.2660e-05 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 56ms/step - loss: 6.5380e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 43/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.4772e-05 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 56ms/step - loss: 3.5128e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 44/500
# 32/33 [============================>.] - ETA: 0s - loss: 6.7237e-05 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.00025
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 33/33 [==============================] - 2s 55ms/step - loss: 6.6477e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 45/500
# 32/33 [============================>.] - ETA: 0s - loss: 8.3848e-05 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 8.2879e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 46/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.2629e-04 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 1.2504e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 47/500
# 32/33 [============================>.] - ETA: 0s - loss: 9.6866e-05 - accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 9.6964e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 48/500
# 32/33 [============================>.] - ETA: 0s - loss: 6.9167e-05 - accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 54ms/step - loss: 6.8944e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 49/500
# 32/33 [============================>.] - ETA: 0s - loss: 8.3238e-05 - accuracy: 1.0000
# Epoch 49: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 8.2775e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 50/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.3613e-05 - accuracy: 1.0000
# Epoch 50: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 3.3375e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 51/500
# 32/33 [============================>.] - ETA: 0s - loss: 4.8932e-05 - accuracy: 1.0000
# Epoch 51: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 54ms/step - loss: 4.8371e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 52/500
# 32/33 [============================>.] - ETA: 0s - loss: 6.7233e-05 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 54ms/step - loss: 6.6465e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 53/500
# 32/33 [============================>.] - ETA: 0s - loss: 5.3012e-05 - accuracy: 1.0000
# Epoch 53: val_loss did not improve from 0.00025
# 33/33 [==============================] - 2s 55ms/step - loss: 6.2652e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 54/500
# 32/33 [============================>.] - ETA: 0s - loss: 7.3685e-05 - accuracy: 1.0000
# Epoch 54: val_loss did not improve from 0.00025
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 33/33 [==============================] - 2s 55ms/step - loss: 7.2919e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# 5/5 [==============================] - 0s 17ms/step - loss: 4.0597 - accuracy: 0.6111
# Test accuracy: 61.11%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_1.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 5/5 [==============================] - 0s 19ms/step
# ([<matplotlib.axis.YTick at 0x7f538c2c2dc0>,
#   <matplotlib.axis.YTick at 0x7f538c2c2760>,
#   <matplotlib.axis.YTick at 0x7f538c37fd30>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
