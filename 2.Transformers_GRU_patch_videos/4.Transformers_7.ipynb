# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import numpy as np
import tensorflow as tf
from transformers import TFBertModel, BertTokenizer
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import imageio
import cv2 as cv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="5"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 2048
MAX_SEQ_LENGTH = 40
IMG_SIZE = 456

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==10)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1152, 40, 2048)
# (1152, 1)
# (144, 40, 2048)
# (144, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_7.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 2048)       81920
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 2048)       67162116
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 2048)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_2 (Dense)             (None, 3)                 6147
#
# =================================================================
# Total params: 67,250,183
# Trainable params: 67,250,183
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.4886 - accuracy: 0.6416
# Epoch 1: val_loss improved from inf to 0.31731, saving model to Transformer_7.h5
# 33/33 [==============================] - 14s 370ms/step - loss: 1.4746 - accuracy: 0.6438 - val_loss: 0.3173 - val_accuracy: 0.9138 - lr: 1.0000e-04
# Epoch 2/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.6263 - accuracy: 0.8066
# Epoch 2: val_loss improved from 0.31731 to 0.08344, saving model to Transformer_7.h5
# 33/33 [==============================] - 14s 435ms/step - loss: 0.6230 - accuracy: 0.8069 - val_loss: 0.0834 - val_accuracy: 0.9741 - lr: 1.0000e-04
# Epoch 3/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.2304 - accuracy: 0.9102
# Epoch 3: val_loss improved from 0.08344 to 0.04049, saving model to Transformer_7.h5
# 33/33 [==============================] - 14s 441ms/step - loss: 0.2287 - accuracy: 0.9112 - val_loss: 0.0405 - val_accuracy: 0.9741 - lr: 1.0000e-04
# Epoch 4/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.1892 - accuracy: 0.9297
# Epoch 4: val_loss improved from 0.04049 to 0.03517, saving model to Transformer_7.h5
# 33/33 [==============================] - 12s 367ms/step - loss: 0.1877 - accuracy: 0.9305 - val_loss: 0.0352 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 5/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.1246 - accuracy: 0.9531
# Epoch 5: val_loss improved from 0.03517 to 0.02340, saving model to Transformer_7.h5
# 33/33 [==============================] - 15s 478ms/step - loss: 0.1284 - accuracy: 0.9517 - val_loss: 0.0234 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 6/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.1233 - accuracy: 0.9570
# Epoch 6: val_loss did not improve from 0.02340
# 33/33 [==============================] - 2s 63ms/step - loss: 0.1260 - accuracy: 0.9546 - val_loss: 0.1252 - val_accuracy: 0.9569 - lr: 1.0000e-04
# Epoch 7/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.1083 - accuracy: 0.9648
# Epoch 7: val_loss did not improve from 0.02340
# 33/33 [==============================] - 2s 62ms/step - loss: 0.1071 - accuracy: 0.9653 - val_loss: 0.0694 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 8/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0388 - accuracy: 0.9844
# Epoch 8: val_loss improved from 0.02340 to 0.00624, saving model to Transformer_7.h5
# 33/33 [==============================] - 11s 327ms/step - loss: 0.0399 - accuracy: 0.9836 - val_loss: 0.0062 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 9/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9824
# Epoch 9: val_loss did not improve from 0.00624
# 33/33 [==============================] - 2s 58ms/step - loss: 0.0524 - accuracy: 0.9807 - val_loss: 0.1164 - val_accuracy: 0.9741 - lr: 1.0000e-04
# Epoch 10/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0699 - accuracy: 0.9756
# Epoch 10: val_loss did not improve from 0.00624
# 33/33 [==============================] - 2s 59ms/step - loss: 0.0692 - accuracy: 0.9759 - val_loss: 0.0111 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 11/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0500 - accuracy: 0.9795
# Epoch 11: val_loss did not improve from 0.00624
# 33/33 [==============================] - 2s 56ms/step - loss: 0.0496 - accuracy: 0.9797 - val_loss: 0.2389 - val_accuracy: 0.9397 - lr: 1.0000e-04
# Epoch 12/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0756 - accuracy: 0.9775
# Epoch 12: val_loss improved from 0.00624 to 0.00258, saving model to Transformer_7.h5
# 33/33 [==============================] - 13s 414ms/step - loss: 0.0756 - accuracy: 0.9768 - val_loss: 0.0026 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 13/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 0.9922
# Epoch 13: val_loss did not improve from 0.00258
# 33/33 [==============================] - 2s 58ms/step - loss: 0.0225 - accuracy: 0.9923 - val_loss: 0.0287 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 14/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9961
# Epoch 14: val_loss did not improve from 0.00258
# 33/33 [==============================] - 2s 58ms/step - loss: 0.0088 - accuracy: 0.9961 - val_loss: 0.0302 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 15/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0164 - accuracy: 0.9941
# Epoch 15: val_loss did not improve from 0.00258
# 33/33 [==============================] - 2s 55ms/step - loss: 0.0163 - accuracy: 0.9942 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 16/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9990
# Epoch 16: val_loss did not improve from 0.00258
# 33/33 [==============================] - 2s 55ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.0122 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 17/500
# 32/33 [============================>.] - ETA: 0s - loss: 5.3098e-04 - accuracy: 1.0000
# Epoch 17: val_loss improved from 0.00258 to 0.00215, saving model to Transformer_7.h5
# 33/33 [==============================] - 14s 449ms/step - loss: 5.2517e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 18/500
# 32/33 [============================>.] - ETA: 0s - loss: 5.5416e-04 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.00215
# 33/33 [==============================] - 2s 58ms/step - loss: 5.5028e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 19/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0025 - accuracy: 0.9980
# Epoch 19: val_loss improved from 0.00215 to 0.00188, saving model to Transformer_7.h5
# 33/33 [==============================] - 11s 332ms/step - loss: 0.0025 - accuracy: 0.9981 - val_loss: 0.0019 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 20/500
# 32/33 [============================>.] - ETA: 0s - loss: 5.4035e-04 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.00188
# 33/33 [==============================] - 2s 57ms/step - loss: 5.3429e-04 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 21/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.1598e-04 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.00188
# 33/33 [==============================] - 2s 55ms/step - loss: 1.2202e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 22/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.9861e-04 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.00188
# 33/33 [==============================] - 2s 57ms/step - loss: 2.9517e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 23/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.8127e-04 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.00188
# 33/33 [==============================] - 2s 54ms/step - loss: 2.7813e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 24/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.1189e-04 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.00188
# 33/33 [==============================] - 2s 55ms/step - loss: 1.1074e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch
val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 55ms/step - loss: 3.8621e-05 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 45/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.8392e-05 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 56ms/step - loss: 3.7990e-05 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 46/500
# 32/33 [============================>.] - ETA: 0s - loss: 7.7344e-05 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 57ms/step - loss: 7.6461e-05 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 47/500
# 32/33 [============================>.] - ETA: 0s - loss: 8.1295e-05 - accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 55ms/step - loss: 8.0546e-05 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 48/500
# 32/33 [============================>.] - ETA: 0s - loss: 6.6195e-05 - accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.00127
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 33/33 [==============================] - 2s 55ms/step - loss: 6.5429e-05 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 49/500
# 32/33 [============================>.] - ETA: 0s - loss: 4.0487e-05 - accuracy: 1.0000
# Epoch 49: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 55ms/step - loss: 4.0024e-05 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 50/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.3016e-05 - accuracy: 1.0000
# Epoch 50: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 55ms/step - loss: 2.3029e-05 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 51/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.8251e-05 - accuracy: 1.0000
# Epoch 51: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 55ms/step - loss: 3.7838e-05 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 52/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.7581e-05 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 55ms/step - loss: 3.7153e-05 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 53/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.5856e-05 - accuracy: 1.0000
# Epoch 53: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 55ms/step - loss: 2.5588e-05 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 54/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.8725e-05 - accuracy: 1.0000
# Epoch 54: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 55ms/step - loss: 3.8471e-05 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 55/500
# 32/33 [============================>.] - ETA: 0s - loss: 5.1012e-05 - accuracy: 1.0000
# Epoch 55: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 54ms/step - loss: 5.0459e-05 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 56/500
# 32/33 [============================>.] - ETA: 0s - loss: 4.6597e-05 - accuracy: 1.0000
# Epoch 56: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 54ms/step - loss: 4.6072e-05 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 57/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.8683e-05 - accuracy: 1.0000
# Epoch 57: val_loss did not improve from 0.00127
# 33/33 [==============================] - 2s 55ms/step - loss: 3.8710e-05 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 58/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.6075e-04 - accuracy: 1.0000
# Epoch 58: val_loss did not improve from 0.00127
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 33/33 [==============================] - 2s 54ms/step - loss: 1.5889e-04 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 1.0000e-06
# 5/5 [==============================] - 0s 19ms/step - loss: 0.4724 - accuracy: 0.9514
# Test accuracy: 95.14%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_7.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 5/5 [==============================] - 0s 18ms/step
# ([<matplotlib.axis.YTick at 0x7fa56041d1c0>,
#   <matplotlib.axis.YTick at 0x7fa56042a790>,
#   <matplotlib.axis.YTick at 0x7fa56034bf10>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
