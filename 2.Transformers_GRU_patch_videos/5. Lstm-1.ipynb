# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="7"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 2048
MAX_SEQ_LENGTH = 40
IMG_SIZE = 456

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==1)]
test
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1152, 40, 2048)
# (1152, 1)
# (144, 40, 2048)
# (144, 1)

# %%
with strategy.scope():

    def get_compiled_model():
        
        frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))

        x = keras.layers.GRU(128, return_sequences=True)(frame_features_input)
        x = keras.layers.GRU(64)(x)
        x = keras.layers.Dropout(0.4)(x)
        x = keras.layers.Dense(64, activation="relu")(x)
        output = keras.layers.Dense(3, activation="softmax")(x)

        rnn_model = keras.Model(frame_features_input, output)

        rnn_model.compile(
            loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
        )
        
        rnn_model.summary()
        
        return rnn_model
    
with strategy.scope():
    
    def run_experiment():
        
        filepath = "lstm_1.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 40, 2048)]        0
#
#  gru (GRU)                   (None, 40, 128)           836352
#
#  gru_1 (GRU)                 (None, 64)                37248
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 877,955
# Trainable params: 877,955
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5847 - accuracy: 0.7210
# Epoch 1: val_loss improved from inf to 0.16891, saving model to lstm_1.h5
# 33/33 [==============================] - 5s 29ms/step - loss: 0.5847 - accuracy: 0.7210 - val_loss: 0.1689 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 2/500
# 28/33 [========================>.....] - ETA: 0s - loss: 0.2243 - accuracy: 0.9241
# Epoch 2: val_loss improved from 0.16891 to 0.06522, saving model to lstm_1.h5
# 33/33 [==============================] - 0s 12ms/step - loss: 0.2151 - accuracy: 0.9286 - val_loss: 0.0652 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 3/500
# 27/33 [=======================>......] - ETA: 0s - loss: 0.1778 - accuracy: 0.9363
# Epoch 3: val_loss improved from 0.06522 to 0.05157, saving model to lstm_1.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 0.1786 - accuracy: 0.9363 - val_loss: 0.0516 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 4/500
# 27/33 [=======================>......] - ETA: 0s - loss: 0.1655 - accuracy: 0.9444
# Epoch 4: val_loss did not improve from 0.05157
# 33/33 [==============================] - 0s 8ms/step - loss: 0.1504 - accuracy: 0.9498 - val_loss: 0.0645 - val_accuracy: 0.9828 - lr: 0.0010
# Epoch 5/500
# 27/33 [=======================>......] - ETA: 0s - loss: 0.0643 - accuracy: 0.9769
# Epoch 5: val_loss did not improve from 0.05157
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0602 - accuracy: 0.9788 - val_loss: 0.0662 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 6/500
# 26/33 [======================>.......] - ETA: 0s - loss: 0.0464 - accuracy: 0.9820
# Epoch 6: val_loss improved from 0.05157 to 0.00454, saving model to lstm_1.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0428 - accuracy: 0.9826 - val_loss: 0.0045 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/500
# 27/33 [=======================>......] - ETA: 0s - loss: 0.0793 - accuracy: 0.9745
# Epoch 7: val_loss did not improve from 0.00454
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0710 - accuracy: 0.9778 - val_loss: 0.2046 - val_accuracy: 0.9224 - lr: 0.0010
# Epoch 8/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0715 - accuracy: 0.9784
# Epoch 8: val_loss did not improve from 0.00454
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0648 - accuracy: 0.9807 - val_loss: 0.0120 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 9/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0287 - accuracy: 0.9896
# Epoch 9: val_loss did not improve from 0.00454
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0271 - accuracy: 0.9903 - val_loss: 0.0319 - val_accuracy: 0.9914 - lr: 0.0010
# Epoch 10/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9903
# Epoch 10: val_loss did not improve from 0.00454
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0236 - accuracy: 0.9903 - val_loss: 0.1050 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 11/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9923
# Epoch 11: val_loss did not improve from 0.00454
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0175 - accuracy: 0.9923 - val_loss: 0.0064 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 12/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0117 - accuracy: 0.9970
# Epoch 12: val_loss did not improve from 0.00454
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 0.0046 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 13/500
# 25/33 [=====================>........] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 13: val_loss did not improve from 0.00454
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 14/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 14: val_loss did not improve from 0.00454
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 15/500
# 26/33 [======================>.......] - ETA: 0s - loss: 6.8036e-04 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.00454 to 0.00138, saving model to lstm_1.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 6.6044e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/500
# 28/33 [========================>.....] - ETA: 0s - loss: 5.7969e-04 - accuracy: 1.0000
# Epoch 16: val_loss improved from 0.00138 to 0.00049, saving model to lstm_1.h5
# 33/33 [==============================] - 0s 12ms/step - loss: 5.6534e-04 - accuracy: 1.0000 - val_loss: 4.9001e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/500
# 26/33 [======================>.......] - ETA: 0s - loss: 4.5678e-04 - accuracy: 1.0000
# Epoch 17: val_loss improved from 0.00049 to 0.00038, saving model to lstm_1.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 4.9636e-04 - accuracy: 1.0000 - val_loss: 3.8141e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/500
# 33/33 [==============================] - ETA: 0s - loss: 3.9537e-04 - accuracy: 1.0000
# Epoch 18: val_loss improved from 0.00038 to 0.00022, saving model to lstm_1.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 3.9537e-04 - accuracy: 1.0000 - val_loss: 2.2126e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/500
# 33/33 [==============================] - ETA: 0s - loss: 3.2338e-04 - accuracy: 1.0000
# Epoch 19: val_loss improved from 0.00022 to 0.00020, saving model to lstm_1.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 3.2338e-04 - accuracy: 1.0000 - val_loss: 1.9998e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/500
# 25/33 [=====================>........] - ETA: 0s - loss: 3.2233e-04 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.00020
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2353e-04 - accuracy: 1.0000 - val_loss: 2.4297e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 21/500
# 33/33 [==============================] - ETA: 0s - loss: 2.6596e-04 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.00020
# 33/33 [==============================] - 0s 9ms/step - loss: 2.6596e-04 - accuracy: 1.0000 - val_loss: 2.2634e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 22/500
# 26/33 [======================>.......] - ETA: 0s - loss: 2.7517e-04 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.00020
# 33/33 [==============================] - 0s 9ms/step - loss: 2.7669e-04 - accuracy: 1.0000 - val_loss: 2.0691e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 23/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.1805e-04 - accuracy: 1.0000
# Epoch 23: val_loss improved from 0.00020 to 0.00009, saving model to lstm_1.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 3.1833e-04 - accuracy: 1.0000 - val_loss: 9.3944e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/500
# 32/33 [============================>.] - ETA: 0s - loss: 2.5299e-04 - accuracy: 1.0000
# Epoch 24: val_loss improved from 0.00009 to 0.00009, saving model to lstm_1.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 2.5180e-04 - accuracy: 1.0000 - val_loss: 8.6857e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 25/500
# 33/33 [==============================] - ETA: 0s - loss: 2.3095e-04 - accuracy: 1.0000
# Epoch 25: val_loss improved from 0.00009 to 0.00007, saving model to lstm_1.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 2.3095e-04 - accuracy: 1.0000 - val_loss: 7.2914e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 26/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.8423e-04 - accuracy: 1.0000
# Epoch 26: val_loss improved from 0.00007 to 0.00007, saving model to lstm_1.h5
# 33/33 [==============================] - 1s 16ms/step - loss: 1.8038e-04 - accuracy: 1.0000 - val_loss: 6.5363e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 27/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.6536e-04 - accuracy: 1.0000
# Epoch 27: val_loss improved from 0.00007 to 0.00006, saving model to lstm_1.h5
# 33/33 [==============================] - 1s 19ms/step - loss: 1.6501e-04 - accuracy: 1.0000 - val_loss: 5.9266e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 28/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.5870e-04 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.00006
# 33/33 [==============================] - 0s 11ms/step - loss: 1.6668e-04 - accuracy: 1.0000 - val_loss: 6.7811e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 29/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.5397e-04 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.00006
# 33/33 [==============================] - 1s 16ms/step - loss: 1.5669e-04 - accuracy: 1.0000 - val_loss: 6.5120e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 30/500
# 33/33 [==============================] - ETA: 0s - loss: 1.4561e-04 - accuracy: 1.0000
# Epoch 30: val_loss improved from 0.00006 to 0.00005, saving model to lstm_1.h5
# 33/33 [==============================] - 1s 24ms/step - loss: 1.4561e-04 - accuracy: 1.0000 - val_loss: 5.3163e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 31/500
# 29/33 [=========================>....] - ETA: 0s - loss: 1.2955e-04 - accuracy: 1.0000
# Epoch 31: val_loss improved from 0.00005 to 0.00005, saving model to lstm_1.h5
# 33/33 [==============================] - 1s 27ms/step - loss: 1.4011e-04 - accuracy: 1.0000 - val_loss: 4.5347e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 32/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.2194e-04 - accuracy: 1.0000
# Epoch 32: val_loss improved from 0.00005 to 0.00004, saving model to lstm_1.h5
# 33/33 [==============================] - 1s 24ms/step - loss: 1.2140e-04 - accuracy: 1.0000 - val_loss: 4.2922e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 33/500
# 33/33 [==============================] - ETA: 0s - loss: 1.4293e-04 - accuracy: 1.0000
# Epoch 33: val_loss improved from 0.00004 to 0.00003, saving model to lstm_1.h5
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 33/33 [==============================] - 1s 15ms/step - loss: 1.4293e-04 - accuracy: 1.0000 - val_loss: 3.3645e-05 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 34/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.2442e-04 - accuracy: 1.0000
# Epoch 34: val_loss improved from 0.00003 to 0.00003, saving model to lstm_1.h5
# 33/33 [==============================] - 1s 18ms/step - loss: 1.2350e-04 - accuracy: 1.0000 - val_loss: 3.3438e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 35/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.2887e-04 - accuracy: 1.0000
# Epoch 35: val_loss did not improve from 0.00003
# 33/33 [==============================] - 1s 18ms/step - loss: 1.4490e-04 - accuracy: 1.0000 - val_loss: 3.3626e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 36/500
# 31/33 [===========================>..] - ETA: 0s - loss: 9.8741e-05 - accuracy: 1.0000
# Epoch 36: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.0179e-04 - accuracy: 1.0000 - val_loss: 3.4578e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 37/500
# 28/33 [========================>.....] - ETA: 0s - loss: 1.3457e-04 - accuracy: 1.0000
# Epoch 37: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 14ms/step - loss: 1.3567e-04 - accuracy: 1.0000 - val_loss: 3.4827e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 38/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.2860e-04 - accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.3380e-04 - accuracy: 1.0000 - val_loss: 3.7224e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 39/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.1764e-04 - accuracy: 1.0000
# Epoch 39: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.1550e-04 - accuracy: 1.0000 - val_loss: 3.6543e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 40/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.2140e-04 - accuracy: 1.0000
# Epoch 40: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 9ms/step - loss: 1.2541e-04 - accuracy: 1.0000 - val_loss: 3.6366e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 41/500
# 26/33 [======================>.......] - ETA: 0s - loss: 1.0469e-04 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.0686e-04 - accuracy: 1.0000 - val_loss: 3.6442e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 42/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.2672e-04 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.2371e-04 - accuracy: 1.0000 - val_loss: 3.6683e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 43/500
# 30/33 [==========================>...] - ETA: 0s - loss: 9.8827e-05 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.00003
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 33/33 [==============================] - 0s 10ms/step - loss: 1.0057e-04 - accuracy: 1.0000 - val_loss: 3.6924e-05 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 44/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.0666e-04 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 9ms/step - loss: 1.1541e-04 - accuracy: 1.0000 - val_loss: 3.6904e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 45/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.2932e-04 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.3027e-04 - accuracy: 1.0000 - val_loss: 3.6897e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 46/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.1234e-04 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 14ms/step - loss: 1.1115e-04 - accuracy: 1.0000 - val_loss: 3.6891e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 47/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.0271e-04 - accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 11ms/step - loss: 1.0015e-04 - accuracy: 1.0000 - val_loss: 3.6850e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 48/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.1485e-04 - accuracy: 1.0000
# Epoch 48: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.1482e-04 - accuracy: 1.0000 - val_loss: 3.6724e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 49/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.1497e-04 - accuracy: 1.0000
# Epoch 49: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.1407e-04 - accuracy: 1.0000 - val_loss: 3.6707e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 50/500
# 31/33 [===========================>..] - ETA: 0s - loss: 9.4278e-05 - accuracy: 1.0000
# Epoch 50: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 9ms/step - loss: 9.7563e-05 - accuracy: 1.0000 - val_loss: 3.6698e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 51/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.2303e-04 - accuracy: 1.0000
# Epoch 51: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 9ms/step - loss: 1.2283e-04 - accuracy: 1.0000 - val_loss: 3.6849e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 52/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.2488e-04 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 9ms/step - loss: 1.2393e-04 - accuracy: 1.0000 - val_loss: 3.6738e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 53/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.2641e-04 - accuracy: 1.0000
# Epoch 53: val_loss did not improve from 0.00003
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 33/33 [==============================] - 0s 12ms/step - loss: 1.2366e-04 - accuracy: 1.0000 - val_loss: 3.6613e-05 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 54/500
# 26/33 [======================>.......] - ETA: 0s - loss: 1.2283e-04 - accuracy: 1.0000
# Epoch 54: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 9ms/step - loss: 1.1705e-04 - accuracy: 1.0000 - val_loss: 3.6610e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 55/500
# 25/33 [=====================>........] - ETA: 0s - loss: 9.5507e-05 - accuracy: 1.0000
# Epoch 55: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 9ms/step - loss: 9.9049e-05 - accuracy: 1.0000 - val_loss: 3.6609e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 56/500
# 26/33 [======================>.......] - ETA: 0s - loss: 1.0660e-04 - accuracy: 1.0000
# Epoch 56: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 9ms/step - loss: 1.1180e-04 - accuracy: 1.0000 - val_loss: 3.6602e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 57/500
# 26/33 [======================>.......] - ETA: 0s - loss: 1.2089e-04 - accuracy: 1.0000
# Epoch 57: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.1652e-04 - accuracy: 1.0000 - val_loss: 3.6602e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 58/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.1488e-04 - accuracy: 1.0000
# Epoch 58: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.1599e-04 - accuracy: 1.0000 - val_loss: 3.6603e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 59/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.3090e-04 - accuracy: 1.0000
# Epoch 59: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.2835e-04 - accuracy: 1.0000 - val_loss: 3.6610e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 60/500
# 26/33 [======================>.......] - ETA: 0s - loss: 1.0597e-04 - accuracy: 1.0000
# Epoch 60: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 9ms/step - loss: 1.1209e-04 - accuracy: 1.0000 - val_loss: 3.6605e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 61/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.3887e-04 - accuracy: 1.0000
# Epoch 61: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.4054e-04 - accuracy: 1.0000 - val_loss: 3.6604e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 62/500
# 27/33 [=======================>......] - ETA: 0s - loss: 1.1275e-04 - accuracy: 1.0000
# Epoch 62: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 10ms/step - loss: 1.2546e-04 - accuracy: 1.0000 - val_loss: 3.6594e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 63/500
# 33/33 [==============================] - ETA: 0s - loss: 1.1710e-04 - accuracy: 1.0000
# Epoch 63: val_loss did not improve from 0.00003
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 33/33 [==============================] - 0s 15ms/step - loss: 1.1710e-04 - accuracy: 1.0000 - val_loss: 3.6594e-05 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 64/500
# 30/33 [==========================>...] - ETA: 0s - loss: 1.0385e-04 - accuracy: 1.0000
# Epoch 64: val_loss did not improve from 0.00003
# 33/33 [==============================] - 0s 12ms/step - loss: 1.0477e-04 - accuracy: 1.0000 - val_loss: 3.6595e-05 - val_accuracy: 1.0000 - lr: 1.0000e-07
# 5/5 [==============================] - 0s 6ms/step - loss: 2.8696 - accuracy: 0.5903
# Test accuracy: 59.03%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('lstm_1.h5')

predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 5/5 [==============================] - 0s 4ms/step
# ([<matplotlib.axis.YTick at 0x7ef6a82ed9d0>,
#   <matplotlib.axis.YTick at 0x7ef6a82ed370>,
#   <matplotlib.axis.YTick at 0x7ef6a82cfbe0>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
