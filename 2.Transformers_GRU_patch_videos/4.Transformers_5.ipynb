# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import numpy as np
import tensorflow as tf
from transformers import TFBertModel, BertTokenizer
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import imageio
import cv2 as cv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 2048
MAX_SEQ_LENGTH = 40
IMG_SIZE = 456

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==8)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1152, 40, 2048)
# (1152, 1)
# (144, 40, 2048)
# (144, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_5.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 2048)       81920
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 2048)       67162116
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 2048)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_2 (Dense)             (None, 3)                 6147
#
# =================================================================
# Total params: 67,250,183
# Trainable params: 67,250,183
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 33/33 [==============================] - ETA: 0s - loss: 1.0017 - accuracy: 0.7191
# Epoch 1: val_loss improved from inf to 0.38403, saving model to Transformer_1.h5
# 33/33 [==============================] - 11s 264ms/step - loss: 1.0017 - accuracy: 0.7191 - val_loss: 0.3840 - val_accuracy: 0.8966 - lr: 1.0000e-04
# Epoch 2/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.6101 - accuracy: 0.8276
# Epoch 2: val_loss improved from 0.38403 to 0.08391, saving model to Transformer_1.h5
# 33/33 [==============================] - 9s 267ms/step - loss: 0.5710 - accuracy: 0.8349 - val_loss: 0.0839 - val_accuracy: 0.9741 - lr: 1.0000e-04
# Epoch 3/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.1918 - accuracy: 0.9278
# Epoch 3: val_loss did not improve from 0.08391
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1857 - accuracy: 0.9305 - val_loss: 0.0926 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 4/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.1416 - accuracy: 0.9461
# Epoch 4: val_loss improved from 0.08391 to 0.01642, saving model to Transformer_1.h5
# 33/33 [==============================] - 8s 263ms/step - loss: 0.1370 - accuracy: 0.9479 - val_loss: 0.0164 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 5/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.1314 - accuracy: 0.9552
# Epoch 5: val_loss did not improve from 0.01642
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1280 - accuracy: 0.9546 - val_loss: 0.0733 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 6/500
# 33/33 [==============================] - ETA: 0s - loss: 0.1021 - accuracy: 0.9662
# Epoch 6: val_loss did not improve from 0.01642
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1021 - accuracy: 0.9662 - val_loss: 0.0423 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 7/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0418 - accuracy: 0.9854
# Epoch 7: val_loss improved from 0.01642 to 0.01358, saving model to Transformer_1.h5
# 33/33 [==============================] - 9s 265ms/step - loss: 0.0413 - accuracy: 0.9855 - val_loss: 0.0136 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 8/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0794 - accuracy: 0.9738
# Epoch 8: val_loss did not improve from 0.01358
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0768 - accuracy: 0.9749 - val_loss: 0.0749 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 9/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9691
# Epoch 9: val_loss did not improve from 0.01358
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0928 - accuracy: 0.9691 - val_loss: 0.1709 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 10/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9759
# Epoch 10: val_loss improved from 0.01358 to 0.01222, saving model to Transformer_1.h5
# 33/33 [==============================] - 8s 263ms/step - loss: 0.0584 - accuracy: 0.9759 - val_loss: 0.0122 - val_accuracy: 0.9914 - lr: 1.0000e-04
# Epoch 11/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0379 - accuracy: 0.9903
# Epoch 11: val_loss improved from 0.01222 to 0.00085, saving model to Transformer_1.h5
# 33/33 [==============================] - 9s 266ms/step - loss: 0.0367 - accuracy: 0.9903 - val_loss: 8.4510e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 12/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0373 - accuracy: 0.9871
# Epoch 12: val_loss did not improve from 0.00085
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0363 - accuracy: 0.9875 - val_loss: 0.0351 - val_accuracy: 0.9828 - lr: 1.0000e-04
# Epoch 13/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0366 - accuracy: 0.9871
# Epoch 13: val_loss did not improve from 0.00085
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0329 - accuracy: 0.9884 - val_loss: 0.0034 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 14/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0064 - accuracy: 0.9968
# Epoch 14: val_loss did not improve from 0.00085
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0061 - accuracy: 0.9971 - val_loss: 0.0033 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 15/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 15: val_loss improved from 0.00085 to 0.00060, saving model to Transformer_1.h5
# 33/33 [==============================] - 9s 267ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 6.0383e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 16/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 16: val_loss improved from 0.00060 to 0.00038, saving model to Transformer_1.h5
# 33/33 [==============================] - 9s 272ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.8406e-04 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 17/500
# 32/33 [============================>.] - ETA: 0s - loss: 7.1682e-04 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.00038
# 33/33 [==============================] - 1s
- val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 36/500
# 29/33 [=========================>....] - ETA: 0s - loss: 5.9454e-05 - accuracy: 1.0000
# Epoch 36: val_loss did not improve from 0.00038
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 33/33 [==============================] - 1s 16ms/step - loss: 5.5849e-05 - accuracy: 1.0000 - val_loss: 9.8992e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 37/500
# 33/33 [==============================] - ETA: 0s - loss: 6.4152e-05 - accuracy: 1.0000
# Epoch 37: val_loss did not improve from 0.00038
# 33/33 [==============================] - 1s 17ms/step - loss: 6.4152e-05 - accuracy: 1.0000 - val_loss: 9.9549e-04 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 38/500
# 33/33 [==============================] - ETA: 0s - loss: 1.6461e-04 - accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.00038
# 33/33 [==============================] - 1s 16ms/step - loss: 1.6461e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 39/500
# 29/33 [=========================>....] - ETA: 0s - loss: 9.1707e-05 - accuracy: 1.0000
# Epoch 39: val_loss did not improve from 0.00038
# 33/33 [==============================] - 1s 16ms/step - loss: 8.3387e-05 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 40/500
# 33/33 [==============================] - ETA: 0s - loss: 6.5397e-04 - accuracy: 1.0000
# Epoch 40: val_loss did not improve from 0.00038
# 33/33 [==============================] - 1s 17ms/step - loss: 6.5397e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 41/500
# 32/33 [============================>.] - ETA: 0s - loss: 1.2426e-04 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.00038
# 33/33 [==============================] - 1s 18ms/step - loss: 1.2287e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 42/500
# 33/33 [==============================] - ETA: 0s - loss: 1.7256e-04 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.00038
# 33/33 [==============================] - 1s 17ms/step - loss: 1.7256e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 43/500
# 33/33 [==============================] - ETA: 0s - loss: 1.0088e-04 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.00038
# 33/33 [==============================] - 1s 17ms/step - loss: 1.0088e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 44/500
# 33/33 [==============================] - ETA: 0s - loss: 1.3788e-04 - accuracy: 1.0000
# Epoch 44: val_loss did not improve from 0.00038
# 33/33 [==============================] - 1s 17ms/step - loss: 1.3788e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 45/500
# 31/33 [===========================>..] - ETA: 0s - loss: 1.4984e-04 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.00038
# 33/33 [==============================] - 1s 18ms/step - loss: 1.4573e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 46/500
# 33/33 [==============================] - ETA: 0s - loss: 6.5103e-05 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.00038
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 33/33 [==============================] - 1s 17ms/step - loss: 6.5103e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - lr: 1.0000e-06
# 5/5 [==============================] - 0s 6ms/step - loss: 5.0222 - accuracy: 0.5417
# Test accuracy: 54.17%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_5.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 5/5 [==============================] - 2s 6ms/step
# ([<matplotlib.axis.YTick at 0x7fbec42adf40>,
#   <matplotlib.axis.YTick at 0x7fbec42adf10>,
#   <matplotlib.axis.YTick at 0x7fbec42adc40>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
