# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="4"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 2048
MAX_SEQ_LENGTH = 40
IMG_SIZE = 456

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==7)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1152, 40, 2048)
# (1152, 1)
# (144, 40, 2048)
# (144, 1)

# %%
with strategy.scope():

    def get_compiled_model():
        
        frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))

        x = keras.layers.GRU(128, return_sequences=True)(frame_features_input)
        x = keras.layers.GRU(64)(x)
        x = keras.layers.Dropout(0.4)(x)
        x = keras.layers.Dense(64, activation="relu")(x)
        output = keras.layers.Dense(3, activation="softmax")(x)

        rnn_model = keras.Model(frame_features_input, output)

        rnn_model.compile(
            loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
        )
        
        rnn_model.summary()
        
        return rnn_model
    
with strategy.scope():
    
    def run_experiment():
        
        filepath = "lstm_4.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 40, 2048)]        0
#
#  gru (GRU)                   (None, 40, 128)           836352
#
#  gru_1 (GRU)                 (None, 64)                37248
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 877,955
# Trainable params: 877,955
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 28/33 [========================>.....] - ETA: 0s - loss: 0.6248 - accuracy: 0.7299
# Epoch 1: val_loss improved from inf to 0.22930, saving model to lstm_4.h5
# 33/33 [==============================] - 6s 33ms/step - loss: 0.6144 - accuracy: 0.7317 - val_loss: 0.2293 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 2/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.3027 - accuracy: 0.8782
# Epoch 2: val_loss improved from 0.22930 to 0.12733, saving model to lstm_4.h5
# 33/33 [==============================] - 1s 15ms/step - loss: 0.3082 - accuracy: 0.8774 - val_loss: 0.1273 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 3/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.1594 - accuracy: 0.9395
# Epoch 3: val_loss improved from 0.12733 to 0.09169, saving model to lstm_4.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1579 - accuracy: 0.9402 - val_loss: 0.0917 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 4/500
# 26/33 [======================>.......] - ETA: 0s - loss: 0.1132 - accuracy: 0.9591
# Epoch 4: val_loss did not improve from 0.09169
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0979 - accuracy: 0.9653 - val_loss: 0.2251 - val_accuracy: 0.9397 - lr: 0.0010
# Epoch 5/500
# 26/33 [======================>.......] - ETA: 0s - loss: 0.0837 - accuracy: 0.9688
# Epoch 5: val_loss improved from 0.09169 to 0.04638, saving model to lstm_4.h5
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0913 - accuracy: 0.9662 - val_loss: 0.0464 - val_accuracy: 0.9741 - lr: 0.0010
# Epoch 6/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0301 - accuracy: 0.9917
# Epoch 6: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0362 - accuracy: 0.9894 - val_loss: 0.1110 - val_accuracy: 0.9569 - lr: 0.0010
# Epoch 7/500
# 25/33 [=====================>........] - ETA: 0s - loss: 0.0915 - accuracy: 0.9725
# Epoch 7: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0866 - accuracy: 0.9730 - val_loss: 0.1896 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 8/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9691
# Epoch 8: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0771 - accuracy: 0.9691 - val_loss: 0.2677 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 9/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0435 - accuracy: 0.9834
# Epoch 9: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0431 - accuracy: 0.9836 - val_loss: 0.1330 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 10/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.1014 - accuracy: 0.9708
# Epoch 10: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0981 - accuracy: 0.9710 - val_loss: 0.1849 - val_accuracy: 0.9569 - lr: 0.0010
# Epoch 11/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9981
# Epoch 11: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0112 - accuracy: 0.9981 - val_loss: 0.1352 - val_accuracy: 0.9569 - lr: 0.0010
# Epoch 12/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9990
# Epoch 12: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.1562 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 13/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0094 - accuracy: 0.9958
# Epoch 13: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0090 - accuracy: 0.9961 - val_loss: 0.2470 - val_accuracy: 0.9397 - lr: 0.0010
# Epoch 14/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 0.9932
# Epoch 14: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0221 - accuracy: 0.9932 - val_loss: 0.1635 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 15/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.9961
# Epoch 15: val_loss did not improve from 0.04638
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 0.1185 - val_accuracy: 0.9655 - lr: 0.0010
# Epoch 16/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9941
# Epoch 16: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0124 - accuracy: 0.9942 - val_loss: 0.1333 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 17/500
# 25/33 [=====================>........] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 18/500
# 25/33 [=====================>........] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 19/500
# 33/33 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 20/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 21/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.04638
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 22/500
# 27/33 [=======================>......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 23/500
# 33/33 [==============================] - ETA: 0s - loss: 8.2492e-04 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.04638
# 33/33 [==============================] - 1s 16ms/step - loss: 8.2492e-04 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 24/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.04638
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1733 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 25/500
# 30/33 [==========================>...] - ETA: 0s - loss: 8.8043e-04 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.04638
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 33/33 [==============================] - 1s 21ms/step - loss: 8.6063e-04 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9655 - lr: 1.0000e-04
# Epoch 26/500
# 32/33 [============================>.] - ETA: 0s - loss: 9.2927e-04 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.04638
# 33/33 [==============================] - 1s 17ms/step - loss: 9.2861e-04 - accuracy: 1.0000 - val_loss: 0.1859 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 27/500
# 29/33 [=========================>....] - ETA: 0s - loss: 9.4170e-04 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 15ms/step - loss: 9.5374e-04 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 28/500
# 33/33 [==============================] - ETA: 0s - loss: 8.6346e-04 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.04638
# 33/33 [==============================] - 1s 17ms/step - loss: 8.6346e-04 - accuracy: 1.0000 - val_loss: 0.1857 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 29/500
# 29/33 [=========================>....] - ETA: 0s - loss: 9.0823e-04 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 12ms/step - loss: 9.3076e-04 - accuracy: 1.0000 - val_loss: 0.1856 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 30/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 31/500
# 31/33 [===========================>..] - ETA: 0s - loss: 8.8193e-04 - accuracy: 1.0000
# Epoch 31: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 12ms/step - loss: 9.5061e-04 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 32/500
# 28/33 [========================>.....] - ETA: 0s - loss: 7.4083e-04 - accuracy: 1.0000
# Epoch 32: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 10ms/step - loss: 7.2890e-04 - accuracy: 1.0000 - val_loss: 0.1859 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 33/500
# 30/33 [==========================>...] - ETA: 0s - loss: 8.8491e-04 - accuracy: 1.0000
# Epoch 33: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 10ms/step - loss: 8.5585e-04 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 34/500
# 29/33 [=========================>....] - ETA: 0s - loss: 8.9096e-04 - accuracy: 1.0000
# Epoch 34: val_loss did not improve from 0.04638
# 33/33 [==============================] - 0s 10ms/step - loss: 9.0735e-04 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9655 - lr: 1.0000e-05
# Epoch 35/500
# 31/33 [===========================>..] - ETA: 0s - loss: 8.6917e-04 - accuracy: 1.0000
# Epoch 35: val_loss did not improve from 0.04638
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 33/33 [==============================] - 0s 10ms/step - loss: 8.8329e-04 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9655 - lr: 1.0000e-05
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3186 - accuracy: 0.8750
# Test accuracy: 87.5%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('lstm_4.h5')

predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 5/5 [==============================] - 1s 4ms/step
# ([<matplotlib.axis.YTick at 0x7f31702419d0>,
#   <matplotlib.axis.YTick at 0x7f3170241e20>,
#   <matplotlib.axis.YTick at 0x7f317022bf10>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
