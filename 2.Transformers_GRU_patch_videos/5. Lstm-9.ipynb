# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="4"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 2048
MAX_SEQ_LENGTH = 40
IMG_SIZE = 456

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==12)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Patch_videos_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (1152, 40, 2048)
# (1152, 1)
# (144, 40, 2048)
# (144, 1)

# %%
with strategy.scope():

    def get_compiled_model():
        
        frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))

        x = keras.layers.GRU(128, return_sequences=True)(frame_features_input)
        x = keras.layers.GRU(64)(x)
        x = keras.layers.Dropout(0.4)(x)
        x = keras.layers.Dense(64, activation="relu")(x)
        output = keras.layers.Dense(3, activation="softmax")(x)

        rnn_model = keras.Model(frame_features_input, output)

        rnn_model.compile(
            loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"]
        )
        
        rnn_model.summary()
        
        return rnn_model
    
with strategy.scope():
    
    def run_experiment():
        
        filepath = "lstm_9.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 40, 2048)]        0
#
#  gru (GRU)                   (None, 40, 128)           836352
#
#  gru_1 (GRU)                 (None, 64)                37248
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 877,955
# Trainable params: 877,955
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.5910 - accuracy: 0.7314
# Epoch 1: val_loss improved from inf to 0.40896, saving model to lstm_9.h5
# 33/33 [==============================] - 5s 29ms/step - loss: 0.5857 - accuracy: 0.7346 - val_loss: 0.4090 - val_accuracy: 0.8190 - lr: 0.0010
# Epoch 2/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.2963 - accuracy: 0.8844
# Epoch 2: val_loss improved from 0.40896 to 0.34449, saving model to lstm_9.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2875 - accuracy: 0.8871 - val_loss: 0.3445 - val_accuracy: 0.8879 - lr: 0.0010
# Epoch 3/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.1367 - accuracy: 0.9469
# Epoch 3: val_loss did not improve from 0.34449
# 33/33 [==============================] - 0s 10ms/step - loss: 0.1322 - accuracy: 0.9479 - val_loss: 0.3806 - val_accuracy: 0.8879 - lr: 0.0010
# Epoch 4/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0738 - accuracy: 0.9785
# Epoch 4: val_loss did not improve from 0.34449
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0755 - accuracy: 0.9778 - val_loss: 0.7446 - val_accuracy: 0.7759 - lr: 0.0010
# Epoch 5/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0837 - accuracy: 0.9629
# Epoch 5: val_loss did not improve from 0.34449
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0828 - accuracy: 0.9633 - val_loss: 0.4344 - val_accuracy: 0.8707 - lr: 0.0010
# Epoch 6/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0455 - accuracy: 0.9844
# Epoch 6: val_loss improved from 0.34449 to 0.31770, saving model to lstm_9.h5
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0452 - accuracy: 0.9846 - val_loss: 0.3177 - val_accuracy: 0.9052 - lr: 0.0010
# Epoch 7/500
# 29/33 [=========================>....] - ETA: 0s - loss: 0.0250 - accuracy: 0.9925
# Epoch 7: val_loss did not improve from 0.31770
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0227 - accuracy: 0.9932 - val_loss: 0.4055 - val_accuracy: 0.8966 - lr: 0.0010
# Epoch 8/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0499 - accuracy: 0.9808
# Epoch 8: val_loss did not improve from 0.31770
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0516 - accuracy: 0.9797 - val_loss: 0.5354 - val_accuracy: 0.8448 - lr: 0.0010
# Epoch 9/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0642 - accuracy: 0.9785
# Epoch 9: val_loss improved from 0.31770 to 0.29554, saving model to lstm_9.h5
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0636 - accuracy: 0.9788 - val_loss: 0.2955 - val_accuracy: 0.8966 - lr: 0.0010
# Epoch 10/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0438 - accuracy: 0.9869
# Epoch 10: val_loss did not improve from 0.29554
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0421 - accuracy: 0.9875 - val_loss: 0.4171 - val_accuracy: 0.9052 - lr: 0.0010
# Epoch 11/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0075 - accuracy: 0.9979
# Epoch 11: val_loss improved from 0.29554 to 0.19971, saving model to lstm_9.h5
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.1997 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 12/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 12: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2763 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 13/500
# 32/33 [============================>.] - ETA: 0s - loss: 0.0124 - accuracy: 0.9951
# Epoch 13: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0214 - accuracy: 0.9932 - val_loss: 0.2494 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 14/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0320 - accuracy: 0.9919
# Epoch 14: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0308 - accuracy: 0.9923 - val_loss: 0.3445 - val_accuracy: 0.9138 - lr: 0.0010
# Epoch 15/500
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 15: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2985 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 16/500
# 30/33 [==========================>...] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 17/500
# 33/33 [==============================] - ETA: 0s - loss: 8.5290e-04 - accuracy: 1.0000
# Epoch 17: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 11ms/step - loss: 8.5290e-04 - accuracy: 1.0000 - val_loss: 0.3250 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 18/500
# 31/33 [===========================>..] - ETA: 0s - loss: 6.3763e-04 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 6.3829e-04 - accuracy: 1.0000 - val_loss: 0.3383 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 19/500
# 33/33 [==============================] - ETA: 0s - loss: 5.6920e-04 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 5.6920e-04 - accuracy: 1.0000 - val_loss: 0.3721 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 20/500
# 30/33 [==========================>...] - ETA: 0s - loss: 5.3637e-04 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 10ms/step - loss: 5.2478e-04 - accuracy: 1.0000 - val_loss: 0.3950 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 21/500
# 33/33 [==============================] - ETA: 0s - loss: 4.7870e-04 - accuracy: 1.0000
# Epoch 21: val_loss did not improve from 0.19971
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 33/33 [==============================] - 0s 9ms/step - loss: 4.7870e-04 - accuracy: 1.0000 - val_loss: 0.3922 - val_accuracy: 0.9310 - lr: 0.0010
# Epoch 22/500
# 25/33 [=====================>........] - ETA: 0s - loss: 3.7005e-04 - accuracy: 1.0000
# Epoch 22: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8731e-04 - accuracy: 1.0000 - val_loss: 0.3928 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 23/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.5013e-04 - accuracy: 1.0000
# Epoch 23: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 13ms/step - loss: 3.4695e-04 - accuracy: 1.0000 - val_loss: 0.3956 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 24/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.9101e-04 - accuracy: 1.0000
# Epoch 24: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 3.9267e-04 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 25/500
# 26/33 [======================>.......] - ETA: 0s - loss: 3.5803e-04 - accuracy: 1.0000
# Epoch 25: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 3.6114e-04 - accuracy: 1.0000 - val_loss: 0.3946 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 26/500
# 32/33 [============================>.] - ETA: 0s - loss: 4.5881e-04 - accuracy: 1.0000
# Epoch 26: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 4.5485e-04 - accuracy: 1.0000 - val_loss: 0.3910 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 27/500
# 31/33 [===========================>..] - ETA: 0s - loss: 3.3122e-04 - accuracy: 1.0000
# Epoch 27: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 3.4111e-04 - accuracy: 1.0000 - val_loss: 0.3927 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 28/500
# 31/33 [===========================>..] - ETA: 0s - loss: 3.7353e-04 - accuracy: 1.0000
# Epoch 28: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 3.7001e-04 - accuracy: 1.0000 - val_loss: 0.3914 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 29/500
# 30/33 [==========================>...] - ETA: 0s - loss: 3.5351e-04 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5509e-04 - accuracy: 1.0000 - val_loss: 0.3946 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 30/500
# 32/33 [============================>.] - ETA: 0s - loss: 3.5193e-04 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5027e-04 - accuracy: 1.0000 - val_loss: 0.3966 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 31/500
# 31/33 [===========================>..] - ETA: 0s - loss: 3.2786e-04 - accuracy: 1.0000
# Epoch 31: val_loss did not improve from 0.19971
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2614e-04 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.9310 - lr: 1.0000e-04
# Epoch 32/500
# 33/33 [==============================] - ETA: 0s - loss: 3.8771e-04 - accuracy: 1.0000
# Epoch 32: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8771e-04 - accuracy: 1.0000 - val_loss: 0.3961 - val_accuracy: 0.9310 - lr: 1.0000e-05
# Epoch 33/500
# 27/33 [=======================>......] - ETA: 0s - loss: 3.6398e-04 - accuracy: 1.0000
# Epoch 33: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 8ms/step - loss: 3.7713e-04 - accuracy: 1.0000 - val_loss: 0.3962 - val_accuracy: 0.9310 - lr: 1.0000e-05
# Epoch 34/500
# 26/33 [======================>.......] - ETA: 0s - loss: 3.3954e-04 - accuracy: 1.0000
# Epoch 34: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 8ms/step - loss: 3.4491e-04 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.9310 - lr: 1.0000e-05
# Epoch 35/500
# 26/33 [======================>.......] - ETA: 0s - loss: 4.1074e-04 - accuracy: 1.0000
# Epoch 35: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 4.0165e-04 - accuracy: 1.0000 - val_loss: 0.3967 - val_accuracy: 0.9310 - lr: 1.0000e-05
# Epoch 36/500
# 33/33 [==============================] - ETA: 0s - loss: 3.5662e-04 - accuracy: 1.0000
# Epoch 36: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5662e-04 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.9310 - lr: 1.0000e-05
# Epoch 37/500
# 31/33 [===========================>..] - ETA: 0s - loss: 3.2923e-04 - accuracy: 1.0000
# Epoch 37: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 10ms/step - loss: 3.3203e-04 - accuracy: 1.0000 - val_loss: 0.3967 - val_accuracy: 0.9310 - lr: 1.0000e-05
# Epoch 38/500
# 26/33 [======================>.......] - ETA: 0s - loss: 4.1934e-04 - accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 10ms/step - loss: 4.2435e-04 - accuracy: 1.0000 - val_loss: 0.3970 - val_accuracy: 0.9310 - lr: 1.0000e-05
# Epoch 39/500
# 31/33 [===========================>..] - ETA: 0s - loss: 3.4507e-04 - accuracy: 1.0000
# Epoch 39: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 10ms/step - loss: 3.5743e-04 - accuracy: 1.0000 - val_loss: 0.3972 - val_accuracy: 0.9310 - lr: 1.0000e-05
# Epoch 40/500
# 30/33 [==========================>...] - ETA: 0s - loss: 3.6211e-04 - accuracy: 1.0000
# Epoch 40: val_loss did not improve from 0.19971
# 33/33 [==============================] - 0s 10ms/step - loss: 3.6313e-04 - accuracy: 1.0000 - val_loss: 0.3973 - val_accuracy: 0.9310 - lr: 1.0000e-05
# Epoch 41/500
# 29/33 [=========================>....] - ETA: 0s - loss: 3.6832e-04 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.19971
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 33/33 [==============================] - 0s 10ms/step - loss: 3.7568e-04 - accuracy: 1.0000 - val_loss: 0.3971 - val_accuracy: 0.9310 - lr: 1.0000e-05
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5180 - accuracy: 0.9028
# Test accuracy: 90.28%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('lstm_9.h5')

predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 5/5 [==============================] - 0s 4ms/step
# ([<matplotlib.axis.YTick at 0x7ff3bc76bcd0>,
#   <matplotlib.axis.YTick at 0x7ff3bc78c250>,
#   <matplotlib.axis.YTick at 0x7ff3bc76bac0>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
