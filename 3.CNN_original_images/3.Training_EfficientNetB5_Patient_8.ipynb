# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2 as cv
import math

from sklearn import preprocessing
import datetime

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import EfficientNetB5, preprocess_input
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint,ReduceLROnPlateau

from sklearn.model_selection import train_test_split

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="2"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
df = pd.read_csv('Label_Training.csv')
df.head()
# Out:
#    video_num    image infection  patient  class_label  \
# 0          1  246.tif        ca        1            0
# 1          1  094.tif        ca        1            0
# 2          1  158.tif        ca        1            0
# 3          1  062.tif        ca        1            0
# 4          1  174.tif        ca        1            0
#
#                               image_path
# 0  /asbdata/Arjun/Bloodi/TIFF8/1/246.tif
# 1  /asbdata/Arjun/Bloodi/TIFF8/1/094.tif
# 2  /asbdata/Arjun/Bloodi/TIFF8/1/158.tif
# 3  /asbdata/Arjun/Bloodi/TIFF8/1/062.tif
# 4  /asbdata/Arjun/Bloodi/TIFF8/1/174.tif

# %%
test = df[(df['patient']==11)]
test
# Out:
#       video_num    image infection  patient  class_label  \
# 5460         30  246.tif        ca       11            0
# 5461         30  094.tif        ca       11            0
# 5462         30  158.tif        ca       11            0
# 5463         30  062.tif        ca       11            0
# 5464         30  174.tif        ca       11            0
# ...         ...      ...       ...      ...          ...
# 6235         32  177.tif      mock       11            2
# 6236         32  066.tif      mock       11            2
# 6237         32  042.tif      mock       11            2
# 6238         32  250.tif      mock       11            2
# 6239         32  227.tif      mock       11            2
#
#                                   image_path
# 5460  /asbdata/Arjun/Bloodi/TIFF8/30/246.tif
# 5461  /asbdata/Arjun/Bloodi/TIFF8/30/094.tif
# 5462  /asbdata/Arjun/Bloodi/TIFF8/30/158.tif
# 5463  /asbdata/Arjun/Bloodi/TIFF8/30/062.tif
# 5464  /asbdata/Arjun/Bloodi/TIFF8/30/174.tif
# ...                                      ...
# 6235  /asbdata/Arjun/Bloodi/TIFF8/32/177.tif
# 6236  /asbdata/Arjun/Bloodi/TIFF8/32/066.tif
# 6237  /asbdata/Arjun/Bloodi/TIFF8/32/042.tif
# 6238  /asbdata/Arjun/Bloodi/TIFF8/32/250.tif
# 6239  /asbdata/Arjun/Bloodi/TIFF8/32/227.tif
#
# [780 rows x 6 columns]

# %%
Xtrain = pd.concat([df, test]).drop_duplicates(keep=False)
Xtrain
# Out:
#       video_num    image infection  patient  class_label  \
# 0             1  246.tif        ca        1            0
# 1             1  094.tif        ca        1            0
# 2             1  158.tif        ca        1            0
# 3             1  062.tif        ca        1            0
# 4             1  174.tif        ca        1            0
# ...         ...      ...       ...      ...          ...
# 7015         35  177.tif      mock       12            2
# 7016         35  066.tif      mock       12            2
# 7017         35  042.tif      mock       12            2
# 7018         35  250.tif      mock       12            2
# 7019         35  227.tif      mock       12            2
#
#                                   image_path
# 0      /asbdata/Arjun/Bloodi/TIFF8/1/246.tif
# 1      /asbdata/Arjun/Bloodi/TIFF8/1/094.tif
# 2      /asbdata/Arjun/Bloodi/TIFF8/1/158.tif
# 3      /asbdata/Arjun/Bloodi/TIFF8/1/062.tif
# 4      /asbdata/Arjun/Bloodi/TIFF8/1/174.tif
# ...                                      ...
# 7015  /asbdata/Arjun/Bloodi/TIFF8/35/177.tif
# 7016  /asbdata/Arjun/Bloodi/TIFF8/35/066.tif
# 7017  /asbdata/Arjun/Bloodi/TIFF8/35/042.tif
# 7018  /asbdata/Arjun/Bloodi/TIFF8/35/250.tif
# 7019  /asbdata/Arjun/Bloodi/TIFF8/35/227.tif
#
# [6240 rows x 6 columns]

# %%
train, val = train_test_split(Xtrain, test_size=0.2, stratify = Xtrain['class_label'], random_state=42)
train
# Out:
#       video_num    image infection  patient  class_label  \
# 542           3  186.tif      mock        1            2
# 2679         19  178.tif        cg        7            1
# 2748         19  107.tif        cg        7            1
# 888           4  142.tif        ca        2            0
# 3739         23  197.tif      mock        8            2
# ...         ...      ...       ...      ...          ...
# 2231         15  140.tif      mock        5            2
# 902           4  189.tif        ca        2            0
# 6588         34  115.tif        cg       12            1
# 3484         22  179.tif        cg        8            1
# 4893         27  088.tif        ca       10            0
#
#                                   image_path
# 542    /asbdata/Arjun/Bloodi/TIFF8/3/186.tif
# 2679  /asbdata/Arjun/Bloodi/TIFF8/19/178.tif
# 2748  /asbdata/Arjun/Bloodi/TIFF8/19/107.tif
# 888    /asbdata/Arjun/Bloodi/TIFF8/4/142.tif
# 3739  /asbdata/Arjun/Bloodi/TIFF8/23/197.tif
# ...                                      ...
# 2231  /asbdata/Arjun/Bloodi/TIFF8/15/140.tif
# 902    /asbdata/Arjun/Bloodi/TIFF8/4/189.tif
# 6588  /asbdata/Arjun/Bloodi/TIFF8/34/115.tif
# 3484  /asbdata/Arjun/Bloodi/TIFF8/22/179.tif
# 4893  /asbdata/Arjun/Bloodi/TIFF8/27/088.tif
#
# [4992 rows x 6 columns]

# %%
val
# Out:
#       video_num    image infection  patient  class_label  \
# 5072         28  069.tif        cg       10            1
# 6462         33  056.tif        ca       12            0
# 1273          5  233.tif        cg        2            1
# 2431         18  051.tif        ca        7            0
# 926           4  039.tif        ca        2            0
# ...         ...      ...       ...      ...          ...
# 3144         21  098.tif        ca        8            0
# 5128         28  103.tif        cg       10            1
# 3572         22  072.tif        cg        8            1
# 3149         21  161.tif        ca        8            0
# 986           4  089.tif        ca        2            0
#
#                                   image_path
# 5072  /asbdata/Arjun/Bloodi/TIFF8/28/069.tif
# 6462  /asbdata/Arjun/Bloodi/TIFF8/33/056.tif
# 1273   /asbdata/Arjun/Bloodi/TIFF8/5/233.tif
# 2431  /asbdata/Arjun/Bloodi/TIFF8/18/051.tif
# 926    /asbdata/Arjun/Bloodi/TIFF8/4/039.tif
# ...                                      ...
# 3144  /asbdata/Arjun/Bloodi/TIFF8/21/098.tif
# 5128  /asbdata/Arjun/Bloodi/TIFF8/28/103.tif
# 3572  /asbdata/Arjun/Bloodi/TIFF8/22/072.tif
# 3149  /asbdata/Arjun/Bloodi/TIFF8/21/161.tif
# 986    /asbdata/Arjun/Bloodi/TIFF8/4/089.tif
#
# [1248 rows x 6 columns]

# %%
image_size = 512
batch_size = 16

def get_train_generator(df, x_col, y_cols, shuffle=True, batch_size=batch_size, seed=1, image_size=image_size):

    # normalize images
    image_generator = ImageDataGenerator(preprocessing_function=preprocess_input,
                                        horizontal_flip=True,
                                        vertical_flip=True)
    
    # flow from directory with specified batch size
    # and target image size
    generator = image_generator.flow_from_dataframe(
            dataframe=df,
            directory=None,
            x_col=x_col,
            y_col=y_cols,
            class_mode="raw",
            batch_size=batch_size,
            target_size=(image_size,image_size),
            shuffle=False,
            seed=seed)
    
    return generator

def get_test_and_valid_generator(valid_df, test_df, x_col, y_cols, batch_size=batch_size, seed=1, image_size=image_size):

    image_generator = ImageDataGenerator(preprocessing_function=preprocess_input)


    # get test generator
    valid_generator = image_generator.flow_from_dataframe(
            dataframe=valid_df,
            directory=None,
            x_col=x_col,
            y_col=y_cols,
            class_mode="raw",
            batch_size=batch_size,
            target_size = (image_size,image_size),
            shuffle=False,
            seed=seed)
    
    test_generator = image_generator.flow_from_dataframe(
            dataframe=test_df,
            directory=None,
            x_col=x_col,
            y_col=y_cols,
            class_mode="raw",
            batch_size=batch_size,
            target_size = (image_size,image_size),
            shuffle=False,
            seed=seed)
    
    return valid_generator, test_generator

# %%
train_generator = get_train_generator(train, 'image_path', 'class_label')
valid_generator, test_generator= get_test_and_valid_generator(val, test, 'image_path','class_label')
# Out:
# Found 4992 validated image filenames.
# Found 1248 validated image filenames.
# Found 780 validated image filenames.

# %%
x, y = train_generator.__getitem__(3)
plt.imshow(x[0])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
x, y = valid_generator.__getitem__(3)
plt.imshow(x[0])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
x, y = test_generator.__getitem__(3)
plt.imshow(x[0])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
with strategy.scope():
    
    inputs = Input(shape=(image_size,image_size, 3))
    base_model = EfficientNetB5 (weights = 'imagenet',include_top=False, input_tensor=inputs)

    # add a global spatial average pooling layer
    x = GlobalAveragePooling2D()(base_model.output)

    x = Dense(1024, kernel_regularizer=l2(0.0003),activation='relu')(x)
    x = Dropout(0.5)(x)

    # and a logistic layer
    predictions = Dense(3, activation="softmax")(x)
    
    model = Model(inputs=inputs, outputs=predictions)
    
    model.compile(optimizer=tf.keras.optimizers.Adam(), 
                  loss="sparse_categorical_crossentropy", 
                  metrics=["accuracy"])
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 512, 512, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 512, 512, 3)  7           ['rescaling[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 512, 512, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 513, 513, 3)  0           ['tf.math.truediv[0][0]']
#
#  stem_conv (Conv2D)             (None, 256, 256, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 256, 256, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 256, 256, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 256, 256, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 256, 256, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 256, 256, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 256, 256, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 256, 256, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 256, 256, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 256, 256, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 256, 256, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 256, 256, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 256, 256, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 256, 256, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 256, 256, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#  block1c_dwconv (DepthwiseConv2  (None, 256, 256, 24  216        ['block1b_add[0][0]']
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 256, 256, 24  96         ['block1c_dwconv[0][0]']
#  )                              )
#
#  block1c_activation (Activation  (None, 256, 256, 24  0          ['block1c_bn[0][0]']
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 24)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 256, 256, 24  0           ['block1c_activation[0][0]',
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 256, 256, 24  576         ['block1c_se_excite[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_drop (Dropout)         (None, 256, 256, 24  0           ['block1c_project_bn[0][0]']
#                                 )
#
#  block1c_add (Add)              (None, 256, 256, 24  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 256, 256, 14  3456        ['block1c_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 256, 256, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 256, 256, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 257, 257, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 128, 128, 14  1296       ['block2a_dwconv_pad[0][0]']
#  D)                             4)
#
#  block2a_bn (BatchNormalization  (None, 128, 128, 14  576        ['block2a_dwconv[0][0]']
#  )                              4)
#
#  block2a_activation (Activation  (None, 128, 128, 14  0          ['block2a_bn[0][0]']
#  )                              4)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 128, 128, 14  0           ['block2a_activation[0][0]',
#                                 4)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 128, 128, 40  5760        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2a_project_bn[0][0]']
#                                 0)
#
#  block2b_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block2b_expand_conv[0][0]']
#  ization)                       0)
#
#  block2b_expand_activation (Act  (None, 128, 128, 24  0          ['block2b_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2b_dwconv (DepthwiseConv2  (None, 128, 128, 24  2160       ['block2b_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2b_bn (BatchNormalization  (None, 128, 128, 24  960        ['block2b_dwconv[0][0]']
#  )                              0)
#
#  block2b_activation (Activation  (None, 128, 128, 24  0          ['block2b_bn[0][0]']
#  )                              0)
#
#  block2b_se_squeeze (GlobalAver  (None, 240)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 128, 128, 24  0           ['block2b_activation[0][0]',
#                                 0)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 128, 128, 40  9600        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 128, 128, 40  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 128, 128, 40  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2b_add[0][0]']
#                                 0)
#
#  block2c_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block2c_expand_conv[0][0]']
#  ization)                       0)
#
#  block2c_expand_activation (Act  (None, 128, 128, 24  0          ['block2c_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2c_dwconv (DepthwiseConv2  (None, 128, 128, 24  2160       ['block2c_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2c_bn (BatchNormalization  (None, 128, 128, 24  960        ['block2c_dwconv[0][0]']
#  )                              0)
#
#  block2c_activation (Activation  (None, 128, 128, 24  0          ['block2c_bn[0][0]']
#  )                              0)
#
#  block2c_se_squeeze (GlobalAver  (None, 240)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 128, 128, 24  0           ['block2c_activation[0][0]',
#                                 0)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 128, 128, 40  9600        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 128, 128, 40  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 128, 128, 40  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2c_add[0][0]']
#                                 0)
#
#  block2d_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block2d_expand_conv[0][0]']
#  ization)                       0)
#
#  block2d_expand_activation (Act  (None, 128, 128, 24  0          ['block2d_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2d_dwconv (DepthwiseConv2  (None, 128, 128, 24  2160       ['block2d_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2d_bn (BatchNormalization  (None, 128, 128, 24  960        ['block2d_dwconv[0][0]']
#  )                              0)
#
#  block2d_activation (Activation  (None, 128, 128, 24  0          ['block2d_bn[0][0]']
#  )                              0)
#
#  block2d_se_squeeze (GlobalAver  (None, 240)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 128, 128, 24  0           ['block2d_activation[0][0]',
#                                 0)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 128, 128, 40  9600        ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 128, 128, 40  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 128, 128, 40  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2d_add[0][0]']
#                                 0)
#
#  block2e_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block2e_expand_conv[0][0]']
#  ization)                       0)
#
#  block2e_expand_activation (Act  (None, 128, 128, 24  0          ['block2e_expand_bn[0][0]']
#  ivation)                       0)
#
#  block2e_dwconv (DepthwiseConv2  (None, 128, 128, 24  2160       ['block2e_expand_activation[0][0]
#  D)                             0)                               ']
#
#  block2e_bn (BatchNormalization  (None, 128, 128, 24  960        ['block2e_dwconv[0][0]']
#  )                              0)
#
#  block2e_activation (Activation  (None, 128, 128, 24  0          ['block2e_bn[0][0]']
#  )                              0)
#
#  block2e_se_squeeze (GlobalAver  (None, 240)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 128, 128, 24  0           ['block2e_activation[0][0]',
#                                 0)                                'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 128, 128, 40  9600        ['block2e_se_excite[0][0]']
#                                 )
#
#  block2e_project_bn (BatchNorma  (None, 128, 128, 40  160        ['block2e_project_conv[0][0]']
#  lization)                      )
#
#  block2e_drop (Dropout)         (None, 128, 128, 40  0           ['block2e_project_bn[0][0]']
#                                 )
#
#  block2e_add (Add)              (None, 128, 128, 40  0           ['block2e_drop[0][0]',
#                                 )                                 'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 128, 128, 24  9600        ['block2e_add[0][0]']
#                                 0)
#
#  block3a_expand_bn (BatchNormal  (None, 128, 128, 24  960        ['block3a_expand_conv[0][0]']
#  ization)                       0)
#
#  block3a_expand_activation (Act  (None, 128, 128, 24  0          ['block3a_expand_bn[0][0]']
#  ivation)                       0)
#  block3a_dwconv_pad (ZeroPaddin  (None, 131, 131, 24  0          ['block3a_expand_activation[0][0]
#  g2D)                           0)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 64, 64, 240)  6000       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 64, 64, 240)  960        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 64, 64, 240)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 240)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 64, 64, 240)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 64, 64, 64)   15360       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 64, 64, 384)  24576       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 64, 64, 384)  1536       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 64, 64, 384)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 64, 64, 384)  9600       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 64, 64, 384)  1536       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 64, 64, 384)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 384)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 64, 64, 384)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 64, 64, 64)   24576       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 64, 64, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 64, 64, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 64, 64, 384)  24576       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 64, 64, 384)  1536       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 64, 64, 384)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 64, 64, 384)  9600       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 64, 64, 384)  1536       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 64, 64, 384)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 384)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 64, 64, 384)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 64, 64, 64)   24576       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 64, 64, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 64, 64, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 64, 64, 384)  24576       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 64, 64, 384)  1536       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 64, 64, 384)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 64, 64, 384)  9600       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 64, 64, 384)  1536       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 64, 64, 384)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 384)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 16)     6160        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 384)    6528        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 64, 64, 384)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 64, 64, 64)   24576       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 64, 64, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 64, 64, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 64, 64, 384)  24576       ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 64, 64, 384)  1536       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 64, 64, 384)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_dwconv (DepthwiseConv2  (None, 64, 64, 384)  9600       ['block3e_expand_activation[0][0]
# ...
#  )                              )
#
#  block6i_se_squeeze (GlobalAver  (None, 1824)        0           ['block6i_activation[0][0]']
#  agePooling2D)
#
#  block6i_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block6i_se_squeeze[0][0]']
#
#  block6i_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multiply)   (None, 16, 16, 1824  0           ['block6i_activation[0][0]',
#                                 )                                 'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv2D)  (None, 16, 16, 304)  554496      ['block6i_se_excite[0][0]']
#
#  block6i_project_bn (BatchNorma  (None, 16, 16, 304)  1216       ['block6i_project_conv[0][0]']
#  lization)
#
#  block6i_drop (Dropout)         (None, 16, 16, 304)  0           ['block6i_project_bn[0][0]']
#
#  block6i_add (Add)              (None, 16, 16, 304)  0           ['block6i_drop[0][0]',
#                                                                   'block6h_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 16, 16, 1824  554496      ['block6i_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 16, 16, 1824  7296       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 16, 16, 1824  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 16, 16, 1824  16416      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 16, 16, 1824  7296       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 16, 16, 1824  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1824)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1824)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 76)     138700      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1824)   140448      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 16, 16, 1824  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 16, 16, 512)  933888      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 16, 16, 3072  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 16, 16, 3072  27648      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 16, 16, 3072  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 3072)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 16, 16, 512)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 16, 16, 512)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 16, 16, 3072  1572864     ['block7b_add[0][0]']
#                                 )
#
#  block7c_expand_bn (BatchNormal  (None, 16, 16, 3072  12288      ['block7c_expand_conv[0][0]']
#  ization)                       )
#
#  block7c_expand_activation (Act  (None, 16, 16, 3072  0          ['block7c_expand_bn[0][0]']
#  ivation)                       )
#
#  block7c_dwconv (DepthwiseConv2  (None, 16, 16, 3072  27648      ['block7c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7c_bn (BatchNormalization  (None, 16, 16, 3072  12288      ['block7c_dwconv[0][0]']
#  )                              )
#
#  block7c_activation (Activation  (None, 16, 16, 3072  0          ['block7c_bn[0][0]']
#  )                              )
#
#  block7c_se_squeeze (GlobalAver  (None, 3072)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 16, 16, 3072  0           ['block7c_activation[0][0]',
#                                 )                                 'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 16, 16, 512)  1572864     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 16, 16, 512)  2048       ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 16, 16, 512)  0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 16, 16, 512)  0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  top_conv (Conv2D)              (None, 16, 16, 2048  1048576     ['block7c_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 16, 16, 2048  8192        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 16, 16, 2048  0           ['top_bn[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['top_activation[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1024)         2098176     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 3)            3075        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 30,614,778
# Trainable params: 30,442,035
# Non-trainable params: 172,743
# __________________________________________________________________________________________________

# %%
lr_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3)

stopping = EarlyStopping(monitor='val_loss', patience=5)

callbacks = ModelCheckpoint('efficient_fullimage_test_8.h5', 
                            monitor='val_loss', save_best_only=True, mode = 'auto')

# %%
history = model.fit(train_generator, 
                              validation_data=valid_generator,
                              epochs = 10,
                              callbacks = [callbacks,lr_schedule,stopping])
# Out:
# Epoch 1/10
# 312/312 [==============================] - 482s 1s/step - loss: 0.5618 - accuracy: 0.9177 - val_loss: 0.3414 - val_accuracy: 0.9519 - lr: 0.0010
# Epoch 2/10
# 312/312 [==============================] - 447s 1s/step - loss: 0.2635 - accuracy: 0.9623 - val_loss: 0.1049 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/10
# 312/312 [==============================] - 445s 1s/step - loss: 0.1405 - accuracy: 0.9782 - val_loss: 0.0744 - val_accuracy: 0.9928 - lr: 0.0010
# Epoch 4/10
# 312/312 [==============================] - 442s 1s/step - loss: 0.1137 - accuracy: 0.9810 - val_loss: 0.3711 - val_accuracy: 0.9279 - lr: 0.0010
# Epoch 5/10
# 312/312 [==============================] - 444s 1s/step - loss: 0.0690 - accuracy: 0.9892 - val_loss: 0.5477 - val_accuracy: 0.7877 - lr: 0.0010
# Epoch 6/10
# 312/312 [==============================] - 446s 1s/step - loss: 0.0851 - accuracy: 0.9846 - val_loss: 0.0321 - val_accuracy: 0.9992 - lr: 0.0010
# Epoch 7/10
# 312/312 [==============================] - 439s 1s/step - loss: 0.0460 - accuracy: 0.9932 - val_loss: 0.1226 - val_accuracy: 0.9808 - lr: 0.0010
# Epoch 8/10
# 312/312 [==============================] - 443s 1s/step - loss: 0.0836 - accuracy: 0.9816 - val_loss: 0.5445 - val_accuracy: 0.8558 - lr: 0.0010
# Epoch 9/10
# 312/312 [==============================] - 442s 1s/step - loss: 0.0776 - accuracy: 0.9864 - val_loss: 0.2725 - val_accuracy: 0.9399 - lr: 0.0010
# Epoch 10/10
# 312/312 [==============================] - 445s 1s/step - loss: 0.0374 - accuracy: 0.9974 - val_loss: 0.0237 - val_accuracy: 1.0000 - lr: 1.0000e-04

# %%
final_model = tf.keras.models.load_model('efficient_fullimage_test_8.h5')

# %%
predicted = final_model.predict(test_generator, steps = len(test_generator)).argmax(axis=1)
# Out:
# 49/49 [==============================] - 31s 584ms/step

# %%
test_labels = test['class_label']
test_labels = np.array(test_labels)

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# ([<matplotlib.axis.YTick at 0x7fe4e00e40d0>,
#   <matplotlib.axis.YTick at 0x7fe4e00d7a30>,
#   <matplotlib.axis.YTick at 0x7fe4e00ceb20>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])
