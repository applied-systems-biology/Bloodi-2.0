# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv
from sklearn.model_selection import train_test_split

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="6"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 1280
MAX_SEQ_LENGTH = 40
IMG_SIZE = 224

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==2)]
test
# Out:
#    Video_Num infection  Patient  Patient_id
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315
# 5          6      mock        2    20180315

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (9547, 40, 1280)
# (9547, 1)
# (1127, 40, 1280)
# (1127, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_2_split.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 1280)       51200
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 1280)       26247684
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 1280)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense_2 (Dense)             (None, 3)                 3843
#
# =================================================================
# Total params: 26,302,727
# Trainable params: 26,302,727
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 263/269 [============================>.] - ETA: 0s - loss: 1.1637 - accuracy: 0.5713
# Epoch 1: val_loss improved from inf to 0.65545, saving model to Transformer_2_split.h5
# 269/269 [==============================] - 11s 28ms/step - loss: 1.1590 - accuracy: 0.5716 - val_loss: 0.6554 - val_accuracy: 0.7654 - lr: 1.0000e-04
# Epoch 2/500
# 264/269 [============================>.] - ETA: 0s - loss: 0.6869 - accuracy: 0.7023
# Epoch 2: val_loss improved from 0.65545 to 0.63492, saving model to Transformer_2_split.h5
# 269/269 [==============================] - 5s 20ms/step - loss: 0.6894 - accuracy: 0.7010 - val_loss: 0.6349 - val_accuracy: 0.7571 - lr: 1.0000e-04
# Epoch 3/500
# 266/269 [============================>.] - ETA: 0s - loss: 0.6210 - accuracy: 0.7319
# Epoch 3: val_loss improved from 0.63492 to 0.62389, saving model to Transformer_2_split.h5
# 269/269 [==============================] - 5s 20ms/step - loss: 0.6207 - accuracy: 0.7317 - val_loss: 0.6239 - val_accuracy: 0.7749 - lr: 1.0000e-04
# Epoch 4/500
# 265/269 [============================>.] - ETA: 0s - loss: 0.5685 - accuracy: 0.7605
# Epoch 4: val_loss improved from 0.62389 to 0.61033, saving model to Transformer_2_split.h5
# 269/269 [==============================] - 6s 22ms/step - loss: 0.5670 - accuracy: 0.7611 - val_loss: 0.6103 - val_accuracy: 0.7927 - lr: 1.0000e-04
# Epoch 5/500
# 268/269 [============================>.] - ETA: 0s - loss: 0.5260 - accuracy: 0.7802
# Epoch 5: val_loss improved from 0.61033 to 0.48499, saving model to Transformer_2_split.h5
# 269/269 [==============================] - 5s 20ms/step - loss: 0.5263 - accuracy: 0.7803 - val_loss: 0.4850 - val_accuracy: 0.8199 - lr: 1.0000e-04
# Epoch 6/500
# 265/269 [============================>.] - ETA: 0s - loss: 0.4789 - accuracy: 0.8024
# Epoch 6: val_loss did not improve from 0.48499
# 269/269 [==============================] - 2s 9ms/step - loss: 0.4790 - accuracy: 0.8019 - val_loss: 0.6016 - val_accuracy: 0.7696 - lr: 1.0000e-04
# Epoch 7/500
# 265/269 [============================>.] - ETA: 0s - loss: 0.4473 - accuracy: 0.8153
# Epoch 7: val_loss did not improve from 0.48499
# 269/269 [==============================] - 2s 9ms/step - loss: 0.4485 - accuracy: 0.8149 - val_loss: 0.7549 - val_accuracy: 0.7529 - lr: 1.0000e-04
# Epoch 8/500
# 267/269 [============================>.] - ETA: 0s - loss: 0.4145 - accuracy: 0.8310
# Epoch 8: val_loss did not improve from 0.48499
# 269/269 [==============================] - 2s 9ms/step - loss: 0.4135 - accuracy: 0.8314 - val_loss: 0.6787 - val_accuracy: 0.7728 - lr: 1.0000e-04
# Epoch 9/500
# 263/269 [============================>.] - ETA: 0s - loss: 0.3919 - accuracy: 0.8380
# Epoch 9: val_loss did not improve from 0.48499
# 269/269 [==============================] - 2s 9ms/step - loss: 0.3916 - accuracy: 0.8379 - val_loss: 1.2699 - val_accuracy: 0.5696 - lr: 1.0000e-04
# Epoch 10/500
# 269/269 [==============================] - ETA: 0s - loss: 0.3508 - accuracy: 0.8568
# Epoch 10: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.3508 - accuracy: 0.8568 - val_loss: 0.8814 - val_accuracy: 0.7257 - lr: 1.0000e-04
# Epoch 11/500
# 266/269 [============================>.] - ETA: 0s - loss: 0.3295 - accuracy: 0.8681
# Epoch 11: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.3289 - accuracy: 0.8682 - val_loss: 1.0005 - val_accuracy: 0.6702 - lr: 1.0000e-04
# Epoch 12/500
# 268/269 [============================>.] - ETA: 0s - loss: 0.3096 - accuracy: 0.8726
# Epoch 12: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.3092 - accuracy: 0.8727 - val_loss: 1.0326 - val_accuracy: 0.7173 - lr: 1.0000e-04
# Epoch 13/500
# 266/269 [============================>.] - ETA: 0s - loss: 0.2866 - accuracy: 0.8864
# Epoch 13: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.2855 - accuracy: 0.8866 - val_loss: 0.9152 - val_accuracy: 0.7403 - lr: 1.0000e-04
# Epoch 14/500
# 268/269 [============================>.] - ETA: 0s - loss: 0.2562 - accuracy: 0.8961
# Epoch 14: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.2564 - accuracy: 0.8959 - val_loss: 1.1733 - val_accuracy: 0.6995 - lr: 1.0000e-04
# Epoch 15/500
# 265/269 [============================>.] - ETA: 0s - loss: 0.2370 - accuracy: 0.9052
# Epoch 15: val_loss did not improve from 0.48499
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 269/269 [==============================] - 3s 10ms/step - loss: 0.2370 - accuracy: 0.9054 - val_loss: 1.0964 - val_accuracy: 0.7529 - lr: 1.0000e-04
# Epoch 16/500
# 266/269 [============================>.] - ETA: 0s - loss: 0.1532 - accuracy: 0.9416
# Epoch 16: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.1532 - accuracy: 0.9416 - val_loss: 1.1658 - val_accuracy: 0.7770 - lr: 1.0000e-05
# Epoch 17/500
# 264/269 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9534
# Epoch 17: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.1295 - accuracy: 0.9531 - val_loss: 1.4746 - val_accuracy: 0.7529 - lr: 1.0000e-05
# Epoch 18/500
# 267/269 [============================>.] - ETA: 0s - loss: 0.1206 - accuracy: 0.9553
# Epoch 18: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.1203 - accuracy: 0.9552 - val_loss: 1.5797 - val_accuracy: 0.7539 - lr: 1.0000e-05
# Epoch 19/500
# 265/269 [============================>.] - ETA: 0s - loss: 0.1150 - accuracy: 0.9586
# Epoch 19: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.1150 - accuracy: 0.9586 - val_loss: 1.8601 - val_accuracy: 0.7487 - lr: 1.0000e-05
# Epoch 20/500
# 267/269 [============================>.] - ETA: 0s - loss: 0.1073 - accuracy: 0.9597
# Epoch 20: val_loss did not improve from 0.48499
# 269/269 [==============================] - 2s 9ms/step - loss: 0.1071 - accuracy: 0.9597 - val_loss: 1.9959 - val_accuracy: 0.7173 - lr: 1.0000e-05
# Epoch 21/500
# 268/269 [============================>.] - ETA: 0s - loss: 0.0979 - accuracy: 0.9625
# Epoch 21: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0977 - accuracy: 0.9625 - val_loss: 2.2901 - val_accuracy: 0.7257 - lr: 1.0000e-05
# Epoch 22/500
# 264/269 [============================>.] - ETA: 0s - loss: 0.0987 - accuracy: 0.9624
# Epoch 22: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0985 - accuracy: 0.9624 - val_loss: 2.3237 - val_accuracy: 0.7079 - lr: 1.0000e-05
# Epoch 23/500
# 264/269 [============================>.] - ETA: 0s - loss: 0.0924 - accuracy: 0.9667
# Epoch 23: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0919 - accuracy: 0.9669 - val_loss: 2.1828 - val_accuracy: 0.7487 - lr: 1.0000e-05
# Epoch 24/500
# 269/269 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9692
# Epoch 24: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0856 - accuracy: 0.9692 - val_loss: 2.1205 - val_accuracy: 0.7550 - lr: 1.0000e-05
# Epoch 25/500
# 263/269 [============================>.] - ETA: 0s - loss: 0.0807 - accuracy: 0.9702
# Epoch 25: val_loss did not improve from 0.48499
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0803 - accuracy: 0.9704 - val_loss: 2.1733 - val_accuracy: 0.7539 - lr: 1.0000e-05
# Epoch 26/500
# 265/269 [============================>.] - ETA: 0s - loss: 0.0697 - accuracy: 0.9738
# Epoch 26: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0696 - accuracy: 0.9739 - val_loss: 2.3399 - val_accuracy: 0.7424 - lr: 1.0000e-06
# Epoch 27/500
# 264/269 [============================>.] - ETA: 0s - loss: 0.0686 - accuracy: 0.9762
# Epoch 27: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0698 - accuracy: 0.9757 - val_loss: 2.3917 - val_accuracy: 0.7445 - lr: 1.0000e-06
# Epoch 28/500
# 266/269 [============================>.] - ETA: 0s - loss: 0.0678 - accuracy: 0.9758
# Epoch 28: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0681 - accuracy: 0.9756 - val_loss: 2.4718 - val_accuracy: 0.7445 - lr: 1.0000e-06
# Epoch 29/500
# 265/269 [============================>.] - ETA: 0s - loss: 0.0638 - accuracy: 0.9775
# Epoch 29: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0636 - accuracy: 0.9777 - val_loss: 2.5828 - val_accuracy: 0.7403 - lr: 1.0000e-06
# Epoch 30/500
# 264/269 [============================>.] - ETA: 0s - loss: 0.0668 - accuracy: 0.9766
# Epoch 30: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0672 - accuracy: 0.9763 - val_loss: 2.7094 - val_accuracy: 0.7351 - lr: 1.0000e-06
# Epoch 31/500
# 264/269 [============================>.] - ETA: 0s - loss: 0.0652 - accuracy: 0.9773
# Epoch 31: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 11ms/step - loss: 0.0653 - accuracy: 0.9771 - val_loss: 2.6330 - val_accuracy: 0.7372 - lr: 1.0000e-06
# Epoch 32/500
# 269/269 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9770
# Epoch 32: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0641 - accuracy: 0.9770 - val_loss: 2.7670 - val_accuracy: 0.7330 - lr: 1.0000e-06
# Epoch 33/500
# 265/269 [============================>.] - ETA: 0s - loss: 0.0676 - accuracy: 0.9752
# Epoch 33: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0671 - accuracy: 0.9756 - val_loss: 2.7049 - val_accuracy: 0.7403 - lr: 1.0000e-06
# Epoch 34/500
# 263/269 [============================>.] - ETA: 0s - loss: 0.0639 - accuracy: 0.9768
# Epoch 34: val_loss did not improve from 0.48499
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0636 - accuracy: 0.9770 - val_loss: 2.7788 - val_accuracy: 0.7403 - lr: 1.0000e-06
# Epoch 35/500
# 267/269 [============================>.] - ETA: 0s - loss: 0.0607 - accuracy: 0.9768
# Epoch 35: val_loss did not improve from 0.48499
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 269/269 [==============================] - 3s 10ms/step - loss: 0.0605 - accuracy: 0.9770 - val_loss: 2.8287 - val_accuracy: 0.7403 - lr: 1.0000e-06
# 36/36 [==============================] - 0s 4ms/step - loss: 1.1519 - accuracy: 0.5297
# Test accuracy: 52.97%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_2_split.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 36/36 [==============================] - 1s 4ms/step
# ([<matplotlib.axis.YTick at 0x7f4aa41b3190>,
#   <matplotlib.axis.YTick at 0x7f4aa4274c70>,
#   <matplotlib.axis.YTick at 0x7f4aa4261d60>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])

# %%
target_names = ["$\it{C. albicans}$","$\it{C. glabrata}$","Mock"]

# %%
import seaborn as sns

cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cmn, cmap="flare",linewidths= 0.5,
            annot=True,xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/2_norm.png',dpi=300,bbox_inches='tight')

# %%
cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cm, cmap="flare",linewidths= 0.5,
            annot=True,fmt ='g',xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/2_all.png',dpi=300,bbox_inches='tight')
