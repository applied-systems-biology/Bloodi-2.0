# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv
from sklearn.model_selection import train_test_split

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="5"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 1280
MAX_SEQ_LENGTH = 40
IMG_SIZE = 224

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==5)]
test
# Out:
#    Video_Num infection  Patient  Patient_id
# 6         13        ca        5    20180409
# 7         14        cg        5    20180409
# 8         15      mock        5    20180409

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (9468, 40, 1280)
# (9468, 1)
# (1206, 40, 1280)
# (1206, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_3_split.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 1280)       51200
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 1280)       26247684
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 1280)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense_2 (Dense)             (None, 3)                 3843
#
# =================================================================
# Total params: 26,302,727
# Trainable params: 26,302,727
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 261/267 [============================>.] - ETA: 0s - loss: 1.1969 - accuracy: 0.5480
# Epoch 1: val_loss improved from inf to 0.60021, saving model to Transformer_3_split.h5
# 267/267 [==============================] - 9s 23ms/step - loss: 1.1901 - accuracy: 0.5497 - val_loss: 0.6002 - val_accuracy: 0.8173 - lr: 1.0000e-04
# Epoch 2/500
# 262/267 [============================>.] - ETA: 0s - loss: 0.7602 - accuracy: 0.6554
# Epoch 2: val_loss improved from 0.60021 to 0.45685, saving model to Transformer_3_split.h5
# 267/267 [==============================] - 5s 20ms/step - loss: 0.7589 - accuracy: 0.6553 - val_loss: 0.4569 - val_accuracy: 0.8374 - lr: 1.0000e-04
# Epoch 3/500
# 265/267 [============================>.] - ETA: 0s - loss: 0.6894 - accuracy: 0.6949
# Epoch 3: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 12ms/step - loss: 0.6892 - accuracy: 0.6950 - val_loss: 0.6709 - val_accuracy: 0.7825 - lr: 1.0000e-04
# Epoch 4/500
# 265/267 [============================>.] - ETA: 0s - loss: 0.6209 - accuracy: 0.7289
# Epoch 4: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.6207 - accuracy: 0.7288 - val_loss: 0.5895 - val_accuracy: 0.8015 - lr: 1.0000e-04
# Epoch 5/500
# 267/267 [==============================] - ETA: 0s - loss: 0.5700 - accuracy: 0.7558
# Epoch 5: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.5700 - accuracy: 0.7558 - val_loss: 0.7254 - val_accuracy: 0.7497 - lr: 1.0000e-04
# Epoch 6/500
# 265/267 [============================>.] - ETA: 0s - loss: 0.5516 - accuracy: 0.7625
# Epoch 6: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.5511 - accuracy: 0.7628 - val_loss: 0.5420 - val_accuracy: 0.8141 - lr: 1.0000e-04
# Epoch 7/500
# 266/267 [============================>.] - ETA: 0s - loss: 0.4983 - accuracy: 0.7896
# Epoch 7: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.4988 - accuracy: 0.7892 - val_loss: 0.7911 - val_accuracy: 0.7001 - lr: 1.0000e-04
# Epoch 8/500
# 266/267 [============================>.] - ETA: 0s - loss: 0.4688 - accuracy: 0.8025
# Epoch 8: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 11ms/step - loss: 0.4686 - accuracy: 0.8026 - val_loss: 0.5157 - val_accuracy: 0.8057 - lr: 1.0000e-04
# Epoch 9/500
# 262/267 [============================>.] - ETA: 0s - loss: 0.4340 - accuracy: 0.8175
# Epoch 9: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.4316 - accuracy: 0.8188 - val_loss: 0.6785 - val_accuracy: 0.7635 - lr: 1.0000e-04
# Epoch 10/500
# 266/267 [============================>.] - ETA: 0s - loss: 0.4031 - accuracy: 0.8307
# Epoch 10: val_loss did not improve from 0.45685
# 267/267 [==============================] - 2s 9ms/step - loss: 0.4035 - accuracy: 0.8307 - val_loss: 0.4743 - val_accuracy: 0.8437 - lr: 1.0000e-04
# Epoch 11/500
# 266/267 [============================>.] - ETA: 0s - loss: 0.3646 - accuracy: 0.8482
# Epoch 11: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.3645 - accuracy: 0.8481 - val_loss: 0.8740 - val_accuracy: 0.7402 - lr: 1.0000e-04
# Epoch 12/500
# 266/267 [============================>.] - ETA: 0s - loss: 0.3443 - accuracy: 0.8574
# Epoch 12: val_loss did not improve from 0.45685
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 267/267 [==============================] - 3s 10ms/step - loss: 0.3441 - accuracy: 0.8574 - val_loss: 0.9551 - val_accuracy: 0.6885 - lr: 1.0000e-04
# Epoch 13/500
# 262/267 [============================>.] - ETA: 0s - loss: 0.2426 - accuracy: 0.9064
# Epoch 13: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.2423 - accuracy: 0.9062 - val_loss: 0.9289 - val_accuracy: 0.7709 - lr: 1.0000e-05
# Epoch 14/500
# 262/267 [============================>.] - ETA: 0s - loss: 0.2228 - accuracy: 0.9141
# Epoch 14: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.2226 - accuracy: 0.9137 - val_loss: 1.0470 - val_accuracy: 0.7719 - lr: 1.0000e-05
# Epoch 15/500
# 265/267 [============================>.] - ETA: 0s - loss: 0.2083 - accuracy: 0.9175
# Epoch 15: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.2084 - accuracy: 0.9174 - val_loss: 1.4221 - val_accuracy: 0.7202 - lr: 1.0000e-05
# Epoch 16/500
# 266/267 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9200
# Epoch 16: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.2041 - accuracy: 0.9201 - val_loss: 1.4808 - val_accuracy: 0.7086 - lr: 1.0000e-05
# Epoch 17/500
# 264/267 [============================>.] - ETA: 0s - loss: 0.1940 - accuracy: 0.9242
# Epoch 17: val_loss did not improve from 0.45685
# 267/267 [==============================] - 2s 9ms/step - loss: 0.1946 - accuracy: 0.9238 - val_loss: 1.7083 - val_accuracy: 0.6790 - lr: 1.0000e-05
# Epoch 18/500
# 267/267 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.9283
# Epoch 18: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.1871 - accuracy: 0.9283 - val_loss: 1.6546 - val_accuracy: 0.7128 - lr: 1.0000e-05
# Epoch 19/500
# 263/267 [============================>.] - ETA: 0s - loss: 0.1794 - accuracy: 0.9289
# Epoch 19: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.1794 - accuracy: 0.9291 - val_loss: 1.5096 - val_accuracy: 0.7508 - lr: 1.0000e-05
# Epoch 20/500
# 263/267 [============================>.] - ETA: 0s - loss: 0.1757 - accuracy: 0.9327
# Epoch 20: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.1746 - accuracy: 0.9333 - val_loss: 1.9623 - val_accuracy: 0.7086 - lr: 1.0000e-05
# Epoch 21/500
# 267/267 [==============================] - ETA: 0s - loss: 0.1719 - accuracy: 0.9338
# Epoch 21: val_loss did not improve from 0.45685
# 267/267 [==============================] - 2s 9ms/step - loss: 0.1719 - accuracy: 0.9338 - val_loss: 2.0003 - val_accuracy: 0.7022 - lr: 1.0000e-05
# Epoch 22/500
# 267/267 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 0.9374
# Epoch 22: val_loss did not improve from 0.45685
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 267/267 [==============================] - 3s 10ms/step - loss: 0.1601 - accuracy: 0.9374 - val_loss: 1.9153 - val_accuracy: 0.6864 - lr: 1.0000e-05
# Epoch 23/500
# 265/267 [============================>.] - ETA: 0s - loss: 0.1516 - accuracy: 0.9441
# Epoch 23: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.1517 - accuracy: 0.9439 - val_loss: 1.8855 - val_accuracy: 0.7170 - lr: 1.0000e-06
# Epoch 24/500
# 266/267 [============================>.] - ETA: 0s - loss: 0.1445 - accuracy: 0.9463
# Epoch 24: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.1446 - accuracy: 0.9463 - val_loss: 1.9462 - val_accuracy: 0.7223 - lr: 1.0000e-06
# Epoch 25/500
# 264/267 [============================>.] - ETA: 0s - loss: 0.1439 - accuracy: 0.9466
# Epoch 25: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 11ms/step - loss: 0.1445 - accuracy: 0.9465 - val_loss: 1.9995 - val_accuracy: 0.7254 - lr: 1.0000e-06
# Epoch 26/500
# 263/267 [============================>.] - ETA: 0s - loss: 0.1425 - accuracy: 0.9471
# Epoch 26: val_loss did not improve from 0.45685
# 267/267 [==============================] - 2s 9ms/step - loss: 0.1425 - accuracy: 0.9472 - val_loss: 2.0645 - val_accuracy: 0.7202 - lr: 1.0000e-06
# Epoch 27/500
# 262/267 [============================>.] - ETA: 0s - loss: 0.1444 - accuracy: 0.9456
# Epoch 27: val_loss did not improve from 0.45685
# 267/267 [==============================] - 2s 9ms/step - loss: 0.1443 - accuracy: 0.9455 - val_loss: 2.1338 - val_accuracy: 0.7202 - lr: 1.0000e-06
# Epoch 28/500
# 262/267 [============================>.] - ETA: 0s - loss: 0.1417 - accuracy: 0.9480
# Epoch 28: val_loss did not improve from 0.45685
# 267/267 [==============================] - 2s 9ms/step - loss: 0.1418 - accuracy: 0.9479 - val_loss: 2.2402 - val_accuracy: 0.7086 - lr: 1.0000e-06
# Epoch 29/500
# 263/267 [============================>.] - ETA: 0s - loss: 0.1413 - accuracy: 0.9471
# Epoch 29: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.1413 - accuracy: 0.9470 - val_loss: 2.0881 - val_accuracy: 0.7381 - lr: 1.0000e-06
# Epoch 30/500
# 266/267 [============================>.] - ETA: 0s - loss: 0.1398 - accuracy: 0.9490
# Epoch 30: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.1399 - accuracy: 0.9489 - val_loss: 2.1901 - val_accuracy: 0.7265 - lr: 1.0000e-06
# Epoch 31/500
# 265/267 [============================>.] - ETA: 0s - loss: 0.1385 - accuracy: 0.9489
# Epoch 31: val_loss did not improve from 0.45685
# 267/267 [==============================] - 3s 10ms/step - loss: 0.1386 - accuracy: 0.9489 - val_loss: 2.1454 - val_accuracy: 0.7328 - lr: 1.0000e-06
# Epoch 32/500
# 261/267 [============================>.] - ETA: 0s - loss: 0.1350 - accuracy: 0.9531
# Epoch 32: val_loss did not improve from 0.45685
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 267/267 [==============================] - 3s 10ms/step - loss: 0.1349 - accuracy: 0.9527 - val_loss: 2.3817 - val_accuracy: 0.7086 - lr: 1.0000e-06
# 38/38 [==============================] - 1s 5ms/step - loss: 0.6933 - accuracy: 0.6683
# Test accuracy: 66.83%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_3_split.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 38/38 [==============================] - 0s 4ms/step
# ([<matplotlib.axis.YTick at 0x7f25384cadc0>,
#   <matplotlib.axis.YTick at 0x7f25384caf10>,
#   <matplotlib.axis.YTick at 0x7f25384cabe0>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])

# %%
target_names = ["$\it{C. albicans}$","$\it{C. glabrata}$","Mock"]

# %%
import seaborn as sns

cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cmn, cmap="flare",linewidths= 0.5,
            annot=True,xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/3_norm.png',dpi=300,bbox_inches='tight')

# %%
cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cm, cmap="flare",linewidths= 0.5,
            annot=True,fmt ='g',xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/3_all.png',dpi=300,bbox_inches='tight')
