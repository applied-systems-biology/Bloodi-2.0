# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv
from sklearn.model_selection import train_test_split

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 1280
MAX_SEQ_LENGTH = 40
IMG_SIZE = 224

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==11)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (9132, 40, 1280)
# (9132, 1)
# (1542, 40, 1280)
# (1542, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_8_split.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 1280)       51200
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 1280)       26247684
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 1280)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense_2 (Dense)             (None, 3)                 3843
#
# =================================================================
# Total params: 26,302,727
# Trainable params: 26,302,727
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 256/257 [============================>.] - ETA: 0s - loss: 1.2065 - accuracy: 0.5582
# Epoch 1: val_loss improved from inf to 0.73413, saving model to Transformer_8_split.h5
# 257/257 [==============================] - 10s 23ms/step - loss: 1.2059 - accuracy: 0.5580 - val_loss: 0.7341 - val_accuracy: 0.7604 - lr: 1.0000e-04
# Epoch 2/500
# 256/257 [============================>.] - ETA: 0s - loss: 0.7161 - accuracy: 0.6836
# Epoch 2: val_loss improved from 0.73413 to 0.68738, saving model to Transformer_8_split.h5
# 257/257 [==============================] - 6s 22ms/step - loss: 0.7168 - accuracy: 0.6833 - val_loss: 0.6874 - val_accuracy: 0.7571 - lr: 1.0000e-04
# Epoch 3/500
# 257/257 [==============================] - ETA: 0s - loss: 0.6237 - accuracy: 0.7234
# Epoch 3: val_loss did not improve from 0.68738
# 257/257 [==============================] - 3s 10ms/step - loss: 0.6237 - accuracy: 0.7234 - val_loss: 0.9762 - val_accuracy: 0.6204 - lr: 1.0000e-04
# Epoch 4/500
# 256/257 [============================>.] - ETA: 0s - loss: 0.5787 - accuracy: 0.7451
# Epoch 4: val_loss improved from 0.68738 to 0.67606, saving model to Transformer_8_split.h5
# 257/257 [==============================] - 8s 30ms/step - loss: 0.5791 - accuracy: 0.7450 - val_loss: 0.6761 - val_accuracy: 0.7199 - lr: 1.0000e-04
# Epoch 5/500
# 257/257 [==============================] - ETA: 0s - loss: 0.5283 - accuracy: 0.7760
# Epoch 5: val_loss improved from 0.67606 to 0.65149, saving model to Transformer_8_split.h5
# 257/257 [==============================] - 5s 21ms/step - loss: 0.5283 - accuracy: 0.7760 - val_loss: 0.6515 - val_accuracy: 0.7527 - lr: 1.0000e-04
# Epoch 6/500
# 254/257 [============================>.] - ETA: 0s - loss: 0.4999 - accuracy: 0.7846
# Epoch 6: val_loss did not improve from 0.65149
# 257/257 [==============================] - 2s 9ms/step - loss: 0.5005 - accuracy: 0.7838 - val_loss: 0.8698 - val_accuracy: 0.6947 - lr: 1.0000e-04
# Epoch 7/500
# 253/257 [============================>.] - ETA: 0s - loss: 0.4704 - accuracy: 0.8046
# Epoch 7: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.4702 - accuracy: 0.8052 - val_loss: 0.8717 - val_accuracy: 0.6871 - lr: 1.0000e-04
# Epoch 8/500
# 256/257 [============================>.] - ETA: 0s - loss: 0.4375 - accuracy: 0.8175
# Epoch 8: val_loss did not improve from 0.65149
# 257/257 [==============================] - 2s 10ms/step - loss: 0.4376 - accuracy: 0.8174 - val_loss: 1.2844 - val_accuracy: 0.5930 - lr: 1.0000e-04
# Epoch 9/500
# 256/257 [============================>.] - ETA: 0s - loss: 0.3932 - accuracy: 0.8380
# Epoch 9: val_loss did not improve from 0.65149
# 257/257 [==============================] - 2s 9ms/step - loss: 0.3929 - accuracy: 0.8380 - val_loss: 1.1216 - val_accuracy: 0.6499 - lr: 1.0000e-04
# Epoch 10/500
# 256/257 [============================>.] - ETA: 0s - loss: 0.3643 - accuracy: 0.8467
# Epoch 10: val_loss did not improve from 0.65149
# 257/257 [==============================] - 2s 9ms/step - loss: 0.3639 - accuracy: 0.8470 - val_loss: 0.9087 - val_accuracy: 0.7199 - lr: 1.0000e-04
# Epoch 11/500
# 256/257 [============================>.] - ETA: 0s - loss: 0.3397 - accuracy: 0.8629
# Epoch 11: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.3393 - accuracy: 0.8631 - val_loss: 1.2724 - val_accuracy: 0.6652 - lr: 1.0000e-04
# Epoch 12/500
# 257/257 [==============================] - ETA: 0s - loss: 0.3183 - accuracy: 0.8726
# Epoch 12: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.3183 - accuracy: 0.8726 - val_loss: 1.4803 - val_accuracy: 0.6171 - lr: 1.0000e-04
# Epoch 13/500
# 253/257 [============================>.] - ETA: 0s - loss: 0.2863 - accuracy: 0.8829
# Epoch 13: val_loss did not improve from 0.65149
# 257/257 [==============================] - 2s 10ms/step - loss: 0.2877 - accuracy: 0.8825 - val_loss: 1.8878 - val_accuracy: 0.5230 - lr: 1.0000e-04
# Epoch 14/500
# 257/257 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.8874
# Epoch 14: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.2701 - accuracy: 0.8874 - val_loss: 1.5570 - val_accuracy: 0.6707 - lr: 1.0000e-04
# Epoch 15/500
# 252/257 [============================>.] - ETA: 0s - loss: 0.2583 - accuracy: 0.8937
# Epoch 15: val_loss did not improve from 0.65149
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 257/257 [==============================] - 3s 10ms/step - loss: 0.2597 - accuracy: 0.8930 - val_loss: 1.3913 - val_accuracy: 0.6980 - lr: 1.0000e-04
# Epoch 16/500
# 253/257 [============================>.] - ETA: 0s - loss: 0.1633 - accuracy: 0.9401
# Epoch 16: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.1626 - accuracy: 0.9403 - val_loss: 2.3894 - val_accuracy: 0.6324 - lr: 1.0000e-05
# Epoch 17/500
# 254/257 [============================>.] - ETA: 0s - loss: 0.1417 - accuracy: 0.9480
# Epoch 17: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.1412 - accuracy: 0.9483 - val_loss: 2.8328 - val_accuracy: 0.6302 - lr: 1.0000e-05
# Epoch 18/500
# 254/257 [============================>.] - ETA: 0s - loss: 0.1305 - accuracy: 0.9502
# Epoch 18: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 11ms/step - loss: 0.1307 - accuracy: 0.9502 - val_loss: 3.1225 - val_accuracy: 0.6171 - lr: 1.0000e-05
# Epoch 19/500
# 257/257 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.9550
# Epoch 19: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.1218 - accuracy: 0.9550 - val_loss: 3.5404 - val_accuracy: 0.5952 - lr: 1.0000e-05
# Epoch 20/500
# 253/257 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9557
# Epoch 20: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.1143 - accuracy: 0.9561 - val_loss: 3.5528 - val_accuracy: 0.6324 - lr: 1.0000e-05
# Epoch 21/500
# 253/257 [============================>.] - ETA: 0s - loss: 0.1096 - accuracy: 0.9574
# Epoch 21: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.1093 - accuracy: 0.9573 - val_loss: 3.8554 - val_accuracy: 0.6313 - lr: 1.0000e-05
# Epoch 22/500
# 253/257 [============================>.] - ETA: 0s - loss: 0.1046 - accuracy: 0.9607
# Epoch 22: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.1043 - accuracy: 0.9606 - val_loss: 3.4873 - val_accuracy: 0.6280 - lr: 1.0000e-05
# Epoch 23/500
# 255/257 [============================>.] - ETA: 0s - loss: 0.0935 - accuracy: 0.9658
# Epoch 23: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0937 - accuracy: 0.9656 - val_loss: 4.5600 - val_accuracy: 0.6072 - lr: 1.0000e-05
# Epoch 24/500
# 252/257 [============================>.] - ETA: 0s - loss: 0.0913 - accuracy: 0.9680
# Epoch 24: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0914 - accuracy: 0.9682 - val_loss: 4.2171 - val_accuracy: 0.6105 - lr: 1.0000e-05
# Epoch 25/500
# 255/257 [============================>.] - ETA: 0s - loss: 0.0862 - accuracy: 0.9675
# Epoch 25: val_loss did not improve from 0.65149
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 257/257 [==============================] - 3s 11ms/step - loss: 0.0867 - accuracy: 0.9674 - val_loss: 4.1151 - val_accuracy: 0.6422 - lr: 1.0000e-05
# Epoch 26/500
# 253/257 [============================>.] - ETA: 0s - loss: 0.0735 - accuracy: 0.9742
# Epoch 26: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0733 - accuracy: 0.9741 - val_loss: 4.3531 - val_accuracy: 0.6247 - lr: 1.0000e-06
# Epoch 27/500
# 257/257 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9735
# Epoch 27: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0727 - accuracy: 0.9735 - val_loss: 4.5964 - val_accuracy: 0.6171 - lr: 1.0000e-06
# Epoch 28/500
# 253/257 [============================>.] - ETA: 0s - loss: 0.0712 - accuracy: 0.9725
# Epoch 28: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 11ms/step - loss: 0.0709 - accuracy: 0.9726 - val_loss: 4.6194 - val_accuracy: 0.6171 - lr: 1.0000e-06
# Epoch 29/500
# 252/257 [============================>.] - ETA: 0s - loss: 0.0711 - accuracy: 0.9736
# Epoch 29: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0717 - accuracy: 0.9736 - val_loss: 4.7704 - val_accuracy: 0.6171 - lr: 1.0000e-06
# Epoch 30/500
# 254/257 [============================>.] - ETA: 0s - loss: 0.0715 - accuracy: 0.9751
# Epoch 30: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0710 - accuracy: 0.9753 - val_loss: 4.8190 - val_accuracy: 0.6127 - lr: 1.0000e-06
# Epoch 31/500
# 255/257 [============================>.] - ETA: 0s - loss: 0.0707 - accuracy: 0.9749
# Epoch 31: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0707 - accuracy: 0.9748 - val_loss: 4.8653 - val_accuracy: 0.6138 - lr: 1.0000e-06
# Epoch 32/500
# 252/257 [============================>.] - ETA: 0s - loss: 0.0678 - accuracy: 0.9740
# Epoch 32: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0683 - accuracy: 0.9740 - val_loss: 4.9626 - val_accuracy: 0.6105 - lr: 1.0000e-06
# Epoch 33/500
# 256/257 [============================>.] - ETA: 0s - loss: 0.0686 - accuracy: 0.9746
# Epoch 33: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0685 - accuracy: 0.9746 - val_loss: 4.7421 - val_accuracy: 0.6247 - lr: 1.0000e-06
# Epoch 34/500
# 254/257 [============================>.] - ETA: 0s - loss: 0.0682 - accuracy: 0.9763
# Epoch 34: val_loss did not improve from 0.65149
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0684 - accuracy: 0.9761 - val_loss: 4.9386 - val_accuracy: 0.6149 - lr: 1.0000e-06
# Epoch 35/500
# 252/257 [============================>.] - ETA: 0s - loss: 0.0670 - accuracy: 0.9751
# Epoch 35: val_loss did not improve from 0.65149
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 257/257 [==============================] - 3s 10ms/step - loss: 0.0666 - accuracy: 0.9754 - val_loss: 4.9699 - val_accuracy: 0.6160 - lr: 1.0000e-06
# 49/49 [==============================] - 0s 4ms/step - loss: 0.7763 - accuracy: 0.6712
# Test accuracy: 67.12%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_8_split.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 49/49 [==============================] - 1s 4ms/step
# ([<matplotlib.axis.YTick at 0x7f01b0575d90>,
#   <matplotlib.axis.YTick at 0x7f01b0575850>,
#   <matplotlib.axis.YTick at 0x7f01b055d940>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])

# %%
target_names = ["$\it{C. albicans}$","$\it{C. glabrata}$","Mock"]

# %%
import seaborn as sns

cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cmn, cmap="flare",linewidths= 0.5,
            annot=True,xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/8_norm.png',dpi=300,bbox_inches='tight')

# %%
cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cm, cmap="flare",linewidths= 0.5,
            annot=True,fmt ='g',xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/8_all.png',dpi=300,bbox_inches='tight')
