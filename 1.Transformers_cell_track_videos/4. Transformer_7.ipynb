# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv
from sklearn.model_selection import train_test_split

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 1280
MAX_SEQ_LENGTH = 40
IMG_SIZE = 224

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==10)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (9436, 40, 1280)
# (9436, 1)
# (1238, 40, 1280)
# (1238, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_7_split.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 1280)       51200
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 1280)       26247684
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 1280)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense_2 (Dense)             (None, 3)                 3843
#
# =================================================================
# Total params: 26,302,727
# Trainable params: 26,302,727
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 260/266 [============================>.] - ETA: 0s - loss: 1.1584 - accuracy: 0.5630
# Epoch 1: val_loss improved from inf to 1.04414, saving model to Transformer_7_split.h5
# 266/266 [==============================] - 13s 26ms/step - loss: 1.1538 - accuracy: 0.5622 - val_loss: 1.0441 - val_accuracy: 0.5053 - lr: 1.0000e-04
# Epoch 2/500
# 261/266 [============================>.] - ETA: 0s - loss: 0.7441 - accuracy: 0.6688
# Epoch 2: val_loss improved from 1.04414 to 0.55678, saving model to Transformer_7_split.h5
# 266/266 [==============================] - 6s 23ms/step - loss: 0.7441 - accuracy: 0.6685 - val_loss: 0.5568 - val_accuracy: 0.7797 - lr: 1.0000e-04
# Epoch 3/500
# 261/266 [============================>.] - ETA: 0s - loss: 0.6640 - accuracy: 0.7134
# Epoch 3: val_loss improved from 0.55678 to 0.43331, saving model to Transformer_7_split.h5
# 266/266 [==============================] - 9s 34ms/step - loss: 0.6627 - accuracy: 0.7135 - val_loss: 0.4333 - val_accuracy: 0.8485 - lr: 1.0000e-04
# Epoch 4/500
# 262/266 [============================>.] - ETA: 0s - loss: 0.5995 - accuracy: 0.7381
# Epoch 4: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 12ms/step - loss: 0.5986 - accuracy: 0.7387 - val_loss: 0.7226 - val_accuracy: 0.7225 - lr: 1.0000e-04
# Epoch 5/500
# 266/266 [==============================] - ETA: 0s - loss: 0.5503 - accuracy: 0.7604
# Epoch 5: val_loss did not improve from 0.43331
# 266/266 [==============================] - 2s 9ms/step - loss: 0.5503 - accuracy: 0.7604 - val_loss: 0.9289 - val_accuracy: 0.6335 - lr: 1.0000e-04
# Epoch 6/500
# 265/266 [============================>.] - ETA: 0s - loss: 0.5159 - accuracy: 0.7835
# Epoch 6: val_loss did not improve from 0.43331
# 266/266 [==============================] - 2s 8ms/step - loss: 0.5161 - accuracy: 0.7834 - val_loss: 0.9685 - val_accuracy: 0.6176 - lr: 1.0000e-04
# Epoch 7/500
# 262/266 [============================>.] - ETA: 0s - loss: 0.4717 - accuracy: 0.8006
# Epoch 7: val_loss did not improve from 0.43331
# 266/266 [==============================] - 2s 9ms/step - loss: 0.4715 - accuracy: 0.8003 - val_loss: 0.5212 - val_accuracy: 0.7977 - lr: 1.0000e-04
# Epoch 8/500
# 263/266 [============================>.] - ETA: 0s - loss: 0.4499 - accuracy: 0.8096
# Epoch 8: val_loss did not improve from 0.43331
# 266/266 [==============================] - 2s 9ms/step - loss: 0.4490 - accuracy: 0.8103 - val_loss: 1.3332 - val_accuracy: 0.5233 - lr: 1.0000e-04
# Epoch 9/500
# 262/266 [============================>.] - ETA: 0s - loss: 0.4078 - accuracy: 0.8304
# Epoch 9: val_loss did not improve from 0.43331
# 266/266 [==============================] - 2s 9ms/step - loss: 0.4081 - accuracy: 0.8301 - val_loss: 0.6830 - val_accuracy: 0.7542 - lr: 1.0000e-04
# Epoch 10/500
# 263/266 [============================>.] - ETA: 0s - loss: 0.3824 - accuracy: 0.8432
# Epoch 10: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.3824 - accuracy: 0.8435 - val_loss: 0.7851 - val_accuracy: 0.7299 - lr: 1.0000e-04
# Epoch 11/500
# 261/266 [============================>.] - ETA: 0s - loss: 0.3517 - accuracy: 0.8569
# Epoch 11: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.3507 - accuracy: 0.8570 - val_loss: 0.6705 - val_accuracy: 0.7871 - lr: 1.0000e-04
# Epoch 12/500
# 264/266 [============================>.] - ETA: 0s - loss: 0.3377 - accuracy: 0.8627
# Epoch 12: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.3374 - accuracy: 0.8629 - val_loss: 0.6796 - val_accuracy: 0.8008 - lr: 1.0000e-04
# Epoch 13/500
# 264/266 [============================>.] - ETA: 0s - loss: 0.3113 - accuracy: 0.8729
# Epoch 13: val_loss did not improve from 0.43331
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 266/266 [==============================] - 2s 9ms/step - loss: 0.3112 - accuracy: 0.8728 - val_loss: 1.1162 - val_accuracy: 0.6801 - lr: 1.0000e-04
# Epoch 14/500
# 265/266 [============================>.] - ETA: 0s - loss: 0.2160 - accuracy: 0.9172
# Epoch 14: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 11ms/step - loss: 0.2158 - accuracy: 0.9173 - val_loss: 1.3369 - val_accuracy: 0.7140 - lr: 1.0000e-05
# Epoch 15/500
# 262/266 [============================>.] - ETA: 0s - loss: 0.1940 - accuracy: 0.9237
# Epoch 15: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1940 - accuracy: 0.9238 - val_loss: 1.4410 - val_accuracy: 0.7278 - lr: 1.0000e-05
# Epoch 16/500
# 262/266 [============================>.] - ETA: 0s - loss: 0.1810 - accuracy: 0.9312
# Epoch 16: val_loss did not improve from 0.43331
# 266/266 [==============================] - 2s 9ms/step - loss: 0.1804 - accuracy: 0.9315 - val_loss: 1.5943 - val_accuracy: 0.7235 - lr: 1.0000e-05
# Epoch 17/500
# 260/266 [============================>.] - ETA: 0s - loss: 0.1786 - accuracy: 0.9319
# Epoch 17: val_loss did not improve from 0.43331
# 266/266 [==============================] - 2s 9ms/step - loss: 0.1785 - accuracy: 0.9313 - val_loss: 1.9263 - val_accuracy: 0.6907 - lr: 1.0000e-05
# Epoch 18/500
# 265/266 [============================>.] - ETA: 0s - loss: 0.1711 - accuracy: 0.9336
# Epoch 18: val_loss did not improve from 0.43331
# 266/266 [==============================] - 2s 9ms/step - loss: 0.1709 - accuracy: 0.9337 - val_loss: 2.0730 - val_accuracy: 0.6886 - lr: 1.0000e-05
# Epoch 19/500
# 265/266 [============================>.] - ETA: 0s - loss: 0.1583 - accuracy: 0.9406
# Epoch 19: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1584 - accuracy: 0.9404 - val_loss: 1.8942 - val_accuracy: 0.7172 - lr: 1.0000e-05
# Epoch 20/500
# 264/266 [============================>.] - ETA: 0s - loss: 0.1569 - accuracy: 0.9409
# Epoch 20: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1568 - accuracy: 0.9411 - val_loss: 2.2721 - val_accuracy: 0.6758 - lr: 1.0000e-05
# Epoch 21/500
# 264/266 [============================>.] - ETA: 0s - loss: 0.1484 - accuracy: 0.9472
# Epoch 21: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 9ms/step - loss: 0.1479 - accuracy: 0.9475 - val_loss: 2.4664 - val_accuracy: 0.6737 - lr: 1.0000e-05
# Epoch 22/500
# 260/266 [============================>.] - ETA: 0s - loss: 0.1445 - accuracy: 0.9450
# Epoch 22: val_loss did not improve from 0.43331
# 266/266 [==============================] - 2s 9ms/step - loss: 0.1442 - accuracy: 0.9452 - val_loss: 2.3240 - val_accuracy: 0.7034 - lr: 1.0000e-05
# Epoch 23/500
# 265/266 [============================>.] - ETA: 0s - loss: 0.1369 - accuracy: 0.9493
# Epoch 23: val_loss did not improve from 0.43331
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1370 - accuracy: 0.9492 - val_loss: 2.3281 - val_accuracy: 0.7044 - lr: 1.0000e-05
# Epoch 24/500
# 263/266 [============================>.] - ETA: 0s - loss: 0.1251 - accuracy: 0.9534
# Epoch 24: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1255 - accuracy: 0.9530 - val_loss: 2.2991 - val_accuracy: 0.7193 - lr: 1.0000e-06
# Epoch 25/500
# 265/266 [============================>.] - ETA: 0s - loss: 0.1232 - accuracy: 0.9538
# Epoch 25: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1233 - accuracy: 0.9536 - val_loss: 2.5417 - val_accuracy: 0.6896 - lr: 1.0000e-06
# Epoch 26/500
# 263/266 [============================>.] - ETA: 0s - loss: 0.1239 - accuracy: 0.9540
# Epoch 26: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1233 - accuracy: 0.9543 - val_loss: 2.5884 - val_accuracy: 0.6960 - lr: 1.0000e-06
# Epoch 27/500
# 263/266 [============================>.] - ETA: 0s - loss: 0.1220 - accuracy: 0.9538
# Epoch 27: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1222 - accuracy: 0.9537 - val_loss: 2.6114 - val_accuracy: 0.6949 - lr: 1.0000e-06
# Epoch 28/500
# 265/266 [============================>.] - ETA: 0s - loss: 0.1218 - accuracy: 0.9532
# Epoch 28: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1217 - accuracy: 0.9531 - val_loss: 2.7230 - val_accuracy: 0.6875 - lr: 1.0000e-06
# Epoch 29/500
# 264/266 [============================>.] - ETA: 0s - loss: 0.1212 - accuracy: 0.9541
# Epoch 29: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1208 - accuracy: 0.9542 - val_loss: 2.6454 - val_accuracy: 0.6949 - lr: 1.0000e-06
# Epoch 30/500
# 261/266 [============================>.] - ETA: 0s - loss: 0.1218 - accuracy: 0.9555
# Epoch 30: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1211 - accuracy: 0.9557 - val_loss: 2.7025 - val_accuracy: 0.6928 - lr: 1.0000e-06
# Epoch 31/500
# 264/266 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9564
# Epoch 31: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1173 - accuracy: 0.9565 - val_loss: 2.6724 - val_accuracy: 0.7002 - lr: 1.0000e-06
# Epoch 32/500
# 261/266 [============================>.] - ETA: 0s - loss: 0.1193 - accuracy: 0.9561
# Epoch 32: val_loss did not improve from 0.43331
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1188 - accuracy: 0.9563 - val_loss: 2.7751 - val_accuracy: 0.6864 - lr: 1.0000e-06
# Epoch 33/500
# 262/266 [============================>.] - ETA: 0s - loss: 0.1156 - accuracy: 0.9574
# Epoch 33: val_loss did not improve from 0.43331
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1153 - accuracy: 0.9577 - val_loss: 2.8595 - val_accuracy: 0.6854 - lr: 1.0000e-06
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5194 - accuracy: 0.7827
# Test accuracy: 78.27%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_7_split.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 39/39 [==============================] - 1s 4ms/step
# ([<matplotlib.axis.YTick at 0x7f4c7c7699a0>,
#   <matplotlib.axis.YTick at 0x7f4c7c769460>,
#   <matplotlib.axis.YTick at 0x7f4cac04dcd0>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])

# %%
target_names = ["$\it{C. albicans}$","$\it{C. glabrata}$","Mock"]

# %%
import seaborn as sns

cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cmn, cmap="flare",linewidths= 0.5,
            annot=True,xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/7_norm.png',dpi=300,bbox_inches='tight')

# %%
cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cm, cmap="flare",linewidths= 0.5,
            annot=True,fmt ='g',xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/7_all.png',dpi=300,bbox_inches='tight')
