# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv
from sklearn.model_selection import train_test_split

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="3"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 1280
MAX_SEQ_LENGTH = 40
IMG_SIZE = 224

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==8)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (9611, 40, 1280)
# (9611, 1)
# (1063, 40, 1280)
# (1063, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_5_split.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 1280)       51200
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 1280)       26247684
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 1280)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense_2 (Dense)             (None, 3)                 3843
#
# =================================================================
# Total params: 26,302,727
# Trainable params: 26,302,727
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 270/271 [============================>.] - ETA: 0s - loss: 1.1765 - accuracy: 0.5587
# Epoch 1: val_loss improved from inf to 0.85581, saving model to Transformer_5_split.h5
# 271/271 [==============================] - 9s 23ms/step - loss: 1.1760 - accuracy: 0.5589 - val_loss: 0.8558 - val_accuracy: 0.6268 - lr: 1.0000e-04
# Epoch 2/500
# 266/271 [============================>.] - ETA: 0s - loss: 0.7076 - accuracy: 0.6924
# Epoch 2: val_loss improved from 0.85581 to 0.69247, saving model to Transformer_5_split.h5
# 271/271 [==============================] - 6s 24ms/step - loss: 0.7073 - accuracy: 0.6924 - val_loss: 0.6925 - val_accuracy: 0.7453 - lr: 1.0000e-04
# Epoch 3/500
# 266/271 [============================>.] - ETA: 0s - loss: 0.6094 - accuracy: 0.7263
# Epoch 3: val_loss did not improve from 0.69247
# 271/271 [==============================] - 2s 9ms/step - loss: 0.6092 - accuracy: 0.7268 - val_loss: 0.8822 - val_accuracy: 0.6258 - lr: 1.0000e-04
# Epoch 4/500
# 267/271 [============================>.] - ETA: 0s - loss: 0.5461 - accuracy: 0.7626
# Epoch 4: val_loss improved from 0.69247 to 0.66703, saving model to Transformer_5_split.h5
# 271/271 [==============================] - 7s 27ms/step - loss: 0.5457 - accuracy: 0.7630 - val_loss: 0.6670 - val_accuracy: 0.7526 - lr: 1.0000e-04
# Epoch 5/500
# 270/271 [============================>.] - ETA: 0s - loss: 0.5187 - accuracy: 0.7709
# Epoch 5: val_loss did not improve from 0.66703
# 271/271 [==============================] - 3s 11ms/step - loss: 0.5186 - accuracy: 0.7711 - val_loss: 1.0841 - val_accuracy: 0.6455 - lr: 1.0000e-04
# Epoch 6/500
# 271/271 [==============================] - ETA: 0s - loss: 0.4809 - accuracy: 0.7912
# Epoch 6: val_loss improved from 0.66703 to 0.50292, saving model to Transformer_5_split.h5
# 271/271 [==============================] - 6s 23ms/step - loss: 0.4809 - accuracy: 0.7912 - val_loss: 0.5029 - val_accuracy: 0.8306 - lr: 1.0000e-04
# Epoch 7/500
# 269/271 [============================>.] - ETA: 0s - loss: 0.4496 - accuracy: 0.8080
# Epoch 7: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s
val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 9ms/step - loss: 0.1027 - accuracy: 0.9598 - val_loss: 2.4872 - val_accuracy: 0.7058 - lr: 1.0000e-05
# Epoch 20/500
# 267/271 [============================>.] - ETA: 0s - loss: 0.0924 - accuracy: 0.9664
# Epoch 20: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 9ms/step - loss: 0.0923 - accuracy: 0.9666 - val_loss: 2.4917 - val_accuracy: 0.7162 - lr: 1.0000e-05
# Epoch 21/500
# 266/271 [============================>.] - ETA: 0s - loss: 0.0885 - accuracy: 0.9649
# Epoch 21: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0882 - accuracy: 0.9649 - val_loss: 2.5344 - val_accuracy: 0.7183 - lr: 1.0000e-05
# Epoch 22/500
# 271/271 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9695
# Epoch 22: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0815 - accuracy: 0.9695 - val_loss: 2.7791 - val_accuracy: 0.7058 - lr: 1.0000e-05
# Epoch 23/500
# 270/271 [============================>.] - ETA: 0s - loss: 0.0770 - accuracy: 0.9719
# Epoch 23: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0769 - accuracy: 0.9719 - val_loss: 3.3644 - val_accuracy: 0.6674 - lr: 1.0000e-05
# Epoch 24/500
# 270/271 [============================>.] - ETA: 0s - loss: 0.0765 - accuracy: 0.9709
# Epoch 24: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0770 - accuracy: 0.9709 - val_loss: 2.8804 - val_accuracy: 0.7089 - lr: 1.0000e-05
# Epoch 25/500
# 266/271 [============================>.] - ETA: 0s - loss: 0.0716 - accuracy: 0.9747
# Epoch 25: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0713 - accuracy: 0.9747 - val_loss: 3.1187 - val_accuracy: 0.6913 - lr: 1.0000e-05
# Epoch 26/500
# 265/271 [============================>.] - ETA: 0s - loss: 0.0693 - accuracy: 0.9744
# Epoch 26: val_loss did not improve from 0.50292
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0693 - accuracy: 0.9742 - val_loss: 3.2738 - val_accuracy: 0.6923 - lr: 1.0000e-05
# Epoch 27/500
# 271/271 [==============================] - ETA: 0s - loss: 0.0547 - accuracy: 0.9814
# Epoch 27: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0547 - accuracy: 0.9814 - val_loss: 3.1680 - val_accuracy: 0.7048 - lr: 1.0000e-06
# Epoch 28/500
# 268/271 [============================>.] - ETA: 0s - loss: 0.0557 - accuracy: 0.9801
# Epoch 28: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0555 - accuracy: 0.9802 - val_loss: 3.1962 - val_accuracy: 0.7100 - lr: 1.0000e-06
# Epoch 29/500
# 266/271 [============================>.] - ETA: 0s - loss: 0.0559 - accuracy: 0.9783
# Epoch 29: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0562 - accuracy: 0.9783 - val_loss: 3.4321 - val_accuracy: 0.6913 - lr: 1.0000e-06
# Epoch 30/500
# 269/271 [============================>.] - ETA: 0s - loss: 0.0545 - accuracy: 0.9807
# Epoch 30: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0545 - accuracy: 0.9807 - val_loss: 3.3262 - val_accuracy: 0.7027 - lr: 1.0000e-06
# Epoch 31/500
# 266/271 [============================>.] - ETA: 0s - loss: 0.0557 - accuracy: 0.9798
# Epoch 31: val_loss did not improve from 0.50292
# 271/271 [==============================] - 2s 9ms/step - loss: 0.0553 - accuracy: 0.9800 - val_loss: 3.3796 - val_accuracy: 0.7037 - lr: 1.0000e-06
# Epoch 32/500
# 267/271 [============================>.] - ETA: 0s - loss: 0.0558 - accuracy: 0.9802
# Epoch 32: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0563 - accuracy: 0.9801 - val_loss: 3.3561 - val_accuracy: 0.7079 - lr: 1.0000e-06
# Epoch 33/500
# 266/271 [============================>.] - ETA: 0s - loss: 0.0567 - accuracy: 0.9791
# Epoch 33: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 9ms/step - loss: 0.0564 - accuracy: 0.9793 - val_loss: 3.4478 - val_accuracy: 0.7058 - lr: 1.0000e-06
# Epoch 34/500
# 265/271 [============================>.] - ETA: 0s - loss: 0.0533 - accuracy: 0.9805
# Epoch 34: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0533 - accuracy: 0.9806 - val_loss: 3.5110 - val_accuracy: 0.7017 - lr: 1.0000e-06
# Epoch 35/500
# 269/271 [============================>.] - ETA: 0s - loss: 0.0519 - accuracy: 0.9812
# Epoch 35: val_loss did not improve from 0.50292
# 271/271 [==============================] - 3s 9ms/step - loss: 0.0518 - accuracy: 0.9813 - val_loss: 3.4657 - val_accuracy: 0.7048 - lr: 1.0000e-06
# Epoch 36/500
# 269/271 [============================>.] - ETA: 0s - loss: 0.0509 - accuracy: 0.9815
# Epoch 36: val_loss did not improve from 0.50292
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 271/271 [==============================] - 3s 10ms/step - loss: 0.0508 - accuracy: 0.9816 - val_loss: 3.6749 - val_accuracy: 0.6944 - lr: 1.0000e-06
# 34/34 [==============================] - 1s 4ms/step - loss: 1.0301 - accuracy: 0.5898
# Test accuracy: 58.98%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_5_split.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 34/34 [==============================] - 0s 4ms/step
# ([<matplotlib.axis.YTick at 0x7fba3c2ee790>,
#   <matplotlib.axis.YTick at 0x7fba3c2ee2b0>,
#   <matplotlib.axis.YTick at 0x7fba3c399b20>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])

# %%
target_names = ["$\it{C. albicans}$","$\it{C. glabrata}$","Mock"]

# %%
import seaborn as sns

cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cmn, cmap="flare",linewidths= 0.5,
            annot=True,xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/5_norm.png',dpi=300,bbox_inches='tight')

# %%
cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cm, cmap="flare",linewidths= 0.5,
            annot=True,fmt ='g',xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/5_all.png',dpi=300,bbox_inches='tight')
