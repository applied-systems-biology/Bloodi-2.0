# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv
from sklearn.model_selection import train_test_split

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="2"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 1280
MAX_SEQ_LENGTH = 40
IMG_SIZE = 224

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==9)]
test
# Out:
#     Video_Num infection  Patient  Patient_id
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 0           1        ca        1    20180220
# 1           2        cg        1    20180220
# 2           3      mock        1    20180220
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (9750, 40, 1280)
# (9750, 1)
# (924, 40, 1280)
# (924, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_6_split.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 1280)       51200
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 1280)       26247684
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 1280)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense_2 (Dense)             (None, 3)                 3843
#
# =================================================================
# Total params: 26,302,727
# Trainable params: 26,302,727
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 272/275 [============================>.] - ETA: 0s - loss: 1.0625 - accuracy: 0.5859
# Epoch 1: val_loss improved from inf to 0.99362, saving model to Transformer_6_split.h5
# 275/275 [==============================] - 10s 24ms/step - loss: 1.0603 - accuracy: 0.5863 - val_loss: 0.9936 - val_accuracy: 0.5405 - lr: 1.0000e-04
# Epoch 2/500
# 272/275 [============================>.] - ETA: 0s - loss: 0.7033 - accuracy: 0.6870
# Epoch 2: val_loss did not improve from 0.99362
# 275/275 [==============================] - 4s 13ms/step - loss: 0.7041 - accuracy: 0.6870 - val_loss: 1.0919 - val_accuracy: 0.5405 - lr: 1.0000e-04
# Epoch 3/500
# 270/275 [============================>.] - ETA: 0s - loss: 0.6415 - accuracy: 0.7209
# Epoch 3: val_loss did not improve from 0.99362
# 275/275 [==============================] - 3s 12ms/step - loss: 0.6414 - accuracy: 0.7208 - val_loss: 1.3052 - val_accuracy: 0.3805 - lr: 1.0000e-04
# Epoch 4/500
# 274/275 [============================>.] - ETA: 0s - loss: 0.5700 - accuracy: 0.7542
# Epoch 4: val_loss improved from 0.99362 to 0.72230, saving model to Transformer_6_split.h5
# 275/275 [==============================] - 8s 28ms/step - loss: 0.5698 - accuracy: 0.7542 - val_loss: 0.7223 - val_accuracy: 0.6687 - lr: 1.0000e-04
# Epoch 5/500
# 273/275 [============================>.] - ETA: 0s - loss: 0.5380 - accuracy: 0.7675
# Epoch 5: val_loss improved from 0.72230 to 0.54123, saving model to Transformer_6_split.h5
# 275/275 [==============================] - 5s 20ms/step - loss: 0.5371 - accuracy: 0.7679 - val_loss: 0.5412 - val_accuracy: 0.8021 - lr: 1.0000e-04
# Epoch 6/500
# 273/275 [============================>.] - ETA: 0s - loss: 0.4847 - accuracy: 0.7908
# Epoch 6: val_loss did not improve from 0.54123
# 275/275 [==============================] - 2s 9ms/step - loss: 0.4853 - accuracy: 0.7904 - val_loss: 0.5703 - val_accuracy: 0.7877 - lr: 1.0000e-04
# Epoch 7/500
# 271/275 [============================>.] - ETA: 0s - loss: 0.4501 - accuracy: 0.8135
# Epoch 7: val_loss did not improve from 0.54123
# 275/275 [==============================] - 2s 9ms/step - loss: 0.4497 - accuracy: 0.8136 - val_loss: 0.9136 - val_accuracy: 0.6636 - lr: 1.0000e-04
# Epoch 8/500
# 270/275 [============================>.] - ETA: 0s - loss: 0.4172 - accuracy: 0.8245
# Epoch 8: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 10ms/step - loss: 0.4169 - accuracy: 0.8244 - val_loss: 0.5533 - val_accuracy: 0.8297 - lr: 1.0000e-04
# Epoch 9/500
# 270/275 [============================>.] - ETA: 0s - loss: 0.3913 - accuracy: 0.8356
# Epoch 9: val_loss did not improve from 0.54123
# 275/275 [==============================] - 2s 9ms/step - loss: 0.3910 - accuracy: 0.8357 - val_loss: 0.9105 - val_accuracy: 0.7221 - lr: 1.0000e-04
# Epoch 10/500
# 272/275 [============================>.] - ETA: 0s - loss: 0.3642 - accuracy: 0.8450
# Epoch 10: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.3651 - accuracy: 0.8446 - val_loss: 1.1293 - val_accuracy: 0.6810 - lr: 1.0000e-04
# Epoch 11/500
# 270/275 [============================>.] - ETA: 0s - loss: 0.3304 - accuracy: 0.8638
# Epoch 11: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 10ms/step - loss: 0.3298 - accuracy: 0.8644 - val_loss: 1.1636 - val_accuracy: 0.6400 - lr: 1.0000e-04
# Epoch 12/500
# 275/275 [==============================] - ETA: 0s - loss: 0.3264 - accuracy: 0.8634
# Epoch 12: val_loss did not improve from 0.54123
# 275/275 [==============================] - 2s 9ms/step - loss: 0.3264 - accuracy: 0.8634 - val_loss: 1.3340 - val_accuracy: 0.6431 - lr: 1.0000e-04
# Epoch 13/500
# 270/275 [============================>.] - ETA: 0s - loss: 0.2927 - accuracy: 0.8781
# Epoch 13: val_loss did not improve from 0.54123
# 275/275 [==============================] - 2s 9ms/step - loss: 0.2936 - accuracy: 0.8777 - val_loss: 0.6414 - val_accuracy: 0.8092 - lr: 1.0000e-04
# Epoch 14/500
# 271/275 [============================>.] - ETA: 0s - loss: 0.2737 - accuracy: 0.8832
# Epoch 14: val_loss did not improve from 0.54123
# 275/275 [==============================] - 2s 9ms/step - loss: 0.2733 - accuracy: 0.8838 - val_loss: 0.9628 - val_accuracy: 0.7538 - lr: 1.0000e-04
# Epoch 15/500
# 274/275 [============================>.] - ETA: 0s - loss: 0.2535 - accuracy: 0.8946
# Epoch 15: val_loss did not improve from 0.54123
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 275/275 [==============================] - 3s 9ms/step - loss: 0.2534 - accuracy: 0.8947 - val_loss: 1.7281 - val_accuracy: 0.5979 - lr: 1.0000e-04
# Epoch 16/500
# 269/275 [============================>.] - ETA: 0s - loss: 0.1639 - accuracy: 0.9368
# Epoch 16: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 10ms/step - loss: 0.1638 - accuracy: 0.9369 - val_loss: 1.4028 - val_accuracy: 0.7559 - lr: 1.0000e-05
# Epoch 17/500
# 274/275 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9440
# Epoch 17: val_loss did not improve from 0.54123
# 275/275 [==============================] - 2s 9ms/step - loss: 0.1441 - accuracy: 0.9440 - val_loss: 1.4984 - val_accuracy: 0.7621 - lr: 1.0000e-05
# Epoch 18/500
# 271/275 [============================>.] - ETA: 0s - loss: 0.1340 - accuracy: 0.9488
# Epoch 18: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.1337 - accuracy: 0.9489 - val_loss: 1.8078 - val_accuracy: 0.7364 - lr: 1.0000e-05
# Epoch 19/500
# 269/275 [============================>.] - ETA: 0s - loss: 0.1248 - accuracy: 0.9497
# Epoch 19: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.1258 - accuracy: 0.9493 - val_loss: 2.1864 - val_accuracy: 0.6923 - lr: 1.0000e-05
# Epoch 20/500
# 274/275 [============================>.] - ETA: 0s - loss: 0.1232 - accuracy: 0.9526
# Epoch 20: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.1232 - accuracy: 0.9525 - val_loss: 1.9333 - val_accuracy: 0.7477 - lr: 1.0000e-05
# Epoch 21/500
# 274/275 [============================>.] - ETA: 0s - loss: 0.1171 - accuracy: 0.9530
# Epoch 21: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.1171 - accuracy: 0.9530 - val_loss: 2.0867 - val_accuracy: 0.7210 - lr: 1.0000e-05
# Epoch 22/500
# 272/275 [============================>.] - ETA: 0s - loss: 0.1060 - accuracy: 0.9596
# Epoch 22: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 10ms/step - loss: 0.1062 - accuracy: 0.9593 - val_loss: 2.4133 - val_accuracy: 0.7036 - lr: 1.0000e-05
# Epoch 23/500
# 274/275 [============================>.] - ETA: 0s - loss: 0.1065 - accuracy: 0.9609
# Epoch 23: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.1065 - accuracy: 0.9608 - val_loss: 2.3891 - val_accuracy: 0.7333 - lr: 1.0000e-05
# Epoch 24/500
# 273/275 [============================>.] - ETA: 0s - loss: 0.1033 - accuracy: 0.9615
# Epoch 24: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.1031 - accuracy: 0.9616 - val_loss: 2.5696 - val_accuracy: 0.6974 - lr: 1.0000e-05
# Epoch 25/500
# 275/275 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9632
# Epoch 25: val_loss did not improve from 0.54123
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 275/275 [==============================] - 3s 10ms/step - loss: 0.0962 - accuracy: 0.9632 - val_loss: 2.5018 - val_accuracy: 0.7179 - lr: 1.0000e-05
# Epoch 26/500
# 271/275 [============================>.] - ETA: 0s - loss: 0.0871 - accuracy: 0.9686
# Epoch 26: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.0867 - accuracy: 0.9687 - val_loss: 2.6733 - val_accuracy: 0.6995 - lr: 1.0000e-06
# Epoch 27/500
# 269/275 [============================>.] - ETA: 0s - loss: 0.0851 - accuracy: 0.9679
# Epoch 27: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.0842 - accuracy: 0.9682 - val_loss: 2.6221 - val_accuracy: 0.7190 - lr: 1.0000e-06
# Epoch 28/500
# 270/275 [============================>.] - ETA: 0s - loss: 0.0846 - accuracy: 0.9677
# Epoch 28: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.0840 - accuracy: 0.9681 - val_loss: 2.6119 - val_accuracy: 0.7190 - lr: 1.0000e-06
# Epoch 29/500
# 272/275 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9713
# Epoch 29: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.0792 - accuracy: 0.9711 - val_loss: 2.6477 - val_accuracy: 0.7231 - lr: 1.0000e-06
# Epoch 30/500
# 272/275 [============================>.] - ETA: 0s - loss: 0.0793 - accuracy: 0.9707
# Epoch 30: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 10ms/step - loss: 0.0789 - accuracy: 0.9709 - val_loss: 2.7359 - val_accuracy: 0.7169 - lr: 1.0000e-06
# Epoch 31/500
# 271/275 [============================>.] - ETA: 0s - loss: 0.0795 - accuracy: 0.9722
# Epoch 31: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.0794 - accuracy: 0.9722 - val_loss: 2.7906 - val_accuracy: 0.7108 - lr: 1.0000e-06
# Epoch 32/500
# 271/275 [============================>.] - ETA: 0s - loss: 0.0760 - accuracy: 0.9728
# Epoch 32: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 10ms/step - loss: 0.0759 - accuracy: 0.9726 - val_loss: 3.0167 - val_accuracy: 0.6995 - lr: 1.0000e-06
# Epoch 33/500
# 273/275 [============================>.] - ETA: 0s - loss: 0.0780 - accuracy: 0.9724
# Epoch 33: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.0783 - accuracy: 0.9723 - val_loss: 2.7925 - val_accuracy: 0.7159 - lr: 1.0000e-06
# Epoch 34/500
# 270/275 [============================>.] - ETA: 0s - loss: 0.0791 - accuracy: 0.9712
# Epoch 34: val_loss did not improve from 0.54123
# 275/275 [==============================] - 3s 9ms/step - loss: 0.0796 - accuracy: 0.9711 - val_loss: 2.9315 - val_accuracy: 0.7036 - lr: 1.0000e-06
# Epoch 35/500
# 273/275 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9715
# Epoch 35: val_loss did not improve from 0.54123
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 275/275 [==============================] - 3s 9ms/step - loss: 0.0784 - accuracy: 0.9716 - val_loss: 2.7534 - val_accuracy: 0.7159 - lr: 1.0000e-06
# 29/29 [==============================] - 0s 4ms/step - loss: 0.7448 - accuracy: 0.6699
# Test accuracy: 66.99%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_6_split.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 29/29 [==============================] - 0s 4ms/step
# ([<matplotlib.axis.YTick at 0x7f9a68030910>,
#   <matplotlib.axis.YTick at 0x7f9a68030700>,
#   <matplotlib.axis.YTick at 0x7f9a680e2f70>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])

# %%
target_names = ["$\it{C. albicans}$","$\it{C. glabrata}$","Mock"]

# %%
import seaborn as sns

cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cmn, cmap="flare",linewidths= 0.5,
            annot=True,xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/6_norm.png',dpi=300,bbox_inches='tight')

# %%
cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cm, cmap="flare",linewidths= 0.5,
            annot=True,fmt ='g',xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/6_all.png',dpi=300,bbox_inches='tight')
