# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import imageio
import cv2 as cv
from sklearn.model_selection import train_test_split

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="7"

strategy = tf.distribute.MirroredStrategy(["GPU:0"])
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
NUM_FEATURES = 1280
MAX_SEQ_LENGTH = 40
IMG_SIZE = 224

EPOCHS = 500

# %%
df = pd.read_csv('Labels.csv')
df = df.rename(columns={'Inefction_type':'infection'})
df.head()
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220
# 3          4        ca        2    20180315
# 4          5        cg        2    20180315

# %%
test = df[(df['Patient']==1)]
test
# Out:
#    Video_Num infection  Patient  Patient_id
# 0          1        ca        1    20180220
# 1          2        cg        1    20180220
# 2          3      mock        1    20180220

# %%
train = pd.concat([df, test]).drop_duplicates(keep=False)
train
# Out:
#     Video_Num infection  Patient  Patient_id
# 3           4        ca        2    20180315
# 4           5        cg        2    20180315
# 5           6      mock        2    20180315
# 6          13        ca        5    20180409
# 7          14        cg        5    20180409
# 8          15      mock        5    20180409
# 9          18        ca        7    20180914
# 10         19        cg        7    20180914
# 11         20      mock        7    20180914
# 12         21        ca        8    20180918
# 13         22        cg        8    20180918
# 14         23      mock        8    20180918
# 15         24        ca        9    20180920
# 16         25        cg        9    20180920
# 17         26      mock        9    20180920
# 18         27        ca       10    20180925
# 19         28        cg       10    20180925
# 20         29      mock       10    20180925
# 21         30        ca       11    20181009
# 22         31        cg       11    20181009
# 23         32      mock       11    20181009
# 24         33        ca       12    20181011
# 25         34        cg       12    20181011
# 26         35      mock       12    20181011

# %%
def concat_arrays(df):

    full_features = []
    full_labels = []

    for i,item in df.iterrows():
    
        features = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/videos/{item[0]}_features.npy')
        labels = np.load(f'/asbdata/Arjun/Bloodi/Split_numpy/labels/{item[0]}_labels.npy')
    
        full_features.extend(features)
        full_labels.extend(labels)
    
    final_features = np.array(full_features)
    final_labels = np.array(full_labels)
    
    return final_features,final_labels

# %%
train_data, train_labels = concat_arrays(train)
test_data, test_labels = concat_arrays(test)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (9790, 40, 1280)
# (9790, 1)
# (884, 40, 1280)
# (884, 1)

# %%
class PositionalEmbedding(layers.Layer):
    
    def __init__(self, sequence_length, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim
        )
        self.sequence_length = sequence_length
        self.output_dim = output_dim
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'sequence_length': self.sequence_length,
            'output_dim': self.output_dim
        })
        return config

    def call(self, inputs):
        # The inputs are of shape: `(batch_size, frames, num_features)`
        length = tf.shape(inputs)[1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_positions = self.position_embeddings(positions)
        return inputs + embedded_positions

    def compute_mask(self, inputs, mask=None):
        mask = tf.reduce_any(tf.cast(inputs, "bool"), axis=-1)
        return mask

# %%
class TransformerEncoder(layers.Layer):
    
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation=tf.nn.gelu), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        
    def get_config(self):

        config = super().get_config().copy()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config

    def call(self, inputs, mask=None):
        
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

# %%
with strategy.scope():
    

    def get_compiled_model():
        
        sequence_length = MAX_SEQ_LENGTH
        embed_dim = NUM_FEATURES
        dense_dim = 4
        num_heads = 4
        classes = 3

        inputs = keras.Input(shape=(None, None))
        x = PositionalEmbedding(sequence_length, embed_dim, name="frame_position_embedding")(inputs)
        x = TransformerEncoder(embed_dim, dense_dim, num_heads, name="transformer_layer")(x)
        x = layers.GlobalMaxPooling1D()(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(classes, activation="softmax")(x)
        model = keras.Model(inputs, outputs)

        model.compile(
            optimizer=tf.keras.optimizers.Adam(lr=0.0001), loss="sparse_categorical_crossentropy", metrics=["accuracy"]
        )
        
        model.summary()
        
        return model

# %%
with strategy.scope():
    
    def run_experiment():
        
        filepath = "Transformer_1_split.h5"
        checkpoint = keras.callbacks.ModelCheckpoint(filepath, save_best_only=True, verbose=1)
        stopping = EarlyStopping(monitor='val_loss', patience=30)
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.1,patience=10,verbose=1,mode='auto')

        model = get_compiled_model()
        history = model.fit(
            train_data,
            train_labels,
            validation_split=0.1,
            epochs=EPOCHS,
            callbacks=[checkpoint,stopping,reduce_lr],
        )

        model.load_weights(filepath)
        _, accuracy = model.evaluate(test_data, test_labels)
        print(f"Test accuracy: {round(accuracy * 100, 2)}%")

        return model

# %%
trained_model = run_experiment()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None)]      0
#
#  frame_position_embedding (P  (None, None, 1280)       51200
#  ositionalEmbedding)
#
#  transformer_layer (Transfor  (None, None, 1280)       26247684
#  merEncoder)
#
#  global_max_pooling1d (Globa  (None, 1280)             0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense_2 (Dense)             (None, 3)                 3843
#
# =================================================================
# Total params: 26,302,727
# Trainable params: 26,302,727
# Non-trainable params: 0
# _________________________________________________________________
# /home/asarkar/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 271/276 [============================>.] - ETA: 0s - loss: 1.1239 - accuracy: 0.5746
# Epoch 1: val_loss improved from inf to 0.58917, saving model to Transformer_1_split.h5
# 276/276 [==============================] - 9s 21ms/step - loss: 1.1182 - accuracy: 0.5758 - val_loss: 0.5892 - val_accuracy: 0.8069 - lr: 1.0000e-04
# Epoch 2/500
# 275/276 [============================>.] - ETA: 0s - loss: 0.7291 - accuracy: 0.6775
# Epoch 2: val_loss did not improve from 0.58917
# 276/276 [==============================] - 4s 15ms/step - loss: 0.7290 - accuracy: 0.6776 - val_loss: 0.7211 - val_accuracy: 0.7446 - lr: 1.0000e-04
# Epoch 3/500
# 275/276 [============================>.] - ETA: 0s - loss: 0.6486 - accuracy: 0.7165
# Epoch 3: val_loss improved from 0.58917 to 0.55864, saving model to Transformer_1_split.h5
# 276/276 [==============================] - 6s 21ms/step - loss: 0.6487 - accuracy: 0.7162 - val_loss: 0.5586 - val_accuracy: 0.8100 - lr: 1.0000e-04
# Epoch 4/500
# 276/276 [==============================] - ETA: 0s - loss: 0.5971 - accuracy: 0.7420
# Epoch 4: val_loss did not improve from 0.55864
# 276/276 [==============================] - 2s 9ms/step - loss: 0.5971 - accuracy: 0.7420 - val_loss: 0.8256 - val_accuracy: 0.6129 - lr: 1.0000e-04
# Epoch 5/500
# 274/276 [============================>.] - ETA: 0s - loss: 0.5595 - accuracy: 0.7576
# Epoch 5: val_loss did not improve from 0.55864
# 276/276 [==============================] - 2s 9ms/step - loss: 0.5591 - accuracy: 0.7579 - val_loss: 1.0050 - val_accuracy: 0.6067 - lr: 1.0000e-04
# Epoch 6/500
# 271/276 [============================>.] - ETA: 0s - loss: 0.5148 - accuracy: 0.7777
# Epoch 6: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.5154 - accuracy: 0.7777 - val_loss: 0.6850 - val_accuracy: 0.7089 - lr: 1.0000e-04
# Epoch 7/500
# 273/276 [============================>.] - ETA: 0s - loss: 0.4815 - accuracy: 0.7996
# Epoch 7: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.4814 - accuracy: 0.7993 - val_loss: 1.0232 - val_accuracy: 0.6139 - lr: 1.0000e-04
# Epoch 8/500
# 272/276 [============================>.] - ETA: 0s - loss: 0.4630 - accuracy: 0.8041
# Epoch 8: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.4617 - accuracy: 0.8048 - val_loss: 0.6335 - val_accuracy: 0.7783 - lr: 1.0000e-04
# Epoch 9/500
# 275/276 [============================>.] - ETA: 0s - loss: 0.4236 - accuracy: 0.8241
# Epoch 9: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.4235 - accuracy: 0.8241 - val_loss: 0.5904 - val_accuracy: 0.7988 - lr: 1.0000e-04
# Epoch 10/500
# 270/276 [============================>.] - ETA: 0s - loss: 0.3875 - accuracy: 0.8361
# Epoch 10: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 9ms/step - loss: 0.3874 - accuracy: 0.8362 - val_loss: 0.8027 - val_accuracy: 0.6823 - lr: 1.0000e-04
# Epoch 11/500
# 270/276 [============================>.] - ETA: 0s - loss: 0.3644 - accuracy: 0.8479
# Epoch 11: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.3641 - accuracy: 0.8481 - val_loss: 0.8995 - val_accuracy: 0.6936 - lr: 1.0000e-04
# Epoch 12/500
# 275/276 [============================>.] - ETA: 0s - loss: 0.3357 - accuracy: 0.8623
# Epoch 12: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 9ms/step - loss: 0.3356 - accuracy: 0.8623 - val_loss: 0.9340 - val_accuracy: 0.7150 - lr: 1.0000e-04
# Epoch 13/500
# 270/276 [============================>.] - ETA: 0s - loss: 0.3256 - accuracy: 0.8666
# Epoch 13: val_loss did not improve from 0.55864
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 276/276 [==============================] - 3s 10ms/step - loss: 0.3241 - accuracy: 0.8674 - val_loss: 1.1673 - val_accuracy: 0.6343 - lr: 1.0000e-04
# Epoch 14/500
# 275/276 [============================>.] - ETA: 0s - loss: 0.2246 - accuracy: 0.9107
# Epoch 14: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.2245 - accuracy: 0.9107 - val_loss: 1.2578 - val_accuracy: 0.7201 - lr: 1.0000e-05
# Epoch 15/500
# 272/276 [============================>.] - ETA: 0s - loss: 0.1968 - accuracy: 0.9230
# Epoch 15: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 9ms/step - loss: 0.1975 - accuracy: 0.9229 - val_loss: 1.4181 - val_accuracy: 0.7211 - lr: 1.0000e-05
# Epoch 16/500
# 271/276 [============================>.] - ETA: 0s - loss: 0.1923 - accuracy: 0.9264
# Epoch 16: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1912 - accuracy: 0.9270 - val_loss: 1.3231 - val_accuracy: 0.7395 - lr: 1.0000e-05
# Epoch 17/500
# 273/276 [============================>.] - ETA: 0s - loss: 0.1787 - accuracy: 0.9298
# Epoch 17: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1801 - accuracy: 0.9300 - val_loss: 1.5998 - val_accuracy: 0.7191 - lr: 1.0000e-05
# Epoch 18/500
# 270/276 [============================>.] - ETA: 0s - loss: 0.1699 - accuracy: 0.9346
# Epoch 18: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1705 - accuracy: 0.9341 - val_loss: 1.8942 - val_accuracy: 0.6956 - lr: 1.0000e-05
# Epoch 19/500
# 276/276 [==============================] - ETA: 0s - loss: 0.1651 - accuracy: 0.9346
# Epoch 19: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 9ms/step - loss: 0.1651 - accuracy: 0.9346 - val_loss: 1.9647 - val_accuracy: 0.6854 - lr: 1.0000e-05
# Epoch 20/500
# 274/276 [============================>.] - ETA: 0s - loss: 0.1587 - accuracy: 0.9402
# Epoch 20: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1586 - accuracy: 0.9404 - val_loss: 1.7067 - val_accuracy: 0.7252 - lr: 1.0000e-05
# Epoch 21/500
# 270/276 [============================>.] - ETA: 0s - loss: 0.1476 - accuracy: 0.9454
# Epoch 21: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1475 - accuracy: 0.9452 - val_loss: 2.2549 - val_accuracy: 0.6813 - lr: 1.0000e-05
# Epoch 22/500
# 271/276 [============================>.] - ETA: 0s - loss: 0.1448 - accuracy: 0.9445
# Epoch 22: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1453 - accuracy: 0.9443 - val_loss: 2.3183 - val_accuracy: 0.6997 - lr: 1.0000e-05
# Epoch 23/500
# 273/276 [============================>.] - ETA: 0s - loss: 0.1412 - accuracy: 0.9483
# Epoch 23: val_loss did not improve from 0.55864
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1409 - accuracy: 0.9484 - val_loss: 1.8604 - val_accuracy: 0.7324 - lr: 1.0000e-05
# Epoch 24/500
# 270/276 [============================>.] - ETA: 0s - loss: 0.1234 - accuracy: 0.9543
# Epoch 24: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1235 - accuracy: 0.9538 - val_loss: 2.2631 - val_accuracy: 0.6946 - lr: 1.0000e-06
# Epoch 25/500
# 270/276 [============================>.] - ETA: 0s - loss: 0.1203 - accuracy: 0.9542
# Epoch 25: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1201 - accuracy: 0.9544 - val_loss: 2.2948 - val_accuracy: 0.6997 - lr: 1.0000e-06
# Epoch 26/500
# 274/276 [============================>.] - ETA: 0s - loss: 0.1252 - accuracy: 0.9522
# Epoch 26: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 9ms/step - loss: 0.1255 - accuracy: 0.9521 - val_loss: 2.2684 - val_accuracy: 0.7028 - lr: 1.0000e-06
# Epoch 27/500
# 272/276 [============================>.] - ETA: 0s - loss: 0.1207 - accuracy: 0.9535
# Epoch 27: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1203 - accuracy: 0.9534 - val_loss: 2.4051 - val_accuracy: 0.6936 - lr: 1.0000e-06
# Epoch 28/500
# 274/276 [============================>.] - ETA: 0s - loss: 0.1208 - accuracy: 0.9553
# Epoch 28: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1212 - accuracy: 0.9551 - val_loss: 2.3888 - val_accuracy: 0.7007 - lr: 1.0000e-06
# Epoch 29/500
# 273/276 [============================>.] - ETA: 0s - loss: 0.1181 - accuracy: 0.9551
# Epoch 29: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 9ms/step - loss: 0.1184 - accuracy: 0.9549 - val_loss: 2.5243 - val_accuracy: 0.6936 - lr: 1.0000e-06
# Epoch 30/500
# 270/276 [============================>.] - ETA: 0s - loss: 0.1229 - accuracy: 0.9531
# Epoch 30: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1224 - accuracy: 0.9532 - val_loss: 2.4646 - val_accuracy: 0.6977 - lr: 1.0000e-06
# Epoch 31/500
# 274/276 [============================>.] - ETA: 0s - loss: 0.1201 - accuracy: 0.9557
# Epoch 31: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1198 - accuracy: 0.9559 - val_loss: 2.3972 - val_accuracy: 0.7028 - lr: 1.0000e-06
# Epoch 32/500
# 276/276 [==============================] - ETA: 0s - loss: 0.1184 - accuracy: 0.9551
# Epoch 32: val_loss did not improve from 0.55864
# 276/276 [==============================] - 3s 9ms/step - loss: 0.1184 - accuracy: 0.9551 - val_loss: 2.4701 - val_accuracy: 0.6956 - lr: 1.0000e-06
# Epoch 33/500
# 274/276 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9577
# Epoch 33: val_loss did not improve from 0.55864
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 276/276 [==============================] - 3s 10ms/step - loss: 0.1176 - accuracy: 0.9578 - val_loss: 2.5510 - val_accuracy: 0.6895 - lr: 1.0000e-06
# 28/28 [==============================] - 0s 4ms/step - loss: 0.8074 - accuracy: 0.6731
# Test accuracy: 67.31%

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
trained_model = tf.keras.models.load_model('Transformer_1_split.h5',custom_objects={'PositionalEmbedding': PositionalEmbedding,
                                                                     'TransformerEncoder':TransformerEncoder})

# %%
predicted_vals = trained_model.predict(test_data).argmax(axis=1)

labels = ['ca','cg','mock']

matrix = confusion_matrix (test_labels,predicted_vals)
plot_confusion_matrix(matrix, figsize=(4,4))
plt.xticks(range(3),labels, fontsize=10)
plt.yticks(range(3),labels, fontsize=10)
# Out:
# 28/28 [==============================] - 1s 4ms/step
# ([<matplotlib.axis.YTick at 0x7f106c08dac0>,
#   <matplotlib.axis.YTick at 0x7f106c08dc10>,
#   <matplotlib.axis.YTick at 0x7f106c08d610>],
#  [Text(0, 0, 'ca'), Text(0, 1, 'cg'), Text(0, 2, 'mock')])

# %%
target_names = ["$\it{C. albicans}$","$\it{C. glabrata}$","Mock"]

# %%
import seaborn as sns

cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cmn, cmap="flare",linewidths= 0.5,
            annot=True,xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/1_norm.png',dpi=300,bbox_inches='tight')

# %%
cm = confusion_matrix(test_labels,predicted_vals)
# Normalise
#sns.set(rc={"figure.dpi":200})
cmn = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(6,6))
sns.set(font_scale = 1.5)
image_cm = sns.heatmap(cm, cmap="flare",linewidths= 0.5,
            annot=True,fmt ='g',xticklabels=target_names, yticklabels=target_names, cbar=0)
plt.ylabel('True Labels', fontsize = 18)
plt.xlabel('Predicted Labels', fontsize = 18)
plt.xticks(rotation = 45, fontsize = 17)
plt.yticks(rotation = 45,fontsize = 17)
plt.title('Confusion Matrix', fontsize=20)
plt.show(block=True)
image_cm.figure.savefig('confusion_matrices_split/1_all.png',dpi=300,bbox_inches='tight')
