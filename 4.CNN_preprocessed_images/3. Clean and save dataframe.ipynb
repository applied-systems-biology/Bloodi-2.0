# %% [markdown]
# Copyright by Arjun Sarkar Research Group Applied Systems Biology - Head: Prof. Dr. Marc Thilo Figge https://www.leibniz-hki.de/en/applied-systems-biology.html HKI-Center for Systems Biology of Infection Leibniz Institute for Natural Product Research and Infection Biology - Hans Knöll Insitute (HKI) Adolf-Reichwein-Straße 23, 07745 Jena, Germany

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
import os
from sklearn import preprocessing

# %%
df = pd.read_csv('Label_preprocessed.csv')
df.head()
# Out:
#    video_num filename infection  patient
# 0          1  246.tif        ca        1
# 1          1  094.tif        ca        1
# 2          1  158.tif        ca        1
# 3          1  062.tif        ca        1
# 4          1  174.tif        ca        1

# %%
path = '/asbdata/Arjun/Bloodi/TIFF8_preprocessed/'

# %%
sns.countplot(x='infection',data=df)
# Out:
# <AxesSubplot: xlabel='infection', ylabel='count'>

# %%
le = preprocessing.LabelEncoder()
le.fit(df.infection)
df['class_label'] = le.transform(df.infection)

df.head()
# Out:
#    video_num filename infection  patient  class_label
# 0          1  246.tif        ca        1            0
# 1          1  094.tif        ca        1            0
# 2          1  158.tif        ca        1            0
# 3          1  062.tif        ca        1            0
# 4          1  174.tif        ca        1            0

# %%
df['path']=path
df.head()
# Out:
#    video_num filename infection  patient  class_label  \
# 0          1  246.tif        ca        1            0
# 1          1  094.tif        ca        1            0
# 2          1  158.tif        ca        1            0
# 3          1  062.tif        ca        1            0
# 4          1  174.tif        ca        1            0
#
#                                         path
# 0  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/
# 1  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/
# 2  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/
# 3  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/
# 4  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/

# %%
df['image_path']=df['path']+(df['video_num']).astype(str)+'/'+df['filename']
df.head()
# Out:
#    video_num filename infection  patient  class_label  \
# 0          1  246.tif        ca        1            0
# 1          1  094.tif        ca        1            0
# 2          1  158.tif        ca        1            0
# 3          1  062.tif        ca        1            0
# 4          1  174.tif        ca        1            0
#
#                                         path  \
# 0  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/
# 1  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/
# 2  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/
# 3  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/
# 4  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/
#
#                                           image_path
# 0  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/1/246...
# 1  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/1/094...
# 2  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/1/158...
# 3  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/1/062...
# 4  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/1/174...

# %%
df = df.drop('path',1)
df.head()
# Out:
# /tmp/ipykernel_2925472/3881183.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('path',1)
#    video_num filename infection  patient  class_label  \
# 0          1  246.tif        ca        1            0
# 1          1  094.tif        ca        1            0
# 2          1  158.tif        ca        1            0
# 3          1  062.tif        ca        1            0
# 4          1  174.tif        ca        1            0
#
#                                           image_path
# 0  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/1/246...
# 1  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/1/094...
# 2  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/1/158...
# 3  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/1/062...
# 4  /asbdata/Arjun/Bloodi/TIFF8_preprocessed/1/174...

# %%
df.to_csv('Label_Training.csv',index = False)
